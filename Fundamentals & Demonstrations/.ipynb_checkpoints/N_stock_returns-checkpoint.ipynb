# %% [markdown]
# <h1>Stock Return</h1>

# %%
from IPython.display import display
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# <h5>We will start by calculating the daily returns of a stock.</h5>

# %% [markdown]
# <p>Let's get the stock prices for Tesla over the past year:</p>

# %%
data = yf.Ticker('TSLA')
price = data.history(period='10y')
display(price)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-06-19 00:00:00-04:00   15.258667   15.687333   15.133333   15.186000
# 2014-06-20 00:00:00-04:00   15.234667   15.419333   15.080000   15.306000
# 2014-06-23 00:00:00-04:00   15.300667   15.932667   15.214667   15.814667
# 2014-06-24 00:00:00-04:00   15.931333   16.125334   15.442000   15.500000
# 2014-06-25 00:00:00-04:00   15.536667   15.836667   15.349333   15.792667
# ...                               ...         ...         ...         ...
# 2024-06-12 00:00:00-04:00  171.119995  180.550003  169.800003  177.289993
# 2024-06-13 00:00:00-04:00  188.389999  191.080002  181.229996  182.470001
# 2024-06-14 00:00:00-04:00  185.800003  186.000000  176.919998  178.009995
# 2024-06-17 00:00:00-04:00  177.919998  188.809998  177.000000  187.440002
# 2024-06-18 00:00:00-04:00  186.559998  187.199997  182.369995  184.860001
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-06-19 00:00:00-04:00  131896500        0.0           0.0
# 2014-06-20 00:00:00-04:00   73558500        0.0           0.0
# 2014-06-23 00:00:00-04:00  116866500        0.0           0.0
# 2014-06-24 00:00:00-04:00  121138500        0.0           0.0
# 2014-06-25 00:00:00-04:00   87024000        0.0           0.0
# ...                              ...        ...           ...
# 2024-06-12 00:00:00-04:00   90389400        0.0           0.0
# 2024-06-13 00:00:00-04:00  118984100        0.0           0.0
# 2024-06-14 00:00:00-04:00   82038200        0.0           0.0
# 2024-06-17 00:00:00-04:00  109786100        0.0           0.0
# 2024-06-18 00:00:00-04:00   68853400        0.0           0.0
#
# [2517 rows x 7 columns]

# %% [markdown]
# <h5>In order to calculate the daily returns, we will use the pct_change() function</h5>
# <p>Which calculates the percentage change between the current element and a prior one.</p>

# %% [markdown]
# <p>We will use it on the 'Close' column:</p>

# %%
pct_change = price['Close'].pct_change()
display(pct_change)
# Out:
# Date
# 2014-06-19 00:00:00-04:00         NaN
# 2014-06-20 00:00:00-04:00    0.007902
# 2014-06-23 00:00:00-04:00    0.033233
# 2014-06-24 00:00:00-04:00   -0.019897
# 2014-06-25 00:00:00-04:00    0.018882
#                                ...
# 2024-06-12 00:00:00-04:00    0.038849
# 2024-06-13 00:00:00-04:00    0.029218
# 2024-06-14 00:00:00-04:00   -0.024442
# 2024-06-17 00:00:00-04:00    0.052975
# 2024-06-18 00:00:00-04:00   -0.013764
# Name: Close, Length: 2517, dtype: float64

# %% [markdown]
# <h5>To visualize the results, we can create a plot for the daily returns:</h5>

# %%
pct_change.plot()
plt.show()

# %% [markdown]
# <h5>We can also make a histogram to see the distribution:</h5>

# %%
pct_change.plot(kind="hist")
plt.show()

# %% [markdown]
# <h5>After understanding how the returns are distributed, we can calculate the returns from an investment</h5>
# <p>For that, we need to calculate the cumulative returns, which can be done using the cumprod() function</p>

# %%
returns = (pct_change + 1).cumprod()
display(returns)
# Out:
# Date
# 2014-06-19 00:00:00-04:00          NaN
# 2014-06-20 00:00:00-04:00     1.007902
# 2014-06-23 00:00:00-04:00     1.041398
# 2014-06-24 00:00:00-04:00     1.020677
# 2014-06-25 00:00:00-04:00     1.039949
#                                ...
# 2024-06-12 00:00:00-04:00    11.674568
# 2024-06-13 00:00:00-04:00    12.015673
# 2024-06-14 00:00:00-04:00    11.721981
# 2024-06-17 00:00:00-04:00    12.342948
# 2024-06-18 00:00:00-04:00    12.173054
# Name: Close, Length: 2517, dtype: float64

# %% [markdown]
# <h5>Here is the plot:</h5>
# <p>The plot shows how a $1 investment would grow.</p>

# %%
returns.plot()
plt.show()
