# %% [markdown]
# <h1>Stock Return</h1>

# %%
from IPython.display import display
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# <h5>We will start by calculating the daily returns of a stock.</h5>

# %% [markdown]
# <p>Let's get the stock prices for Tesla over the past year:</p>

# %%
data = yf.Ticker('TSLA')
price = data.history(period='10y')
display(price)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-06-24 00:00:00-04:00   15.931333   16.125334   15.442000   15.500000
# 2014-06-25 00:00:00-04:00   15.536667   15.836667   15.349333   15.792667
# 2014-06-26 00:00:00-04:00   15.811333   16.026667   15.614000   15.706667
# 2014-06-27 00:00:00-04:00   15.646000   16.000000   15.633333   15.937333
# 2014-06-30 00:00:00-04:00   15.970000   16.299334   15.933333   16.004000
# ...                               ...         ...         ...         ...
# 2024-06-17 00:00:00-04:00  177.919998  188.809998  177.000000  187.440002
# 2024-06-18 00:00:00-04:00  186.559998  187.199997  182.369995  184.860001
# 2024-06-20 00:00:00-04:00  184.679993  185.210007  179.660004  181.570007
# 2024-06-21 00:00:00-04:00  182.300003  183.949997  180.690002  183.009995
# 2024-06-24 00:00:00-04:00  184.889999  188.380005  182.600006  183.450195
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-06-24 00:00:00-04:00  121138500        0.0           0.0
# 2014-06-25 00:00:00-04:00   87024000        0.0           0.0
# 2014-06-26 00:00:00-04:00   76821000        0.0           0.0
# 2014-06-27 00:00:00-04:00   84525000        0.0           0.0
# 2014-06-30 00:00:00-04:00   72429000        0.0           0.0
# ...                              ...        ...           ...
# 2024-06-17 00:00:00-04:00  109786100        0.0           0.0
# 2024-06-18 00:00:00-04:00   68982300        0.0           0.0
# 2024-06-20 00:00:00-04:00   55893100        0.0           0.0
# 2024-06-21 00:00:00-04:00   61937300        0.0           0.0
# 2024-06-24 00:00:00-04:00   47835995        0.0           0.0
#
# [2517 rows x 7 columns]

# %% [markdown]
# <h5>In order to calculate the daily returns, we will use the pct_change() function</h5>
# <p>Which calculates the percentage change between the current element and a prior one.</p>

# %% [markdown]
# <p>We will use it on the 'Close' column:</p>

# %%
pct_change = price['Close'].pct_change()
display(pct_change)
# Out:
# Date
# 2014-06-24 00:00:00-04:00         NaN
# 2014-06-25 00:00:00-04:00    0.018882
# 2014-06-26 00:00:00-04:00   -0.005446
# 2014-06-27 00:00:00-04:00    0.014686
# 2014-06-30 00:00:00-04:00    0.004183
#                                ...
# 2024-06-17 00:00:00-04:00    0.052975
# 2024-06-18 00:00:00-04:00   -0.013764
# 2024-06-20 00:00:00-04:00   -0.017797
# 2024-06-21 00:00:00-04:00    0.007931
# 2024-06-24 00:00:00-04:00    0.002405
# Name: Close, Length: 2517, dtype: float64

# %% [markdown]
# <h5>To visualize the results, we can create a plot for the daily returns:</h5>

# %%
pct_change.plot()
plt.show()

# %% [markdown]
# <h5>We can also make a histogram to see the distribution:</h5>

# %%
pct_change.plot(kind="hist")
plt.show()

# %% [markdown]
# <h5>After understanding how the returns are distributed, we can calculate the returns from an investment</h5>
# <p>For that, we need to calculate the cumulative returns, which can be done using the cumprod() function</p>

# %%
returns = (pct_change + 1).cumprod()
display(returns)
# Out:
# Date
# 2014-06-24 00:00:00-04:00          NaN
# 2014-06-25 00:00:00-04:00     1.018882
# 2014-06-26 00:00:00-04:00     1.013333
# 2014-06-27 00:00:00-04:00     1.028215
# 2014-06-30 00:00:00-04:00     1.032516
#                                ...
# 2024-06-17 00:00:00-04:00    12.092903
# 2024-06-18 00:00:00-04:00    11.926452
# 2024-06-20 00:00:00-04:00    11.714194
# 2024-06-21 00:00:00-04:00    11.807096
# 2024-06-24 00:00:00-04:00    11.835496
# Name: Close, Length: 2517, dtype: float64

# %% [markdown]
# <h5>Here is the plot:</h5>
# <p>The plot shows how a $1 investment would grow.</p>

# %%
returns.plot()
plt.show()
