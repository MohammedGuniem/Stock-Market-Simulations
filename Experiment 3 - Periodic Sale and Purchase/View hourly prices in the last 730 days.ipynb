# %%
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
# Download historical stock data for a specific ticker
symbol = 'AAPL'

stock = yf.Ticker(symbol)

stock_data = stock.history(period="730d", interval="1h")

# %%
display(stock_data)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2022-05-09 09:30:00-04:00  155.250000  155.759598  153.070007  153.210007
# 2022-05-09 10:30:00-04:00  153.199997  154.529999  152.000000  152.256699
# 2022-05-09 11:30:00-04:00  152.250000  153.500000  151.559998  153.274994
# 2022-05-09 12:30:00-04:00  153.250000  153.660004  152.259903  153.332001
# 2022-05-09 13:30:00-04:00  153.324997  153.539993  152.059998  152.190002
# ...                               ...         ...         ...         ...
# 2025-04-04 11:30:00-04:00  194.464996  196.000000  192.259995  192.809998
# 2025-04-04 12:30:00-04:00  192.779999  193.976196  190.899994  190.990005
# 2025-04-04 13:30:00-04:00  190.979996  192.570007  188.830994  188.880005
# 2025-04-04 14:30:00-04:00  188.899994  190.868805  187.345001  190.229996
# 2025-04-04 15:30:00-04:00  190.210007  191.729996  188.059998  188.380005
#
#                              Volume  Dividends  Stock Splits
# ...

# %%
print("Number of open trading days in market: ", len(stock_data))
# Out:
# Number of open trading days in market:  5086

# %%
import matplotlib.pyplot as plt

# Creating the plot
plt.plot(stock_data.index, stock_data["Close"].values)

# Adding title and labels
plt.title("Close vs. Datetime")
plt.xlabel("Datetime")
plt.ylabel("Close")

# Rotate x-tick labels vertically
plt.xticks(rotation=90)

# Enabling grid
plt.grid(True)

# Display the plot
plt.show()
