# %%
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
# Download historical stock data for a specific ticker
ticker = 'AAPL'

stock_data = yf.download(ticker, start='2010-01-01', end='2024-12-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
display(stock_data)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.440331    6.455077    6.391278    6.422877  493729600
# 2010-01-05    6.451465    6.487878    6.417459    6.458086  601904800
# 2010-01-06    6.348848    6.477047    6.342228    6.451467  552160000
# 2010-01-07    6.337109    6.379842    6.291066    6.372319  477131200
# 2010-01-08    6.379241    6.379844    6.291369    6.328684  447610800
# ...                ...         ...         ...         ...        ...
# 2024-12-23  254.989655  255.369227  253.171646  254.490204   40858800
# 2024-12-24  257.916443  257.926411  255.009620  255.209412   23234700
# 2024-12-26  258.735504  259.814335  257.347047  257.906429   27237100
# 2024-12-27  255.309296  258.415896  252.782075  257.546826   42355300
# 2024-12-30  251.923019  253.221595  250.474615  251.952985   35557500
#
# [3773 rows x 5 columns]

# %%
print("Number of open trading days in market: ", len(stock_data))
# Out:
# Number of open trading days in market:  3773

# %%
stock_close_prices = stock_data['Close']

# %%
def evaluate_trade_period(prices, period_length):
    investments = []
    prices_values = stock_close_prices.values
    if period_length >= len(prices) or period_length <= 0:
        raise ValueError("period_length should be less than len(prices) and bigger than 0")
        
    result_list = []
    for i in range(0, len(prices_values)-period_length, 1):
        buy_price = prices_values[i][0]
        investments.append(buy_price)
        sell_price = prices_values[i+period_length][0]
        result_list.append(float(sell_price-buy_price))
        
    return np.array(result_list), np.array(investments)

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=1)

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Number of all Buy/Sell Pairs (periods): 3772
# Sum of all Buy/Sell Pairs (periods): 245.48268842697144
# Number of investments: 3772
# Sum of investments: 254324.7914161682
#
# Number of Pairs (periods) with positive result (win): 2004
# Sum of Pairs (periods) with positive result (win): 1722.908004283905
#
# Number of Pairs (periods) with negative result (lost): 1761
# Sum of Pairs (periods) with negative result (lost): -1477.4253158569336

# %%
period_lengths, corresponding_results = [], []
for i in range(1, len(stock_close_prices), 1):
    result_list, investments = evaluate_trade_period(stock_close_prices, period_length=i)
    period_lengths.append(i)
    corresponding_results.append(sum(result_list))

    print(f"Length of period: {i}")
    print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
    print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
    print(f"Number of investments: {len(investments)}")
    print(f"Sum of investments: {sum(investments)}")
    print()
    
    positive_results = result_list[result_list > 0]
    print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
    print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
    print()
    
    negative_results = result_list[result_list < 0]
    print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
    print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
    print()
    print("------------------------------------------------------")
# Out:
# Length of period: 1
# Number of all Buy/Sell Pairs (periods): 3772
# Sum of all Buy/Sell Pairs (periods): 245.48268842697144
# Number of investments: 3772
# Sum of investments: 254324.7914161682
#
# Number of Pairs (periods) with positive result (win): 2004
# Sum of Pairs (periods) with positive result (win): 1722.908004283905
#
# Number of Pairs (periods) with negative result (lost): 1761
# Sum of Pairs (periods) with negative result (lost): -1477.4253158569336
#
# ------------------------------------------------------
# Length of period: 2
# Number of all Buy/Sell Pairs (periods): 3771
# Sum of all Buy/Sell Pairs (periods): 494.340518951416
# Number of investments: 3771
# Sum of investments: 254069.48212051392
#
# Number of Pairs (periods) with positive result (win): 2095
# Sum of Pairs (periods) with positive result (win): 2556.9842047691345
#
# Number of Pairs (periods) with negative result (lost): 1674
# Sum of Pairs (periods) with negative result (lost): -2062.6436858177185
#
# ------------------------------------------------------
# Length of period: 3
# Number of all Buy/Sell Pairs (periods): 3770
# Sum of all Buy/Sell Pairs (periods): 746.7271747589111
# Number of investments: 3770
# Sum of investments: 253810.74661636353
#
# Number of Pairs (periods) with positive result (win): 2137
# Sum of Pairs (periods) with positive result (win): 3198.343113422394
#
# Number of Pairs (periods) with negative result (lost): 1627
# Sum of Pairs (periods) with negative result (lost): -2451.6159386634827
#
# ------------------------------------------------------
# Length of period: 4
# Number of all Buy/Sell Pairs (periods): 3769
# Sum of all Buy/Sell Pairs (periods): 998.3065090179443
# Number of investments: 3769
# Sum of investments: 253552.83017349243
#
# Number of Pairs (periods) with positive result (win): 2151
# Sum of Pairs (periods) with positive result (win): 3763.572497844696
#
# Number of Pairs (periods) with negative result (lost): 1616
# Sum of Pairs (periods) with negative result (lost): -2765.2659888267517
#
# ------------------------------------------------------
# Length of period: 5
# Number of all Buy/Sell Pairs (periods): 3768
# Sum of all Buy/Sell Pairs (periods): 1246.9169220924377
# Number of investments: 3768
# Sum of investments: 253297.84051895142
#
# Number of Pairs (periods) with positive result (win): 2182
# Sum of Pairs (periods) with positive result (win): 4308.668833255768
#
# Number of Pairs (periods) with negative result (lost): 1583
# Sum of Pairs (periods) with negative result (lost): -3061.75191116333
#
# ------------------------------------------------------
# Length of period: 6
# Number of all Buy/Sell Pairs (periods): 3767
# Sum of all Buy/Sell Pairs (periods): 1494.8044667243958
# Number of investments: 3767
# Sum of investments: 253043.6300086975
#
# Number of Pairs (periods) with positive result (win): 2202
# Sum of Pairs (periods) with positive result (win): 4805.080173969269
#
# Number of Pairs (periods) with negative result (lost): 1564
# Sum of Pairs (periods) with negative result (lost): -3310.275707244873
#
# ------------------------------------------------------
# Length of period: 7
# Number of all Buy/Sell Pairs (periods): 3766
# Sum of all Buy/Sell Pairs (periods): 1738.0690808296204
# Number of investments: 3766
# Sum of investments: 252794.11435317993
#
# Number of Pairs (periods) with positive result (win): 2224
# Sum of Pairs (periods) with positive result (win): 5289.103187561035
#
# Number of Pairs (periods) with negative result (lost): 1541
# Sum of Pairs (periods) with negative result (lost): -3551.034106731415
#
# ------------------------------------------------------
# Length of period: 8
# Number of all Buy/Sell Pairs (periods): 3765
# Sum of all Buy/Sell Pairs (periods): 1979.507435798645
# Number of investments: 3765
# Sum of investments: 252546.3367805481
#
# Number of Pairs (periods) with positive result (win): 2243
# Sum of Pairs (periods) with positive result (win): 5785.96924495697
#
# Number of Pairs (periods) with negative result (lost): 1520
# Sum of Pairs (periods) with negative result (lost): -3806.461809158325
#
# ------------------------------------------------------
# Length of period: 9
# Number of all Buy/Sell Pairs (periods): 3764
# Sum of all Buy/Sell Pairs (periods): 2226.4065351486206
# Number of investments: 3764
# Sum of investments: 252293.135181427
#
# Number of Pairs (periods) with positive result (win): 2238
# Sum of Pairs (periods) with positive result (win): 6238.7527413368225
#
# Number of Pairs (periods) with negative result (lost): 1526
# Sum of Pairs (periods) with negative result (lost): -4012.346206188202
#
# ------------------------------------------------------
# Length of period: 10
# Number of all Buy/Sell Pairs (periods): 3763
# Sum of all Buy/Sell Pairs (periods): 2470.973641872406
# Number of investments: 3763
# Sum of investments: 252042.37089920044
#
# Number of Pairs (periods) with positive result (win): 2263
# Sum of Pairs (periods) with positive result (win): 6677.098910331726
#
# Number of Pairs (periods) with negative result (lost): 1497
# Sum of Pairs (periods) with negative result (lost): -4206.12526845932
#
# ------------------------------------------------------
# Length of period: 11
# Number of all Buy/Sell Pairs (periods): 3762
# Sum of all Buy/Sell Pairs (periods): 2712.3597984313965
# Number of investments: 3762
# Sum of investments: 251794.51341629028
#
# Number of Pairs (periods) with positive result (win): 2272
# Sum of Pairs (periods) with positive result (win): 7111.091028690338
#
# Number of Pairs (periods) with negative result (lost): 1489
# Sum of Pairs (periods) with negative result (lost): -4398.731230258942
#
# ------------------------------------------------------
# Length of period: 12
# Number of all Buy/Sell Pairs (periods): 3761
# Sum of all Buy/Sell Pairs (periods): 2953.6757640838623
# Number of investments: 3761
# Sum of investments: 251546.8257331848
#
# Number of Pairs (periods) with positive result (win): 2287
# Sum of Pairs (periods) with positive result (win): 7521.428857803345
#
# Number of Pairs (periods) with negative result (lost): 1471
# Sum of Pairs (periods) with negative result (lost): -4567.753093719482
#
# ------------------------------------------------------
# Length of period: 13
# Number of all Buy/Sell Pairs (periods): 3760
# Sum of all Buy/Sell Pairs (periods): 3193.633472919464
# Number of investments: 3760
# Sum of investments: 251300.6064491272
#
# Number of Pairs (periods) with positive result (win): 2299
# Sum of Pairs (periods) with positive result (win): 7895.409471035004
#
# Number of Pairs (periods) with negative result (lost): 1461
# Sum of Pairs (periods) with negative result (lost): -4701.77599811554
#
# ------------------------------------------------------
# Length of period: 14
# Number of all Buy/Sell Pairs (periods): 3759
# Sum of all Buy/Sell Pairs (periods): 3435.1803426742554
# Number of investments: 3759
# Sum of investments: 251053.10857009888
#
# Number of Pairs (periods) with positive result (win): 2317
# Sum of Pairs (periods) with positive result (win): 8256.916906356812
#
# Number of Pairs (periods) with negative result (lost): 1440
# Sum of Pairs (periods) with negative result (lost): -4821.736563682556
#
# ------------------------------------------------------
# Length of period: 15
# Number of all Buy/Sell Pairs (periods): 3758
# Sum of all Buy/Sell Pairs (periods): 3675.5482387542725
# Number of investments: 3758
# Sum of investments: 250806.62956619263
#
# Number of Pairs (periods) with positive result (win): 2325
# Sum of Pairs (periods) with positive result (win): 8628.252666473389
#
# Number of Pairs (periods) with negative result (lost): 1433
# Sum of Pairs (periods) with negative result (lost): -4952.704427719116
#
# ------------------------------------------------------
# Length of period: 16
# Number of all Buy/Sell Pairs (periods): 3757
# Sum of all Buy/Sell Pairs (periods): 3911.924051761627
# Number of investments: 3757
# Sum of investments: 250564.05627822876
#
# Number of Pairs (periods) with positive result (win): 2330
# Sum of Pairs (periods) with positive result (win): 8981.938054084778
#
# Number of Pairs (periods) with negative result (lost): 1427
# Sum of Pairs (periods) with negative result (lost): -5070.014002323151
#
# ------------------------------------------------------
# Length of period: 17
# Number of all Buy/Sell Pairs (periods): 3756
# Sum of all Buy/Sell Pairs (periods): 4148.441265583038
# Number of investments: 3756
# Sum of investments: 250321.2832069397
#
# Number of Pairs (periods) with positive result (win): 2347
# Sum of Pairs (periods) with positive result (win): 9355.27667093277
#
# Number of Pairs (periods) with negative result (lost): 1409
# Sum of Pairs (periods) with negative result (lost): -5206.835405349731
#
# ------------------------------------------------------
# Length of period: 18
# Number of all Buy/Sell Pairs (periods): 3755
# Sum of all Buy/Sell Pairs (periods): 4385.18701505661
# Number of investments: 3755
# Sum of investments: 250078.54010391235
#
# Number of Pairs (periods) with positive result (win): 2342
# Sum of Pairs (periods) with positive result (win): 9661.32597732544
#
# Number of Pairs (periods) with negative result (lost): 1413
# Sum of Pairs (periods) with negative result (lost): -5276.138962268829
#
# ------------------------------------------------------
# Length of period: 19
# Number of all Buy/Sell Pairs (periods): 3754
# Sum of all Buy/Sell Pairs (periods): 4621.790738582611
# Number of investments: 3754
# Sum of investments: 249836.15660476685
#
# Number of Pairs (periods) with positive result (win): 2364
# Sum of Pairs (periods) with positive result (win): 9975.662829875946
#
# Number of Pairs (periods) with negative result (lost): 1390
# Sum of Pairs (periods) with negative result (lost): -5353.872091293335
#
# ------------------------------------------------------
# Length of period: 20
# Number of all Buy/Sell Pairs (periods): 3753
# Sum of all Buy/Sell Pairs (periods): 4855.257471084595
# Number of investments: 3753
# Sum of investments: 249596.82974624634
#
# Number of Pairs (periods) with positive result (win): 2360
# Sum of Pairs (periods) with positive result (win): 10280.405087471008
#
# Number of Pairs (periods) with negative result (lost): 1393
# Sum of Pairs (periods) with negative result (lost): -5425.147616386414
#
# ------------------------------------------------------
# Length of period: 21
# Number of all Buy/Sell Pairs (periods): 3752
# Sum of all Buy/Sell Pairs (periods): 5086.432689189911
# Number of investments: 3752
# Sum of investments: 249359.76039505005
#
# Number of Pairs (periods) with positive result (win): 2345
# Sum of Pairs (periods) with positive result (win): 10621.322266101837
#
# Number of Pairs (periods) with negative result (lost): 1406
# Sum of Pairs (periods) with negative result (lost): -5534.889576911926
#
# ------------------------------------------------------
# Length of period: 22
# Number of all Buy/Sell Pairs (periods): 3751
# Sum of all Buy/Sell Pairs (periods): 5315.109124183655
# Number of investments: 3751
# Sum of investments: 249125.08841323853
#
# Number of Pairs (periods) with positive result (win): 2339
# Sum of Pairs (periods) with positive result (win): 10966.191105365753
#
# Number of Pairs (periods) with negative result (lost): 1412
# Sum of Pairs (periods) with negative result (lost): -5651.081981182098
#
# ------------------------------------------------------
# Length of period: 23
# Number of all Buy/Sell Pairs (periods): 3750
# Sum of all Buy/Sell Pairs (periods): 5544.131482601166
# Number of investments: 3750
# Sum of investments: 248890.28657913208
#
# Number of Pairs (periods) with positive result (win): 2341
# Sum of Pairs (periods) with positive result (win): 11313.426352500916
#
# Number of Pairs (periods) with negative result (lost): 1407
# Sum of Pairs (periods) with negative result (lost): -5769.29486989975
#
# ------------------------------------------------------
# Length of period: 24
# Number of all Buy/Sell Pairs (periods): 3749
# Sum of all Buy/Sell Pairs (periods): 5770.863632678986
# Number of investments: 3749
# Sum of investments: 248657.67233657837
#
# Number of Pairs (periods) with positive result (win): 2330
# Sum of Pairs (periods) with positive result (win): 11630.325953960419
#
# Number of Pairs (periods) with negative result (lost): 1418
# Sum of Pairs (periods) with negative result (lost): -5859.462321281433
#
# ------------------------------------------------------
# Length of period: 25
# Number of all Buy/Sell Pairs (periods): 3748
# Sum of all Buy/Sell Pairs (periods): 5994.639400482178
# Number of investments: 3748
# Sum of investments: 248428.05479812622
#
# Number of Pairs (periods) with positive result (win): 2330
# Sum of Pairs (periods) with positive result (win): 11898.45305776596
#
# Number of Pairs (periods) with negative result (lost): 1417
# Sum of Pairs (periods) with negative result (lost): -5903.813657283783
#
# ------------------------------------------------------
# Length of period: 26
# Number of all Buy/Sell Pairs (periods): 3747
# Sum of all Buy/Sell Pairs (periods): 6217.0043659210205
# Number of investments: 3747
# Sum of investments: 248199.78577041626
#
# Number of Pairs (periods) with positive result (win): 2330
# Sum of Pairs (periods) with positive result (win): 12157.83880519867
#
# Number of Pairs (periods) with negative result (lost): 1417
# Sum of Pairs (periods) with negative result (lost): -5940.834439277649
#
# ------------------------------------------------------
# Length of period: 27
# Number of all Buy/Sell Pairs (periods): 3746
# Sum of all Buy/Sell Pairs (periods): 6439.8809933662415
# Number of investments: 3746
# Sum of investments: 247971.03728103638
#
# Number of Pairs (periods) with positive result (win): 2339
# Sum of Pairs (periods) with positive result (win): 12408.207206249237
#
# Number of Pairs (periods) with negative result (lost): 1406
# Sum of Pairs (periods) with negative result (lost): -5968.326212882996
#
# ------------------------------------------------------
# Length of period: 28
# Number of all Buy/Sell Pairs (periods): 3745
# Sum of all Buy/Sell Pairs (periods): 6661.931581497192
# Number of investments: 3745
# Sum of investments: 247743.00799942017
#
# Number of Pairs (periods) with positive result (win): 2345
# Sum of Pairs (periods) with positive result (win): 12674.130379676819
#
# Number of Pairs (periods) with negative result (lost): 1400
# Sum of Pairs (periods) with negative result (lost): -6012.1987981796265
#
# ------------------------------------------------------
# Length of period: 29
# Number of all Buy/Sell Pairs (periods): 3744
# Sum of all Buy/Sell Pairs (periods): 6883.671003818512
# Number of investments: 3744
# Sum of investments: 247515.2384223938
#
# Number of Pairs (periods) with positive result (win): 2352
# Sum of Pairs (periods) with positive result (win): 12947.142460346222
#
# Number of Pairs (periods) with negative result (lost): 1391
# Sum of Pairs (periods) with negative result (lost): -6063.47145652771
#
# ------------------------------------------------------
# Length of period: 30
# Number of all Buy/Sell Pairs (periods): 3743
# Sum of all Buy/Sell Pairs (periods): 7102.302849292755
# Number of investments: 3743
# Sum of investments: 247290.48553848267
#
# Number of Pairs (periods) with positive result (win): 2362
# Sum of Pairs (periods) with positive result (win): 13241.665879249573
#
# Number of Pairs (periods) with negative result (lost): 1380
# Sum of Pairs (periods) with negative result (lost): -6139.363029956818
#
# ------------------------------------------------------
# Length of period: 31
# Number of all Buy/Sell Pairs (periods): 3742
# Sum of all Buy/Sell Pairs (periods): 7324.176749706268
# Number of investments: 3742
# Sum of investments: 247062.5161781311
#
# Number of Pairs (periods) with positive result (win): 2359
# Sum of Pairs (periods) with positive result (win): 13522.3968334198
#
# Number of Pairs (periods) with negative result (lost): 1383
# Sum of Pairs (periods) with negative result (lost): -6198.2200837135315
#
# ------------------------------------------------------
# Length of period: 32
# Number of all Buy/Sell Pairs (periods): 3741
# Sum of all Buy/Sell Pairs (periods): 7542.942613124847
# Number of investments: 3741
# Sum of investments: 246837.6434211731
#
# Number of Pairs (periods) with positive result (win): 2396
# Sum of Pairs (periods) with positive result (win): 13804.271500110626
#
# Number of Pairs (periods) with negative result (lost): 1345
# Sum of Pairs (periods) with negative result (lost): -6261.328886985779
#
# ------------------------------------------------------
# Length of period: 33
# Number of all Buy/Sell Pairs (periods): 3740
# Sum of all Buy/Sell Pairs (periods): 7760.857372283936
# Number of investments: 3740
# Sum of investments: 246613.65968704224
#
# Number of Pairs (periods) with positive result (win): 2403
# Sum of Pairs (periods) with positive result (win): 14081.079624176025
#
# Number of Pairs (periods) with negative result (lost): 1337
# Sum of Pairs (periods) with negative result (lost): -6320.22225189209
#
# ------------------------------------------------------
# Length of period: 34
# Number of all Buy/Sell Pairs (periods): 3739
# Sum of all Buy/Sell Pairs (periods): 7978.80974817276
# Number of investments: 3739
# Sum of investments: 246389.67595291138
#
# Number of Pairs (periods) with positive result (win): 2414
# Sum of Pairs (periods) with positive result (win): 14344.93633890152
#
# Number of Pairs (periods) with negative result (lost): 1325
# Sum of Pairs (periods) with negative result (lost): -6366.12659072876
#
# ------------------------------------------------------
# Length of period: 35
# Number of all Buy/Sell Pairs (periods): 3738
# Sum of all Buy/Sell Pairs (periods): 8199.590243339539
# Number of investments: 3738
# Sum of investments: 246162.96521377563
#
# Number of Pairs (periods) with positive result (win): 2426
# Sum of Pairs (periods) with positive result (win): 14612.804857254028
#
# Number of Pairs (periods) with negative result (lost): 1312
# Sum of Pairs (periods) with negative result (lost): -6413.21461391449
#
# ------------------------------------------------------
# Length of period: 36
# Number of all Buy/Sell Pairs (periods): 3737
# Sum of all Buy/Sell Pairs (periods): 8420.532100200653
# Number of investments: 3737
# Sum of investments: 245935.9847755432
#
# Number of Pairs (periods) with positive result (win): 2430
# Sum of Pairs (periods) with positive result (win): 14894.501166343689
#
# Number of Pairs (periods) with negative result (lost): 1307
# Sum of Pairs (periods) with negative result (lost): -6473.969066143036
#
# ------------------------------------------------------
# Length of period: 37
# Number of all Buy/Sell Pairs (periods): 3736
# Sum of all Buy/Sell Pairs (periods): 8636.68408870697
# Number of investments: 3736
# Sum of investments: 245713.75387954712
#
# Number of Pairs (periods) with positive result (win): 2452
# Sum of Pairs (periods) with positive result (win): 15154.848599910736
#
# Number of Pairs (periods) with negative result (lost): 1283
# Sum of Pairs (periods) with negative result (lost): -6518.164511203766
#
# ------------------------------------------------------
# Length of period: 38
# Number of all Buy/Sell Pairs (periods): 3735
# Sum of all Buy/Sell Pairs (periods): 8853.48562669754
# Number of investments: 3735
# Sum of investments: 245490.79458999634
#
# Number of Pairs (periods) with positive result (win): 2480
# Sum of Pairs (periods) with positive result (win): 15428.011205673218
#
# Number of Pairs (periods) with negative result (lost): 1255
# Sum of Pairs (periods) with negative result (lost): -6574.5255789756775
#
# ------------------------------------------------------
# Length of period: 39
# Number of all Buy/Sell Pairs (periods): 3734
# Sum of all Buy/Sell Pairs (periods): 9068.718811035156
# Number of investments: 3734
# Sum of investments: 245269.27214431763
#
# Number of Pairs (periods) with positive result (win): 2497
# Sum of Pairs (periods) with positive result (win): 15694.838562011719
#
# Number of Pairs (periods) with negative result (lost): 1237
# Sum of Pairs (periods) with negative result (lost): -6626.1197509765625
#
# ------------------------------------------------------
# Length of period: 40
# Number of all Buy/Sell Pairs (periods): 3733
# Sum of all Buy/Sell Pairs (periods): 9284.854233264923
# Number of investments: 3733
# Sum of investments: 245046.85167312622
#
# Number of Pairs (periods) with positive result (win): 2475
# Sum of Pairs (periods) with positive result (win): 15953.237129211426
#
# Number of Pairs (periods) with negative result (lost): 1258
# Sum of Pairs (periods) with negative result (lost): -6668.382895946503
#
# ------------------------------------------------------
# Length of period: 41
# Number of all Buy/Sell Pairs (periods): 3732
# Sum of all Buy/Sell Pairs (periods): 9503.968634605408
# Number of investments: 3732
# Sum of investments: 244821.4377784729
#
# Number of Pairs (periods) with positive result (win): 2504
# Sum of Pairs (periods) with positive result (win): 16188.350671291351
#
# Number of Pairs (periods) with negative result (lost): 1226
# Sum of Pairs (periods) with negative result (lost): -6684.382036685944
#
# ------------------------------------------------------
# Length of period: 42
# Number of all Buy/Sell Pairs (periods): 3731
# Sum of all Buy/Sell Pairs (periods): 9727.222293376923
# Number of investments: 3731
# Sum of investments: 244591.84309768677
#
# Number of Pairs (periods) with positive result (win): 2499
# Sum of Pairs (periods) with positive result (win): 16434.110500335693
#
# Number of Pairs (periods) with negative result (lost): 1232
# Sum of Pairs (periods) with negative result (lost): -6706.888206958771
#
# ------------------------------------------------------
# Length of period: 43
# Number of all Buy/Sell Pairs (periods): 3730
# Sum of all Buy/Sell Pairs (periods): 9953.790143489838
# Number of investments: 3730
# Sum of investments: 244358.686252594
#
# Number of Pairs (periods) with positive result (win): 2492
# Sum of Pairs (periods) with positive result (win): 16702.53661441803
#
# Number of Pairs (periods) with negative result (lost): 1237
# Sum of Pairs (periods) with negative result (lost): -6748.746470928192
#
# ------------------------------------------------------
# Length of period: 44
# Number of all Buy/Sell Pairs (periods): 3729
# Sum of all Buy/Sell Pairs (periods): 10180.084675312042
# Number of investments: 3729
# Sum of investments: 244125.7988166809
#
# Number of Pairs (periods) with positive result (win): 2502
# Sum of Pairs (periods) with positive result (win): 16961.525492668152
#
# Number of Pairs (periods) with negative result (lost): 1226
# Sum of Pairs (periods) with negative result (lost): -6781.44081735611
#
# ------------------------------------------------------
# Length of period: 45
# Number of all Buy/Sell Pairs (periods): 3728
# Sum of all Buy/Sell Pairs (periods): 10404.275011062622
# Number of investments: 3728
# Sum of investments: 243894.89700698853
#
# Number of Pairs (periods) with positive result (win): 2506
# Sum of Pairs (periods) with positive result (win): 17196.866228580475
#
# Number of Pairs (periods) with negative result (lost): 1221
# Sum of Pairs (periods) with negative result (lost): -6792.591217517853
#
# ------------------------------------------------------
# Length of period: 46
# Number of all Buy/Sell Pairs (periods): 3727
# Sum of all Buy/Sell Pairs (periods): 10627.572439193726
# Number of investments: 3727
# Sum of investments: 243664.83333206177
#
# Number of Pairs (periods) with positive result (win): 2527
# Sum of Pairs (periods) with positive result (win): 17433.158113002777
#
# Number of Pairs (periods) with negative result (lost): 1199
# Sum of Pairs (periods) with negative result (lost): -6805.5856738090515
#
# ------------------------------------------------------
# Length of period: 47
# Number of all Buy/Sell Pairs (periods): 3726
# Sum of all Buy/Sell Pairs (periods): 10851.03956747055
# Number of investments: 3726
# Sum of investments: 243434.5800971985
#
# Number of Pairs (periods) with positive result (win): 2538
# Sum of Pairs (periods) with positive result (win): 17655.79715156555
#
# Number of Pairs (periods) with negative result (lost): 1187
# Sum of Pairs (periods) with negative result (lost): -6804.757584095001
#
# ------------------------------------------------------
# Length of period: 48
# Number of all Buy/Sell Pairs (periods): 3725
# Sum of all Buy/Sell Pairs (periods): 11079.562398433685
# Number of investments: 3725
# Sum of investments: 243199.23805618286
#
# Number of Pairs (periods) with positive result (win): 2545
# Sum of Pairs (periods) with positive result (win): 17892.77452802658
#
# Number of Pairs (periods) with negative result (lost): 1180
# Sum of Pairs (periods) with negative result (lost): -6813.2121295928955
#
# ------------------------------------------------------
# Length of period: 49
# Number of all Buy/Sell Pairs (periods): 3724
# Sum of all Buy/Sell Pairs (periods): 11308.786924362183
# Number of investments: 3724
# Sum of investments: 242963.27737808228
#
# Number of Pairs (periods) with positive result (win): 2549
# Sum of Pairs (periods) with positive result (win): 18135.686294555664
#
# Number of Pairs (periods) with negative result (lost): 1175
# Sum of Pairs (periods) with negative result (lost): -6826.899370193481
#
# ------------------------------------------------------
# Length of period: 50
# Number of all Buy/Sell Pairs (periods): 3723
# Sum of all Buy/Sell Pairs (periods): 11536.516334533691
# Number of investments: 3723
# Sum of investments: 242728.79346084595
#
# Number of Pairs (periods) with positive result (win): 2557
# Sum of Pairs (periods) with positive result (win): 18354.71560382843
#
# Number of Pairs (periods) with negative result (lost): 1166
# Sum of Pairs (periods) with negative result (lost): -6818.199269294739
#
# ------------------------------------------------------
# Length of period: 51
# Number of all Buy/Sell Pairs (periods): 3722
# Sum of all Buy/Sell Pairs (periods): 11761.411939620972
# Number of investments: 3722
# Sum of investments: 242497.15327835083
#
# Number of Pairs (periods) with positive result (win): 2578
# Sum of Pairs (periods) with positive result (win): 18578.903563022614
#
# Number of Pairs (periods) with negative result (lost): 1144
# Sum of Pairs (periods) with negative result (lost): -6817.491623401642
#
# ------------------------------------------------------
# Length of period: 52
# Number of all Buy/Sell Pairs (periods): 3721
# Sum of all Buy/Sell Pairs (periods): 11985.922407150269
# Number of investments: 3721
# Sum of investments: 242265.88228225708
#
# Number of Pairs (periods) with positive result (win): 2590
# Sum of Pairs (periods) with positive result (win): 18795.115637779236
#
# Number of Pairs (periods) with negative result (lost): 1131
# Sum of Pairs (periods) with negative result (lost): -6809.193230628967
#
# ------------------------------------------------------
# Length of period: 53
# Number of all Buy/Sell Pairs (periods): 3720
# Sum of all Buy/Sell Pairs (periods): 12212.570561408997
# Number of investments: 3720
# Sum of investments: 242032.54582595825
#
# Number of Pairs (periods) with positive result (win): 2587
# Sum of Pairs (periods) with positive result (win): 19007.084117412567
#
# Number of Pairs (periods) with negative result (lost): 1133
# Sum of Pairs (periods) with negative result (lost): -6794.513556003571
#
# ------------------------------------------------------
# Length of period: 54
# Number of all Buy/Sell Pairs (periods): 3719
# Sum of all Buy/Sell Pairs (periods): 12436.599078655243
# Number of investments: 3719
# Sum of investments: 241801.7537727356
#
# Number of Pairs (periods) with positive result (win): 2587
# Sum of Pairs (periods) with positive result (win): 19232.29847574234
#
# Number of Pairs (periods) with negative result (lost): 1132
# Sum of Pairs (periods) with negative result (lost): -6795.699397087097
#
# ------------------------------------------------------
# Length of period: 55
# Number of all Buy/Sell Pairs (periods): 3718
# Sum of all Buy/Sell Pairs (periods): 12656.77719783783
# Number of investments: 3718
# Sum of investments: 241574.70347976685
#
# Number of Pairs (periods) with positive result (win): 2589
# Sum of Pairs (periods) with positive result (win): 19456.84297800064
#
# Number of Pairs (periods) with negative result (lost): 1129
# Sum of Pairs (periods) with negative result (lost): -6800.065780162811
#
# ------------------------------------------------------
# Length of period: 56
# Number of all Buy/Sell Pairs (periods): 3717
# Sum of all Buy/Sell Pairs (periods): 12878.41164779663
# Number of investments: 3717
# Sum of investments: 241346.16646194458
#
# Number of Pairs (periods) with positive result (win): 2590
# Sum of Pairs (periods) with positive result (win): 19677.52899837494
#
# Number of Pairs (periods) with negative result (lost): 1127
# Sum of Pairs (periods) with negative result (lost): -6799.117350578308
#
# ------------------------------------------------------
# Length of period: 57
# Number of all Buy/Sell Pairs (periods): 3716
# Sum of all Buy/Sell Pairs (periods): 13100.62685251236
# Number of investments: 3716
# Sum of investments: 241117.13054275513
#
# Number of Pairs (periods) with positive result (win): 2599
# Sum of Pairs (periods) with positive result (win): 19889.52079153061
#
# Number of Pairs (periods) with negative result (lost): 1117
# Sum of Pairs (periods) with negative result (lost): -6788.8939390182495
#
# ------------------------------------------------------
# Length of period: 58
# Number of all Buy/Sell Pairs (periods): 3715
# Sum of all Buy/Sell Pairs (periods): 13318.952442646027
# Number of investments: 3715
# Sum of investments: 240891.85634231567
#
# Number of Pairs (periods) with positive result (win): 2597
# Sum of Pairs (periods) with positive result (win): 20126.104928970337
#
# Number of Pairs (periods) with negative result (lost): 1118
# Sum of Pairs (periods) with negative result (lost): -6807.15248632431
#
# ------------------------------------------------------
# Length of period: 59
# Number of all Buy/Sell Pairs (periods): 3714
# Sum of all Buy/Sell Pairs (periods): 13533.16214799881
# Number of investments: 3714
# Sum of investments: 240670.6531867981
#
# Number of Pairs (periods) with positive result (win): 2611
# Sum of Pairs (periods) with positive result (win): 20330.74960422516
#
# Number of Pairs (periods) with negative result (lost): 1103
# Sum of Pairs (periods) with negative result (lost): -6797.587456226349
#
# ------------------------------------------------------
# Length of period: 60
# Number of all Buy/Sell Pairs (periods): 3713
# Sum of all Buy/Sell Pairs (periods): 13752.366513252258
# Number of investments: 3713
# Sum of investments: 240444.35124588013
#
# Number of Pairs (periods) with positive result (win): 2628
# Sum of Pairs (periods) with positive result (win): 20554.643500328064
#
# Number of Pairs (periods) with negative result (lost): 1085
# Sum of Pairs (periods) with negative result (lost): -6802.276987075806
#
# ------------------------------------------------------
# Length of period: 61
# Number of all Buy/Sell Pairs (periods): 3712
# Sum of all Buy/Sell Pairs (periods): 13970.468925476074
# Number of investments: 3712
# Sum of investments: 240219.17683792114
#
# Number of Pairs (periods) with positive result (win): 2630
# Sum of Pairs (periods) with positive result (win): 20776.992508411407
#
# Number of Pairs (periods) with negative result (lost): 1082
# Sum of Pairs (periods) with negative result (lost): -6806.523582935333
#
# ------------------------------------------------------
# Length of period: 62
# Number of all Buy/Sell Pairs (periods): 3711
# Sum of all Buy/Sell Pairs (periods): 14189.649723529816
# Number of investments: 3711
# Sum of investments: 239992.89485549927
#
# Number of Pairs (periods) with positive result (win): 2643
# Sum of Pairs (periods) with positive result (win): 20986.324472904205
#
# Number of Pairs (periods) with negative result (lost): 1068
# Sum of Pairs (periods) with negative result (lost): -6796.67474937439
#
# ------------------------------------------------------
# Length of period: 63
# Number of all Buy/Sell Pairs (periods): 3710
# Sum of all Buy/Sell Pairs (periods): 14408.185944080353
# Number of investments: 3710
# Sum of investments: 239767.18161392212
#
# Number of Pairs (periods) with positive result (win): 2642
# Sum of Pairs (periods) with positive result (win): 21177.440014362335
#
# Number of Pairs (periods) with negative result (lost): 1068
# Sum of Pairs (periods) with negative result (lost): -6769.254070281982
#
# ------------------------------------------------------
# Length of period: 64
# Number of all Buy/Sell Pairs (periods): 3709
# Sum of all Buy/Sell Pairs (periods): 14633.465650081635
# Number of investments: 3709
# Sum of investments: 239534.69328689575
#
# Number of Pairs (periods) with positive result (win): 2662
# Sum of Pairs (periods) with positive result (win): 21383.7237534523
#
# Number of Pairs (periods) with negative result (lost): 1047
# Sum of Pairs (periods) with negative result (lost): -6750.2581033706665
#
# ------------------------------------------------------
# Length of period: 65
# Number of all Buy/Sell Pairs (periods): 3708
# Sum of all Buy/Sell Pairs (periods): 14853.514883041382
# Number of investments: 3708
# Sum of investments: 239307.40353775024
#
# Number of Pairs (periods) with positive result (win): 2676
# Sum of Pairs (periods) with positive result (win): 21593.520619392395
#
# Number of Pairs (periods) with negative result (lost): 1032
# Sum of Pairs (periods) with negative result (lost): -6740.005736351013
#
# ------------------------------------------------------
# Length of period: 66
# Number of all Buy/Sell Pairs (periods): 3707
# Sum of all Buy/Sell Pairs (periods): 15073.3142786026
# Number of investments: 3707
# Sum of investments: 239080.38318252563
#
# Number of Pairs (periods) with positive result (win): 2678
# Sum of Pairs (periods) with positive result (win): 21780.850820064545
#
# Number of Pairs (periods) with negative result (lost): 1029
# Sum of Pairs (periods) with negative result (lost): -6707.536541461945
#
# ------------------------------------------------------
# Length of period: 67
# Number of all Buy/Sell Pairs (periods): 3706
# Sum of all Buy/Sell Pairs (periods): 15291.910827159882
# Number of investments: 3706
# Sum of investments: 238854.5103034973
#
# Number of Pairs (periods) with positive result (win): 2693
# Sum of Pairs (periods) with positive result (win): 21970.40793609619
#
# Number of Pairs (periods) with negative result (lost): 1013
# Sum of Pairs (periods) with negative result (lost): -6678.49710893631
#
# ------------------------------------------------------
# Length of period: 68
# Number of all Buy/Sell Pairs (periods): 3705
# Sum of all Buy/Sell Pairs (periods): 15511.490132808685
# Number of investments: 3705
# Sum of investments: 238627.63962173462
#
# Number of Pairs (periods) with positive result (win): 2691
# Sum of Pairs (periods) with positive result (win): 22138.363636493683
#
# Number of Pairs (periods) with negative result (lost): 1014
# Sum of Pairs (periods) with negative result (lost): -6626.873503684998
#
# ------------------------------------------------------
# Length of period: 69
# Number of all Buy/Sell Pairs (periods): 3704
# Sum of all Buy/Sell Pairs (periods): 15730.16719865799
# Number of investments: 3704
# Sum of investments: 238401.66696548462
#
# Number of Pairs (periods) with positive result (win): 2713
# Sum of Pairs (periods) with positive result (win): 22330.37012720108
#
# Number of Pairs (periods) with negative result (lost): 991
# Sum of Pairs (periods) with negative result (lost): -6600.202928543091
#
# ------------------------------------------------------
# Length of period: 70
# Number of all Buy/Sell Pairs (periods): 3703
# Sum of all Buy/Sell Pairs (periods): 15950.472354412079
# Number of investments: 3703
# Sum of investments: 238173.96811294556
#
# Number of Pairs (periods) with positive result (win): 2709
# Sum of Pairs (periods) with positive result (win): 22520.584660053253
#
# Number of Pairs (periods) with negative result (lost): 994
# Sum of Pairs (periods) with negative result (lost): -6570.112305641174
#
# ------------------------------------------------------
# Length of period: 71
# Number of all Buy/Sell Pairs (periods): 3702
# Sum of all Buy/Sell Pairs (periods): 16171.348840713501
# Number of investments: 3702
# Sum of investments: 237945.6007270813
#
# Number of Pairs (periods) with positive result (win): 2709
# Sum of Pairs (periods) with positive result (win): 22713.44702386856
#
# Number of Pairs (periods) with negative result (lost): 993
# Sum of Pairs (periods) with negative result (lost): -6542.09818315506
#
# ------------------------------------------------------
# Length of period: 72
# Number of all Buy/Sell Pairs (periods): 3701
# Sum of all Buy/Sell Pairs (periods): 16384.109039783478
# Number of investments: 3701
# Sum of investments: 237725.3953742981
#
# Number of Pairs (periods) with positive result (win): 2715
# Sum of Pairs (periods) with positive result (win): 22894.87319469452
#
# Number of Pairs (periods) with negative result (lost): 986
# Sum of Pairs (periods) with negative result (lost): -6510.764154911041
#
# ------------------------------------------------------
# Length of period: 73
# Number of all Buy/Sell Pairs (periods): 3700
# Sum of all Buy/Sell Pairs (periods): 16592.987718105316
# Number of investments: 3700
# Sum of investments: 237509.0814704895
#
# Number of Pairs (periods) with positive result (win): 2714
# Sum of Pairs (periods) with positive result (win): 23080.370352745056
#
# Number of Pairs (periods) with negative result (lost): 986
# Sum of Pairs (periods) with negative result (lost): -6487.38263463974
#
# ------------------------------------------------------
# Length of period: 74
# Number of all Buy/Sell Pairs (periods): 3699
# Sum of all Buy/Sell Pairs (periods): 16801.472081661224
# Number of investments: 3699
# Sum of investments: 237293.23651504517
#
# Number of Pairs (periods) with positive result (win): 2715
# Sum of Pairs (periods) with positive result (win): 23243.48169517517
#
# Number of Pairs (periods) with negative result (lost): 984
# Sum of Pairs (periods) with negative result (lost): -6442.0096135139465
#
# ------------------------------------------------------
# Length of period: 75
# Number of all Buy/Sell Pairs (periods): 3698
# Sum of all Buy/Sell Pairs (periods): 17015.68259859085
# Number of investments: 3698
# Sum of investments: 237071.22513198853
#
# Number of Pairs (periods) with positive result (win): 2720
# Sum of Pairs (periods) with positive result (win): 23446.122662067413
#
# Number of Pairs (periods) with negative result (lost): 978
# Sum of Pairs (periods) with negative result (lost): -6430.4400634765625
#
# ------------------------------------------------------
# Length of period: 76
# Number of all Buy/Sell Pairs (periods): 3697
# Sum of all Buy/Sell Pairs (periods): 17229.94433259964
# Number of investments: 3697
# Sum of investments: 236848.944355011
#
# Number of Pairs (periods) with positive result (win): 2721
# Sum of Pairs (periods) with positive result (win): 23651.58467245102
#
# Number of Pairs (periods) with negative result (lost): 976
# Sum of Pairs (periods) with negative result (lost): -6421.640339851379
#
# ------------------------------------------------------
# Length of period: 77
# Number of all Buy/Sell Pairs (periods): 3696
# Sum of all Buy/Sell Pairs (periods): 17443.965104579926
# Number of investments: 3696
# Sum of investments: 236626.77333450317
#
# Number of Pairs (periods) with positive result (win): 2719
# Sum of Pairs (periods) with positive result (win): 23845.843026161194
#
# Number of Pairs (periods) with negative result (lost): 977
# Sum of Pairs (periods) with negative result (lost): -6401.877921581268
#
# ------------------------------------------------------
# Length of period: 78
# Number of all Buy/Sell Pairs (periods): 3695
# Sum of all Buy/Sell Pairs (periods): 17655.481514453888
# Number of investments: 3695
# Sum of investments: 236407.14670181274
#
# Number of Pairs (periods) with positive result (win): 2711
# Sum of Pairs (periods) with positive result (win): 24041.525372505188
#
# Number of Pairs (periods) with negative result (lost): 984
# Sum of Pairs (periods) with negative result (lost): -6386.0438580513
#
# ------------------------------------------------------
# Length of period: 79
# Number of all Buy/Sell Pairs (periods): 3694
# Sum of all Buy/Sell Pairs (periods): 17868.020655155182
# Number of investments: 3694
# Sum of investments: 236186.7218360901
#
# Number of Pairs (periods) with positive result (win): 2723
# Sum of Pairs (periods) with positive result (win): 24232.05162668228
#
# Number of Pairs (periods) with negative result (lost): 971
# Sum of Pairs (periods) with negative result (lost): -6364.0309715271
#
# ------------------------------------------------------
# Length of period: 80
# Number of all Buy/Sell Pairs (periods): 3693
# Sum of all Buy/Sell Pairs (periods): 18080.483255386353
# Number of investments: 3693
# Sum of investments: 235966.38675308228
#
# Number of Pairs (periods) with positive result (win): 2716
# Sum of Pairs (periods) with positive result (win): 24422.635130405426
#
# Number of Pairs (periods) with negative result (lost): 977
# Sum of Pairs (periods) with negative result (lost): -6342.1518750190735
#
# ------------------------------------------------------
# Length of period: 81
# Number of all Buy/Sell Pairs (periods): 3692
# Sum of all Buy/Sell Pairs (periods): 18294.290541648865
# Number of investments: 3692
# Sum of investments: 235744.4951210022
#
# Number of Pairs (periods) with positive result (win): 2720
# Sum of Pairs (periods) with positive result (win): 24603.56689453125
#
# Number of Pairs (periods) with negative result (lost): 972
# Sum of Pairs (periods) with negative result (lost): -6309.276352882385
#
# ------------------------------------------------------
# Length of period: 82
# Number of all Buy/Sell Pairs (periods): 3691
# Sum of all Buy/Sell Pairs (periods): 18506.79841041565
# Number of investments: 3691
# Sum of investments: 235524.13011550903
#
# Number of Pairs (periods) with positive result (win): 2725
# Sum of Pairs (periods) with positive result (win): 24815.238329410553
#
# Number of Pairs (periods) with negative result (lost): 966
# Sum of Pairs (periods) with negative result (lost): -6308.439918994904
#
# ------------------------------------------------------
# Length of period: 83
# Number of all Buy/Sell Pairs (periods): 3690
# Sum of all Buy/Sell Pairs (periods): 18721.063755989075
# Number of investments: 3690
# Sum of investments: 235301.8493385315
#
# Number of Pairs (periods) with positive result (win): 2732
# Sum of Pairs (periods) with positive result (win): 25019.010806560516
#
# Number of Pairs (periods) with negative result (lost): 957
# Sum of Pairs (periods) with negative result (lost): -6297.947050571442
#
# ------------------------------------------------------
# Length of period: 84
# Number of all Buy/Sell Pairs (periods): 3689
# Sum of all Buy/Sell Pairs (periods): 18941.77624607086
# Number of investments: 3689
# Sum of investments: 235073.35223770142
#
# Number of Pairs (periods) with positive result (win): 2733
# Sum of Pairs (periods) with positive result (win): 25233.520281791687
#
# Number of Pairs (periods) with negative result (lost): 956
# Sum of Pairs (periods) with negative result (lost): -6291.744035720825
#
# ------------------------------------------------------
# Length of period: 85
# Number of all Buy/Sell Pairs (periods): 3688
# Sum of all Buy/Sell Pairs (periods): 19163.357958316803
# Number of investments: 3688
# Sum of investments: 234844.06686782837
#
# Number of Pairs (periods) with positive result (win): 2728
# Sum of Pairs (periods) with positive result (win): 25444.318986415863
#
# Number of Pairs (periods) with negative result (lost): 960
# Sum of Pairs (periods) with negative result (lost): -6280.96102809906
#
# ------------------------------------------------------
# Length of period: 86
# Number of all Buy/Sell Pairs (periods): 3687
# Sum of all Buy/Sell Pairs (periods): 19381.940024852753
# Number of investments: 3687
# Sum of investments: 234618.07425308228
#
# Number of Pairs (periods) with positive result (win): 2740
# Sum of Pairs (periods) with positive result (win): 25635.22218465805
#
# Number of Pairs (periods) with negative result (lost): 947
# Sum of Pairs (periods) with negative result (lost): -6253.282159805298
#
# ------------------------------------------------------
# Length of period: 87
# Number of all Buy/Sell Pairs (periods): 3686
# Sum of all Buy/Sell Pairs (periods): 19602.37137031555
# Number of investments: 3686
# Sum of investments: 234390.54503250122
#
# Number of Pairs (periods) with positive result (win): 2741
# Sum of Pairs (periods) with positive result (win): 25803.739521980286
#
# Number of Pairs (periods) with negative result (lost): 945
# Sum of Pairs (periods) with negative result (lost): -6201.368151664734
#
# ------------------------------------------------------
# Length of period: 88
# Number of all Buy/Sell Pairs (periods): 3685
# Sum of all Buy/Sell Pairs (periods): 19821.408987522125
# Number of investments: 3685
# Sum of investments: 234163.86394119263
#
# Number of Pairs (periods) with positive result (win): 2738
# Sum of Pairs (periods) with positive result (win): 25977.69767141342
#
# Number of Pairs (periods) with negative result (lost): 947
# Sum of Pairs (periods) with negative result (lost): -6156.288683891296
#
# ------------------------------------------------------
# Length of period: 89
# Number of all Buy/Sell Pairs (periods): 3684
# Sum of all Buy/Sell Pairs (periods): 20040.031220912933
# Number of investments: 3684
# Sum of investments: 233937.52209854126
#
# Number of Pairs (periods) with positive result (win): 2742
# Sum of Pairs (periods) with positive result (win): 26151.341136455536
#
# Number of Pairs (periods) with negative result (lost): 942
# Sum of Pairs (periods) with negative result (lost): -6111.3099155426025
#
# ------------------------------------------------------
# Length of period: 90
# Number of all Buy/Sell Pairs (periods): 3683
# Sum of all Buy/Sell Pairs (periods): 20256.180916309357
# Number of investments: 3683
# Sum of investments: 233713.48517227173
#
# Number of Pairs (periods) with positive result (win): 2761
# Sum of Pairs (periods) with positive result (win): 26341.277733802795
#
# Number of Pairs (periods) with negative result (lost): 922
# Sum of Pairs (periods) with negative result (lost): -6085.096817493439
#
# ------------------------------------------------------
# Length of period: 91
# Number of all Buy/Sell Pairs (periods): 3682
# Sum of all Buy/Sell Pairs (periods): 20474.308738708496
# Number of investments: 3682
# Sum of investments: 233487.58237075806
#
# Number of Pairs (periods) with positive result (win): 2764
# Sum of Pairs (periods) with positive result (win): 26512.57864189148
#
# Number of Pairs (periods) with negative result (lost): 918
# Sum of Pairs (periods) with negative result (lost): -6038.269903182983
#
# ------------------------------------------------------
# Length of period: 92
# Number of all Buy/Sell Pairs (periods): 3681
# Sum of all Buy/Sell Pairs (periods): 20692.682954788208
# Number of investments: 3681
# Sum of investments: 233261.56979751587
#
# Number of Pairs (periods) with positive result (win): 2772
# Sum of Pairs (periods) with positive result (win): 26696.699726104736
#
# Number of Pairs (periods) with negative result (lost): 909
# Sum of Pairs (periods) with negative result (lost): -6004.016771316528
#
# ------------------------------------------------------
# Length of period: 93
# Number of all Buy/Sell Pairs (periods): 3680
# Sum of all Buy/Sell Pairs (periods): 20910.426496505737
# Number of investments: 3680
# Sum of investments: 233036.17586135864
#
# Number of Pairs (periods) with positive result (win): 2770
# Sum of Pairs (periods) with positive result (win): 26905.689925193787
#
# Number of Pairs (periods) with negative result (lost): 910
# Sum of Pairs (periods) with negative result (lost): -5995.263428688049
#
# ------------------------------------------------------
# Length of period: 94
# Number of all Buy/Sell Pairs (periods): 3679
# Sum of all Buy/Sell Pairs (periods): 21128.38566684723
# Number of investments: 3679
# Sum of investments: 232810.62227249146
#
# Number of Pairs (periods) with positive result (win): 2780
# Sum of Pairs (periods) with positive result (win): 27098.145206928253
#
# Number of Pairs (periods) with negative result (lost): 899
# Sum of Pairs (periods) with negative result (lost): -5969.759540081024
#
# ------------------------------------------------------
# Length of period: 95
# Number of all Buy/Sell Pairs (periods): 3678
# Sum of all Buy/Sell Pairs (periods): 21345.138724327087
# Number of investments: 3678
# Sum of investments: 232586.3957710266
#
# Number of Pairs (periods) with positive result (win): 2791
# Sum of Pairs (periods) with positive result (win): 27284.275996685028
#
# Number of Pairs (periods) with negative result (lost): 887
# Sum of Pairs (periods) with negative result (lost): -5939.137272357941
#
# ------------------------------------------------------
# ...
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3740
# Number of all Buy/Sell Pairs (periods): 33
# Sum of all Buy/Sell Pairs (periods): 7760.857372283936
# Number of investments: 33
# Sum of investments: 202.1973762512207
#
# Number of Pairs (periods) with positive result (win): 33
# Sum of Pairs (periods) with positive result (win): 7760.857372283936
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3741
# Number of all Buy/Sell Pairs (periods): 32
# Sum of all Buy/Sell Pairs (periods): 7542.942613124847
# Number of investments: 32
# Sum of investments: 196.12840127944946
#
# Number of Pairs (periods) with positive result (win): 32
# Sum of Pairs (periods) with positive result (win): 7542.942613124847
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3742
# Number of all Buy/Sell Pairs (periods): 31
# Sum of all Buy/Sell Pairs (periods): 7324.176749706268
# Number of investments: 31
# Sum of investments: 190.02150774002075
#
# Number of Pairs (periods) with positive result (win): 31
# Sum of Pairs (periods) with positive result (win): 7324.176749706268
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3743
# Number of all Buy/Sell Pairs (periods): 30
# Sum of all Buy/Sell Pairs (periods): 7102.302849292755
# Number of investments: 30
# Sum of investments: 183.92604780197144
#
# Number of Pairs (periods) with positive result (win): 30
# Sum of Pairs (periods) with positive result (win): 7102.302849292755
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3744
# Number of all Buy/Sell Pairs (periods): 29
# Sum of all Buy/Sell Pairs (periods): 6883.671003818512
# Number of investments: 29
# Sum of investments: 177.8050093650818
#
# Number of Pairs (periods) with positive result (win): 29
# Sum of Pairs (periods) with positive result (win): 6883.671003818512
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3745
# Number of all Buy/Sell Pairs (periods): 28
# Sum of all Buy/Sell Pairs (periods): 6661.931581497192
# Number of investments: 28
# Sum of investments: 171.77485466003418
#
# Number of Pairs (periods) with positive result (win): 28
# Sum of Pairs (periods) with positive result (win): 6661.931581497192
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3746
# Number of all Buy/Sell Pairs (periods): 27
# Sum of all Buy/Sell Pairs (periods): 6439.8809933662415
# Number of investments: 27
# Sum of investments: 165.79616117477417
#
# Number of Pairs (periods) with positive result (win): 27
# Sum of Pairs (periods) with positive result (win): 6439.8809933662415
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3747
# Number of all Buy/Sell Pairs (periods): 26
# Sum of all Buy/Sell Pairs (periods): 6217.0043659210205
# Number of investments: 26
# Sum of investments: 159.9242992401123
#
# Number of Pairs (periods) with positive result (win): 26
# Sum of Pairs (periods) with positive result (win): 6217.0043659210205
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3748
# Number of all Buy/Sell Pairs (periods): 25
# Sum of all Buy/Sell Pairs (periods): 5994.639400482178
# Number of investments: 25
# Sum of investments: 154.02023696899414
#
# Number of Pairs (periods) with positive result (win): 25
# Sum of Pairs (periods) with positive result (win): 5994.639400482178
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3749
# Number of all Buy/Sell Pairs (periods): 24
# Sum of all Buy/Sell Pairs (periods): 5770.863632678986
# Number of investments: 24
# Sum of investments: 148.17846632003784
#
# Number of Pairs (periods) with positive result (win): 24
# Sum of Pairs (periods) with positive result (win): 5770.863632678986
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3750
# Number of all Buy/Sell Pairs (periods): 23
# Sum of all Buy/Sell Pairs (periods): 5544.131482601166
# Number of investments: 23
# Sum of investments: 142.29637384414673
#
# Number of Pairs (periods) with positive result (win): 23
# Sum of Pairs (periods) with positive result (win): 5544.131482601166
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3751
# Number of all Buy/Sell Pairs (periods): 22
# Sum of all Buy/Sell Pairs (periods): 5315.109124183655
# Number of investments: 22
# Sum of investments: 136.5168981552124
#
# Number of Pairs (periods) with positive result (win): 22
# Sum of Pairs (periods) with positive result (win): 5315.109124183655
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3752
# Number of all Buy/Sell Pairs (periods): 21
# Sum of all Buy/Sell Pairs (periods): 5086.432689189911
# Number of investments: 21
# Sum of investments: 130.52135133743286
#
# Number of Pairs (periods) with positive result (win): 21
# Sum of Pairs (periods) with positive result (win): 5086.432689189911
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3753
# Number of all Buy/Sell Pairs (periods): 20
# Sum of all Buy/Sell Pairs (periods): 4855.257471084595
# Number of investments: 20
# Sum of investments: 124.62721824645996
#
# Number of Pairs (periods) with positive result (win): 20
# Sum of Pairs (periods) with positive result (win): 4855.257471084595
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3754
# Number of all Buy/Sell Pairs (periods): 19
# Sum of all Buy/Sell Pairs (periods): 4621.790738582611
# Number of investments: 19
# Sum of investments: 118.76709222793579
#
# Number of Pairs (periods) with positive result (win): 19
# Sum of Pairs (periods) with positive result (win): 4621.790738582611
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3755
# Number of all Buy/Sell Pairs (periods): 18
# Sum of all Buy/Sell Pairs (periods): 4385.18701505661
# Number of investments: 18
# Sum of investments: 112.98731660842896
#
# Number of Pairs (periods) with positive result (win): 18
# Sum of Pairs (periods) with positive result (win): 4385.18701505661
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3756
# Number of all Buy/Sell Pairs (periods): 17
# Sum of all Buy/Sell Pairs (periods): 4148.441265583038
# Number of investments: 17
# Sum of investments: 106.98996305465698
#
# Number of Pairs (periods) with positive result (win): 17
# Sum of Pairs (periods) with positive result (win): 4148.441265583038
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3757
# Number of all Buy/Sell Pairs (periods): 16
# Sum of all Buy/Sell Pairs (periods): 3911.924051761627
# Number of investments: 16
# Sum of investments: 100.73410558700562
#
# Number of Pairs (periods) with positive result (win): 16
# Sum of Pairs (periods) with positive result (win): 3911.924051761627
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3758
# Number of all Buy/Sell Pairs (periods): 15
# Sum of all Buy/Sell Pairs (periods): 3675.5482387542725
# Number of investments: 15
# Sum of investments: 94.53663063049316
#
# Number of Pairs (periods) with positive result (win): 15
# Sum of Pairs (periods) with positive result (win): 3675.5482387542725
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3759
# Number of all Buy/Sell Pairs (periods): 14
# Sum of all Buy/Sell Pairs (periods): 3435.1803426742554
# Number of investments: 14
# Sum of investments: 88.42552280426025
#
# Number of Pairs (periods) with positive result (win): 14
# Sum of Pairs (periods) with positive result (win): 3435.1803426742554
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3760
# Number of all Buy/Sell Pairs (periods): 13
# Sum of all Buy/Sell Pairs (periods): 3193.633472919464
# Number of investments: 13
# Sum of investments: 82.4745135307312
#
# Number of Pairs (periods) with positive result (win): 13
# Sum of Pairs (periods) with positive result (win): 3193.633472919464
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3761
# Number of all Buy/Sell Pairs (periods): 12
# Sum of all Buy/Sell Pairs (periods): 2953.6757640838623
# Number of investments: 12
# Sum of investments: 76.21293830871582
#
# Number of Pairs (periods) with positive result (win): 12
# Sum of Pairs (periods) with positive result (win): 2953.6757640838623
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3762
# Number of all Buy/Sell Pairs (periods): 11
# Sum of all Buy/Sell Pairs (periods): 2712.3597984313965
# Number of investments: 11
# Sum of investments: 69.84122085571289
#
# Number of Pairs (periods) with positive result (win): 11
# Sum of Pairs (periods) with positive result (win): 2712.3597984313965
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3763
# Number of all Buy/Sell Pairs (periods): 10
# Sum of all Buy/Sell Pairs (periods): 2470.973641872406
# Number of investments: 10
# Sum of investments: 63.36989450454712
#
# Number of Pairs (periods) with positive result (win): 10
# Sum of Pairs (periods) with positive result (win): 2470.973641872406
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3764
# Number of all Buy/Sell Pairs (periods): 9
# Sum of all Buy/Sell Pairs (periods): 2226.4065351486206
# Number of investments: 9
# Sum of investments: 57.17271900177002
#
# Number of Pairs (periods) with positive result (win): 9
# Sum of Pairs (periods) with positive result (win): 2226.4065351486206
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3765
# Number of all Buy/Sell Pairs (periods): 8
# Sum of all Buy/Sell Pairs (periods): 1979.507435798645
# Number of investments: 8
# Sum of investments: 50.870219230651855
#
# Number of Pairs (periods) with positive result (win): 8
# Sum of Pairs (periods) with positive result (win): 1979.507435798645
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3766
# Number of all Buy/Sell Pairs (periods): 7
# Sum of all Buy/Sell Pairs (periods): 1738.0690808296204
# Number of investments: 7
# Sum of investments: 44.531001567840576
#
# Number of Pairs (periods) with positive result (win): 7
# Sum of Pairs (periods) with positive result (win): 1738.0690808296204
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3767
# Number of all Buy/Sell Pairs (periods): 6
# Sum of all Buy/Sell Pairs (periods): 1494.8044667243958
# Number of investments: 6
# Sum of investments: 38.27996015548706
#
# Number of Pairs (periods) with positive result (win): 6
# Sum of Pairs (periods) with positive result (win): 1494.8044667243958
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3768
# Number of all Buy/Sell Pairs (periods): 5
# Sum of all Buy/Sell Pairs (periods): 1246.9169220924377
# Number of investments: 5
# Sum of investments: 31.95699453353882
#
# Number of Pairs (periods) with positive result (win): 5
# Sum of Pairs (periods) with positive result (win): 1246.9169220924377
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3769
# Number of all Buy/Sell Pairs (periods): 4
# Sum of all Buy/Sell Pairs (periods): 998.3065090179443
# Number of investments: 4
# Sum of investments: 25.5777530670166
#
# Number of Pairs (periods) with positive result (win): 4
# Sum of Pairs (periods) with positive result (win): 998.3065090179443
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3770
# Number of all Buy/Sell Pairs (periods): 3
# Sum of all Buy/Sell Pairs (periods): 746.7271747589111
# Number of investments: 3
# Sum of investments: 19.240644454956055
#
# Number of Pairs (periods) with positive result (win): 3
# Sum of Pairs (periods) with positive result (win): 746.7271747589111
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3771
# Number of all Buy/Sell Pairs (periods): 2
# Sum of all Buy/Sell Pairs (periods): 494.340518951416
# Number of investments: 2
# Sum of investments: 12.891796112060547
#
# Number of Pairs (periods) with positive result (win): 2
# Sum of Pairs (periods) with positive result (win): 494.340518951416
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 3772
# Number of all Buy/Sell Pairs (periods): 1
# Sum of all Buy/Sell Pairs (periods): 245.48268842697144
# Number of investments: 1
# Sum of investments: 6.440330982208252
#
# Number of Pairs (periods) with positive result (win): 1
# Sum of Pairs (periods) with positive result (win): 245.48268842697144
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# Creating the plot
plt.plot(period_lengths, corresponding_results)

# Adding title and labels
plt.title("Result vs. period length")
plt.xlabel("Length of Stay in Market")
plt.ylabel("Result")

# Enabling grid
plt.grid(True)

# Finding the maximum y value and its corresponding x
max_y = max(corresponding_results)
max_x = period_lengths[corresponding_results.index(max_y)]

# Plotting the maximum y value
plt.plot(max_x, max_y, 'ro')  # 'ro' stands for red circle marker

# Annotating the maximum y value and corresponding x value
plt.annotate(f'Max y = {max_y} at x = {max_x}', 
             (max_x, max_y), 
             textcoords="offset points", 
             xytext=(0, 10), 
             ha='center')

# Display the plot
plt.show()

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=max_x)

print(f"Period length (stay in market): {max_x}")
print(f"Max Result: {max_y}")
print()

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Period length (stay in market): 1879
# Max Result: 185094.20447540283
#
# Number of all Buy/Sell Pairs (periods): 1894
# Sum of all Buy/Sell Pairs (periods): 185094.20447540283
# Number of investments: 1894
# Sum of investments: 34994.512062072754
#
# Number of Pairs (periods) with positive result (win): 1894
# Sum of Pairs (periods) with positive result (win): 185094.20447540283
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0

# %%
total_investement = sum(investments)

share_return = round((max_y/total_investement) * 100, 2) 

print("Invested: ", total_investement)
print("Lost/Win: ", max_y)
print(f"Share Return: {share_return} %")
# Out:
# Invested:  34994.512062072754
# Lost/Win:  185094.20447540283
# Share Return: 528.92 %

# %%
buy_price_at_start = stock_close_prices.values[0][0]
bought_shares = total_investement/buy_price_at_start
sell_price_at_end = stock_close_prices.values[len(stock_close_prices)-1][0]
profit = (bought_shares*sell_price_at_end) - (bought_shares*buy_price_at_start)

print("One-time Investment: ", total_investement)
print("One-time Investment - Lost/Win: ", profit)
print(f"One-time Investment Share Return: {(profit/total_investement) * 100} %")
# Out:
# One-time Investment:  34994.512062072754
# One-time Investment - Lost/Win:  1333867.3004414728
# One-time Investment Share Return: 3811.647089336404 %
