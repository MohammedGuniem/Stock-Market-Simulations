# %%
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
# Download historical stock data for a specific ticker
ticker = 'AAPL'

stock_data = yf.download(ticker, start='2020-01-01', end='2024-12-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
display(stock_data)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.716072   72.776598   71.466812   71.721019  135480400
# 2020-01-03   72.009109   72.771737   71.783954   71.941321  146322800
# 2020-01-06   72.582893   72.621631   70.876060   71.127851  118387200
# 2020-01-07   72.241539   72.849216   72.021223   72.592586  108872000
# 2020-01-08   73.403648   73.706279   71.943759   71.943759  132079200
# ...                ...         ...         ...         ...        ...
# 2024-12-23  254.989655  255.369227  253.171646  254.490204   40858800
# 2024-12-24  257.916443  257.926411  255.009620  255.209412   23234700
# 2024-12-26  258.735504  259.814335  257.347047  257.906429   27237100
# 2024-12-27  255.309296  258.415896  252.782075  257.546826   42355300
# 2024-12-30  251.923019  253.221595  250.474615  251.952985   35557500
#
# [1257 rows x 5 columns]

# %%
print("Number of open trading days in market: ", len(stock_data))
# Out:
# Number of open trading days in market:  1257

# %%
stock_close_prices = stock_data['Close']

# %%
def evaluate_trade_period(prices, period_length):
    investments = []
    prices_values = stock_close_prices.values
    if period_length >= len(prices) or period_length <= 0:
        raise ValueError("period_length should be less than len(prices) and bigger than 0")
        
    result_list = []
    for i in range(0, len(prices_values)-period_length, 1):
        buy_price = prices_values[i][0]
        investments.append(buy_price)
        sell_price = prices_values[i+period_length][0]
        result_list.append(float(sell_price-buy_price))
        
    return np.array(result_list), np.array(investments)

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=1)

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Number of all Buy/Sell Pairs (periods): 1256
# Sum of all Buy/Sell Pairs (periods): 179.20694732666016
# Number of investments: 1256
# Sum of investments: 190937.3928718567
#
# Number of Pairs (periods) with positive result (win): 670
# Sum of Pairs (periods) with positive result (win): 1331.885196685791
#
# Number of Pairs (periods) with negative result (lost): 582
# Sum of Pairs (periods) with negative result (lost): -1152.6782493591309

# %%
period_lengths, corresponding_results = [], []
for i in range(1, len(stock_close_prices), 1):
    result_list, investments = evaluate_trade_period(stock_close_prices, period_length=i)
    period_lengths.append(i)
    corresponding_results.append(sum(result_list))

    print(f"Length of period: {i}")
    print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
    print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
    print(f"Number of investments: {len(investments)}")
    print(f"Sum of investments: {sum(investments)}")
    print()
    
    positive_results = result_list[result_list > 0]
    print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
    print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
    print()
    
    negative_results = result_list[result_list < 0]
    print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
    print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
    print()
    print("------------------------------------------------------")
# Out:
# Length of period: 1
# Number of all Buy/Sell Pairs (periods): 1256
# Sum of all Buy/Sell Pairs (periods): 179.20694732666016
# Number of investments: 1256
# Sum of investments: 190937.3928718567
#
# Number of Pairs (periods) with positive result (win): 670
# Sum of Pairs (periods) with positive result (win): 1331.885196685791
#
# Number of Pairs (periods) with negative result (lost): 582
# Sum of Pairs (periods) with negative result (lost): -1152.6782493591309
#
# ------------------------------------------------------
# Length of period: 2
# Number of all Buy/Sell Pairs (periods): 1255
# Sum of all Buy/Sell Pairs (periods): 362.5071334838867
# Number of investments: 1255
# Sum of investments: 190682.0835762024
#
# Number of Pairs (periods) with positive result (win): 680
# Sum of Pairs (periods) with positive result (win): 1963.5662727355957
#
# Number of Pairs (periods) with negative result (lost): 575
# Sum of Pairs (periods) with negative result (lost): -1601.059139251709
#
# ------------------------------------------------------
# Length of period: 3
# Number of all Buy/Sell Pairs (periods): 1254
# Sum of all Buy/Sell Pairs (periods): 548.6597442626953
# Number of investments: 1254
# Sum of investments: 190423.348072052
#
# Number of Pairs (periods) with positive result (win): 711
# Sum of Pairs (periods) with positive result (win): 2445.863739013672
#
# Number of Pairs (periods) with negative result (lost): 539
# Sum of Pairs (periods) with negative result (lost): -1897.2039947509766
#
# ------------------------------------------------------
# Length of period: 4
# Number of all Buy/Sell Pairs (periods): 1253
# Sum of all Buy/Sell Pairs (periods): 734.3346481323242
# Number of investments: 1253
# Sum of investments: 190165.4316291809
#
# Number of Pairs (periods) with positive result (win): 707
# Sum of Pairs (periods) with positive result (win): 2871.9227714538574
#
# Number of Pairs (periods) with negative result (lost): 545
# Sum of Pairs (periods) with negative result (lost): -2137.588123321533
#
# ------------------------------------------------------
# Length of period: 5
# Number of all Buy/Sell Pairs (periods): 1252
# Sum of all Buy/Sell Pairs (periods): 915.920654296875
# Number of investments: 1252
# Sum of investments: 189910.4419746399
#
# Number of Pairs (periods) with positive result (win): 722
# Sum of Pairs (periods) with positive result (win): 3280.5885848999023
#
# Number of Pairs (periods) with negative result (lost): 530
# Sum of Pairs (periods) with negative result (lost): -2364.6679306030273
#
# ------------------------------------------------------
# Length of period: 6
# Number of all Buy/Sell Pairs (periods): 1251
# Sum of all Buy/Sell Pairs (periods): 1095.1683654785156
# Number of investments: 1251
# Sum of investments: 189656.231464386
#
# Number of Pairs (periods) with positive result (win): 726
# Sum of Pairs (periods) with positive result (win): 3648.4376335144043
#
# Number of Pairs (periods) with negative result (lost): 525
# Sum of Pairs (periods) with negative result (lost): -2553.2692680358887
#
# ------------------------------------------------------
# Length of period: 7
# Number of all Buy/Sell Pairs (periods): 1250
# Sum of all Buy/Sell Pairs (periods): 1269.5517501831055
# Number of investments: 1250
# Sum of investments: 189406.7158088684
#
# Number of Pairs (periods) with positive result (win): 739
# Sum of Pairs (periods) with positive result (win): 4011.7583923339844
#
# Number of Pairs (periods) with negative result (lost): 510
# Sum of Pairs (periods) with negative result (lost): -2742.206642150879
#
# ------------------------------------------------------
# Length of period: 8
# Number of all Buy/Sell Pairs (periods): 1249
# Sum of all Buy/Sell Pairs (periods): 1440.5918807983398
# Number of investments: 1249
# Sum of investments: 189158.93823623657
#
# Number of Pairs (periods) with positive result (win): 722
# Sum of Pairs (periods) with positive result (win): 4379.226848602295
#
# Number of Pairs (periods) with negative result (lost): 527
# Sum of Pairs (periods) with negative result (lost): -2938.634967803955
#
# ------------------------------------------------------
# Length of period: 9
# Number of all Buy/Sell Pairs (periods): 1248
# Sum of all Buy/Sell Pairs (periods): 1618.0922622680664
# Number of investments: 1248
# Sum of investments: 188905.73663711548
#
# Number of Pairs (periods) with positive result (win): 728
# Sum of Pairs (periods) with positive result (win): 4722.76265335083
#
# Number of Pairs (periods) with negative result (lost): 520
# Sum of Pairs (periods) with negative result (lost): -3104.6703910827637
#
# ------------------------------------------------------
# Length of period: 10
# Number of all Buy/Sell Pairs (periods): 1247
# Sum of all Buy/Sell Pairs (periods): 1793.479736328125
# Number of investments: 1247
# Sum of investments: 188654.97235488892
#
# Number of Pairs (periods) with positive result (win): 751
# Sum of Pairs (periods) with positive result (win): 5045.910430908203
#
# Number of Pairs (periods) with negative result (lost): 496
# Sum of Pairs (periods) with negative result (lost): -3252.430694580078
#
# ------------------------------------------------------
# Length of period: 11
# Number of all Buy/Sell Pairs (periods): 1246
# Sum of all Buy/Sell Pairs (periods): 1965.016212463379
# Number of investments: 1246
# Sum of investments: 188407.11487197876
#
# Number of Pairs (periods) with positive result (win): 750
# Sum of Pairs (periods) with positive result (win): 5367.045970916748
#
# Number of Pairs (periods) with negative result (lost): 496
# Sum of Pairs (periods) with negative result (lost): -3402.029758453369
#
# ------------------------------------------------------
# Length of period: 12
# Number of all Buy/Sell Pairs (periods): 1245
# Sum of all Buy/Sell Pairs (periods): 2135.537956237793
# Number of investments: 1245
# Sum of investments: 188159.4271888733
#
# Number of Pairs (periods) with positive result (win): 752
# Sum of Pairs (periods) with positive result (win): 5675.501865386963
#
# Number of Pairs (periods) with negative result (lost): 491
# Sum of Pairs (periods) with negative result (lost): -3539.96390914917
#
# ------------------------------------------------------
# Length of period: 13
# Number of all Buy/Sell Pairs (periods): 1244
# Sum of all Buy/Sell Pairs (periods): 2305.114242553711
# Number of investments: 1244
# Sum of investments: 187913.20790481567
#
# Number of Pairs (periods) with positive result (win): 757
# Sum of Pairs (periods) with positive result (win): 5947.114952087402
#
# Number of Pairs (periods) with negative result (lost): 487
# Sum of Pairs (periods) with negative result (lost): -3642.0007095336914
#
# ------------------------------------------------------
# Length of period: 14
# Number of all Buy/Sell Pairs (periods): 1243
# Sum of all Buy/Sell Pairs (periods): 2475.695541381836
# Number of investments: 1243
# Sum of investments: 187665.71002578735
#
# Number of Pairs (periods) with positive result (win): 762
# Sum of Pairs (periods) with positive result (win): 6203.077980041504
#
# Number of Pairs (periods) with negative result (lost): 480
# Sum of Pairs (periods) with negative result (lost): -3727.382438659668
#
# ------------------------------------------------------
# Length of period: 15
# Number of all Buy/Sell Pairs (periods): 1242
# Sum of all Buy/Sell Pairs (periods): 2644.8875427246094
# Number of investments: 1242
# Sum of investments: 187419.2310218811
#
# Number of Pairs (periods) with positive result (win): 767
# Sum of Pairs (periods) with positive result (win): 6468.87935256958
#
# Number of Pairs (periods) with negative result (lost): 475
# Sum of Pairs (periods) with negative result (lost): -3823.9918098449707
#
# ------------------------------------------------------
# Length of period: 16
# Number of all Buy/Sell Pairs (periods): 1241
# Sum of all Buy/Sell Pairs (periods): 2810.39656829834
# Number of investments: 1241
# Sum of investments: 187176.65773391724
#
# Number of Pairs (periods) with positive result (win): 775
# Sum of Pairs (periods) with positive result (win): 6723.670375823975
#
# Number of Pairs (periods) with negative result (lost): 466
# Sum of Pairs (periods) with negative result (lost): -3913.2738075256348
#
# ------------------------------------------------------
# Length of period: 17
# Number of all Buy/Sell Pairs (periods): 1240
# Sum of all Buy/Sell Pairs (periods): 2978.3714752197266
# Number of investments: 1240
# Sum of investments: 186933.88466262817
#
# Number of Pairs (periods) with positive result (win): 772
# Sum of Pairs (periods) with positive result (win): 6994.022274017334
#
# Number of Pairs (periods) with negative result (lost): 468
# Sum of Pairs (periods) with negative result (lost): -4015.6507987976074
#
# ------------------------------------------------------
# Length of period: 18
# Number of all Buy/Sell Pairs (periods): 1239
# Sum of all Buy/Sell Pairs (periods): 3144.200424194336
# Number of investments: 1239
# Sum of investments: 186691.14155960083
#
# Number of Pairs (periods) with positive result (win): 766
# Sum of Pairs (periods) with positive result (win): 7198.066150665283
#
# Number of Pairs (periods) with negative result (lost): 473
# Sum of Pairs (periods) with negative result (lost): -4053.8657264709473
#
# ------------------------------------------------------
# Length of period: 19
# Number of all Buy/Sell Pairs (periods): 1238
# Sum of all Buy/Sell Pairs (periods): 3308.0597534179688
# Number of investments: 1238
# Sum of investments: 186448.75806045532
#
# Number of Pairs (periods) with positive result (win): 774
# Sum of Pairs (periods) with positive result (win): 7415.859470367432
#
# Number of Pairs (periods) with negative result (lost): 464
# Sum of Pairs (periods) with negative result (lost): -4107.799716949463
#
# ------------------------------------------------------
# Length of period: 20
# Number of all Buy/Sell Pairs (periods): 1237
# Sum of all Buy/Sell Pairs (periods): 3468.976249694824
# Number of investments: 1237
# Sum of investments: 186209.4312019348
#
# Number of Pairs (periods) with positive result (win): 775
# Sum of Pairs (periods) with positive result (win): 7620.614696502686
#
# Number of Pairs (periods) with negative result (lost): 462
# Sum of Pairs (periods) with negative result (lost): -4151.638446807861
#
# ------------------------------------------------------
# Length of period: 21
# Number of all Buy/Sell Pairs (periods): 1236
# Sum of all Buy/Sell Pairs (periods): 3631.1118545532227
# Number of investments: 1236
# Sum of investments: 185972.36185073853
#
# Number of Pairs (periods) with positive result (win): 769
# Sum of Pairs (periods) with positive result (win): 7859.143672943115
#
# Number of Pairs (periods) with negative result (lost): 467
# Sum of Pairs (periods) with negative result (lost): -4228.031818389893
#
# ------------------------------------------------------
# Length of period: 22
# Number of all Buy/Sell Pairs (periods): 1235
# Sum of all Buy/Sell Pairs (periods): 3791.055892944336
# Number of investments: 1235
# Sum of investments: 185737.689868927
#
# Number of Pairs (periods) with positive result (win): 758
# Sum of Pairs (periods) with positive result (win): 8097.409687042236
#
# Number of Pairs (periods) with negative result (lost): 477
# Sum of Pairs (periods) with negative result (lost): -4306.3537940979
#
# ------------------------------------------------------
# Length of period: 23
# Number of all Buy/Sell Pairs (periods): 1234
# Sum of all Buy/Sell Pairs (periods): 3948.662727355957
# Number of investments: 1234
# Sum of investments: 185502.88803482056
#
# Number of Pairs (periods) with positive result (win): 761
# Sum of Pairs (periods) with positive result (win): 8343.705486297607
#
# Number of Pairs (periods) with negative result (lost): 472
# Sum of Pairs (periods) with negative result (lost): -4395.04275894165
#
# ------------------------------------------------------
# Length of period: 24
# Number of all Buy/Sell Pairs (periods): 1233
# Sum of all Buy/Sell Pairs (periods): 4103.452491760254
# Number of investments: 1233
# Sum of investments: 185270.27379226685
#
# Number of Pairs (periods) with positive result (win): 753
# Sum of Pairs (periods) with positive result (win): 8561.821384429932
#
# Number of Pairs (periods) with negative result (lost): 480
# Sum of Pairs (periods) with negative result (lost): -4458.368892669678
#
# ------------------------------------------------------
# Length of period: 25
# Number of all Buy/Sell Pairs (periods): 1232
# Sum of all Buy/Sell Pairs (periods): 4254.335258483887
# Number of investments: 1232
# Sum of investments: 185040.6562538147
#
# Number of Pairs (periods) with positive result (win): 747
# Sum of Pairs (periods) with positive result (win): 8737.283351898193
#
# Number of Pairs (periods) with negative result (lost): 485
# Sum of Pairs (periods) with negative result (lost): -4482.948093414307
#
# ------------------------------------------------------
# Length of period: 26
# Number of all Buy/Sell Pairs (periods): 1231
# Sum of all Buy/Sell Pairs (periods): 4404.9397048950195
# Number of investments: 1231
# Sum of investments: 184812.38722610474
#
# Number of Pairs (periods) with positive result (win): 754
# Sum of Pairs (periods) with positive result (win): 8904.013118743896
#
# Number of Pairs (periods) with negative result (lost): 477
# Sum of Pairs (periods) with negative result (lost): -4499.073413848877
#
# ------------------------------------------------------
# Length of period: 27
# Number of all Buy/Sell Pairs (periods): 1230
# Sum of all Buy/Sell Pairs (periods): 4555.654754638672
# Number of investments: 1230
# Sum of investments: 184583.63873672485
#
# Number of Pairs (periods) with positive result (win): 745
# Sum of Pairs (periods) with positive result (win): 9063.209331512451
#
# Number of Pairs (periods) with negative result (lost): 485
# Sum of Pairs (periods) with negative result (lost): -4507.554576873779
#
# ------------------------------------------------------
# Length of period: 28
# Number of all Buy/Sell Pairs (periods): 1229
# Sum of all Buy/Sell Pairs (periods): 4706.121391296387
# Number of investments: 1229
# Sum of investments: 184355.60945510864
#
# Number of Pairs (periods) with positive result (win): 740
# Sum of Pairs (periods) with positive result (win): 9236.323230743408
#
# Number of Pairs (periods) with negative result (lost): 489
# Sum of Pairs (periods) with negative result (lost): -4530.2018394470215
#
# ------------------------------------------------------
# Length of period: 29
# Number of all Buy/Sell Pairs (periods): 1228
# Sum of all Buy/Sell Pairs (periods): 4854.486389160156
# Number of investments: 1228
# Sum of investments: 184127.83987808228
#
# Number of Pairs (periods) with positive result (win): 745
# Sum of Pairs (periods) with positive result (win): 9412.674556732178
#
# Number of Pairs (periods) with negative result (lost): 483
# Sum of Pairs (periods) with negative result (lost): -4558.1881675720215
#
# ------------------------------------------------------
# Length of period: 30
# Number of all Buy/Sell Pairs (periods): 1227
# Sum of all Buy/Sell Pairs (periods): 5000.4001388549805
# Number of investments: 1227
# Sum of investments: 183903.08699417114
#
# Number of Pairs (periods) with positive result (win): 741
# Sum of Pairs (periods) with positive result (win): 9613.977924346924
#
# Number of Pairs (periods) with negative result (lost): 486
# Sum of Pairs (periods) with negative result (lost): -4613.577785491943
#
# ------------------------------------------------------
# Length of period: 31
# Number of all Buy/Sell Pairs (periods): 1226
# Sum of all Buy/Sell Pairs (periods): 5149.510948181152
# Number of investments: 1226
# Sum of investments: 183675.11763381958
#
# Number of Pairs (periods) with positive result (win): 739
# Sum of Pairs (periods) with positive result (win): 9803.679775238037
#
# Number of Pairs (periods) with negative result (lost): 487
# Sum of Pairs (periods) with negative result (lost): -4654.168827056885
#
# ------------------------------------------------------
# Length of period: 32
# Number of all Buy/Sell Pairs (periods): 1225
# Sum of all Buy/Sell Pairs (periods): 5296.969100952148
# Number of investments: 1225
# Sum of investments: 183450.24487686157
#
# Number of Pairs (periods) with positive result (win): 748
# Sum of Pairs (periods) with positive result (win): 9996.185527801514
#
# Number of Pairs (periods) with negative result (lost): 477
# Sum of Pairs (periods) with negative result (lost): -4699.216426849365
#
# ------------------------------------------------------
# Length of period: 33
# Number of all Buy/Sell Pairs (periods): 1224
# Sum of all Buy/Sell Pairs (periods): 5442.417053222656
# Number of investments: 1224
# Sum of investments: 183226.2611427307
#
# Number of Pairs (periods) with positive result (win): 752
# Sum of Pairs (periods) with positive result (win): 10185.599925994873
#
# Number of Pairs (periods) with negative result (lost): 472
# Sum of Pairs (periods) with negative result (lost): -4743.182872772217
#
# ------------------------------------------------------
# Length of period: 34
# Number of all Buy/Sell Pairs (periods): 1223
# Sum of all Buy/Sell Pairs (periods): 5588.670707702637
# Number of investments: 1223
# Sum of investments: 183002.27740859985
#
# Number of Pairs (periods) with positive result (win): 753
# Sum of Pairs (periods) with positive result (win): 10365.001247406006
#
# Number of Pairs (periods) with negative result (lost): 470
# Sum of Pairs (periods) with negative result (lost): -4776.330539703369
#
# ------------------------------------------------------
# Length of period: 35
# Number of all Buy/Sell Pairs (periods): 1222
# Sum of all Buy/Sell Pairs (periods): 5739.410789489746
# Number of investments: 1222
# Sum of investments: 182775.5666694641
#
# Number of Pairs (periods) with positive result (win): 746
# Sum of Pairs (periods) with positive result (win): 10547.714298248291
#
# Number of Pairs (periods) with negative result (lost): 476
# Sum of Pairs (periods) with negative result (lost): -4808.303508758545
#
# ------------------------------------------------------
# Length of period: 36
# Number of all Buy/Sell Pairs (periods): 1221
# Sum of all Buy/Sell Pairs (periods): 5894.029190063477
# Number of investments: 1221
# Sum of investments: 182548.5862312317
#
# Number of Pairs (periods) with positive result (win): 748
# Sum of Pairs (periods) with positive result (win): 10749.181102752686
#
# Number of Pairs (periods) with negative result (lost): 473
# Sum of Pairs (periods) with negative result (lost): -4855.151912689209
#
# ------------------------------------------------------
# Length of period: 37
# Number of all Buy/Sell Pairs (periods): 1220
# Sum of all Buy/Sell Pairs (periods): 6046.3491134643555
# Number of investments: 1220
# Sum of investments: 182326.3553352356
#
# Number of Pairs (periods) with positive result (win): 758
# Sum of Pairs (periods) with positive result (win): 10935.574871063232
#
# Number of Pairs (periods) with negative result (lost): 462
# Sum of Pairs (periods) with negative result (lost): -4889.225757598877
#
# ------------------------------------------------------
# Length of period: 38
# Number of all Buy/Sell Pairs (periods): 1219
# Sum of all Buy/Sell Pairs (periods): 6198.288391113281
# Number of investments: 1219
# Sum of investments: 182103.3960456848
#
# Number of Pairs (periods) with positive result (win): 774
# Sum of Pairs (periods) with positive result (win): 11135.243000030518
#
# Number of Pairs (periods) with negative result (lost): 445
# Sum of Pairs (periods) with negative result (lost): -4936.954608917236
#
# ------------------------------------------------------
# Length of period: 39
# Number of all Buy/Sell Pairs (periods): 1218
# Sum of all Buy/Sell Pairs (periods): 6353.43327331543
# Number of investments: 1218
# Sum of investments: 181881.8736000061
#
# Number of Pairs (periods) with positive result (win): 772
# Sum of Pairs (periods) with positive result (win): 11326.90871810913
#
# Number of Pairs (periods) with negative result (lost): 446
# Sum of Pairs (periods) with negative result (lost): -4973.475444793701
#
# ------------------------------------------------------
# Length of period: 40
# Number of all Buy/Sell Pairs (periods): 1217
# Sum of all Buy/Sell Pairs (periods): 6509.515007019043
# Number of investments: 1217
# Sum of investments: 181659.4531135559
#
# Number of Pairs (periods) with positive result (win): 762
# Sum of Pairs (periods) with positive result (win): 11511.308139801025
#
# Number of Pairs (periods) with negative result (lost): 455
# Sum of Pairs (periods) with negative result (lost): -5001.793132781982
#
# ------------------------------------------------------
# Length of period: 41
# Number of all Buy/Sell Pairs (periods): 1216
# Sum of all Buy/Sell Pairs (periods): 6662.413993835449
# Number of investments: 1216
# Sum of investments: 181434.0392189026
#
# Number of Pairs (periods) with positive result (win): 776
# Sum of Pairs (periods) with positive result (win): 11673.098430633545
#
# Number of Pairs (periods) with negative result (lost): 439
# Sum of Pairs (periods) with negative result (lost): -5010.684436798096
#
# ------------------------------------------------------
# Length of period: 42
# Number of all Buy/Sell Pairs (periods): 1215
# Sum of all Buy/Sell Pairs (periods): 6821.796783447266
# Number of investments: 1215
# Sum of investments: 181204.44452285767
#
# Number of Pairs (periods) with positive result (win): 767
# Sum of Pairs (periods) with positive result (win): 11846.652240753174
#
# Number of Pairs (periods) with negative result (lost): 448
# Sum of Pairs (periods) with negative result (lost): -5024.855457305908
#
# ------------------------------------------------------
# Length of period: 43
# Number of all Buy/Sell Pairs (periods): 1214
# Sum of all Buy/Sell Pairs (periods): 6981.484977722168
# Number of investments: 1214
# Sum of investments: 180971.2876777649
#
# Number of Pairs (periods) with positive result (win): 757
# Sum of Pairs (periods) with positive result (win): 12043.97360610962
#
# Number of Pairs (periods) with negative result (lost): 457
# Sum of Pairs (periods) with negative result (lost): -5062.488628387451
#
# ------------------------------------------------------
# Length of period: 44
# Number of all Buy/Sell Pairs (periods): 1213
# Sum of all Buy/Sell Pairs (periods): 7143.2868728637695
# Number of investments: 1213
# Sum of investments: 180738.4002418518
#
# Number of Pairs (periods) with positive result (win): 759
# Sum of Pairs (periods) with positive result (win): 12232.786518096924
#
# Number of Pairs (periods) with negative result (lost): 454
# Sum of Pairs (periods) with negative result (lost): -5089.499645233154
#
# ------------------------------------------------------
# Length of period: 45
# Number of all Buy/Sell Pairs (periods): 1212
# Sum of all Buy/Sell Pairs (periods): 7304.047157287598
# Number of investments: 1212
# Sum of investments: 180507.49843215942
#
# Number of Pairs (periods) with positive result (win): 760
# Sum of Pairs (periods) with positive result (win): 12400.681636810303
#
# Number of Pairs (periods) with negative result (lost): 452
# Sum of Pairs (periods) with negative result (lost): -5096.634479522705
#
# ------------------------------------------------------
# Length of period: 46
# Number of all Buy/Sell Pairs (periods): 1211
# Sum of all Buy/Sell Pairs (periods): 7469.516952514648
# Number of investments: 1211
# Sum of investments: 180277.43477249146
#
# Number of Pairs (periods) with positive result (win): 758
# Sum of Pairs (periods) with positive result (win): 12567.860233306885
#
# Number of Pairs (periods) with negative result (lost): 453
# Sum of Pairs (periods) with negative result (lost): -5098.343280792236
#
# ------------------------------------------------------
# Length of period: 47
# Number of all Buy/Sell Pairs (periods): 1210
# Sum of all Buy/Sell Pairs (periods): 7630.524147033691
# Number of investments: 1210
# Sum of investments: 180047.18153762817
#
# Number of Pairs (periods) with positive result (win): 766
# Sum of Pairs (periods) with positive result (win): 12721.525402069092
#
# Number of Pairs (periods) with negative result (lost): 444
# Sum of Pairs (periods) with negative result (lost): -5091.0012550354
#
# ------------------------------------------------------
# Length of period: 48
# Number of all Buy/Sell Pairs (periods): 1209
# Sum of all Buy/Sell Pairs (periods): 7799.025093078613
# Number of investments: 1209
# Sum of investments: 179811.83949661255
#
# Number of Pairs (periods) with positive result (win): 764
# Sum of Pairs (periods) with positive result (win): 12884.636600494385
#
# Number of Pairs (periods) with negative result (lost): 445
# Sum of Pairs (periods) with negative result (lost): -5085.6115074157715
#
# ------------------------------------------------------
# Length of period: 49
# Number of all Buy/Sell Pairs (periods): 1208
# Sum of all Buy/Sell Pairs (periods): 7974.745552062988
# Number of investments: 1208
# Sum of investments: 179575.87881851196
#
# Number of Pairs (periods) with positive result (win): 767
# Sum of Pairs (periods) with positive result (win): 13053.16417312622
#
# Number of Pairs (periods) with negative result (lost): 441
# Sum of Pairs (periods) with negative result (lost): -5078.418621063232
#
# ------------------------------------------------------
# Length of period: 50
# Number of all Buy/Sell Pairs (periods): 1207
# Sum of all Buy/Sell Pairs (periods): 8141.772003173828
# Number of investments: 1207
# Sum of investments: 179341.39488601685
#
# Number of Pairs (periods) with positive result (win): 760
# Sum of Pairs (periods) with positive result (win): 13199.907047271729
#
# Number of Pairs (periods) with negative result (lost): 447
# Sum of Pairs (periods) with negative result (lost): -5058.1350440979
#
# ------------------------------------------------------
# Length of period: 51
# Number of all Buy/Sell Pairs (periods): 1206
# Sum of all Buy/Sell Pairs (periods): 8314.632900238037
# Number of investments: 1206
# Sum of investments: 179109.75470352173
#
# Number of Pairs (periods) with positive result (win): 771
# Sum of Pairs (periods) with positive result (win): 13352.145336151123
#
# Number of Pairs (periods) with negative result (lost): 435
# Sum of Pairs (periods) with negative result (lost): -5037.512435913086
#
# ------------------------------------------------------
# Length of period: 52
# Number of all Buy/Sell Pairs (periods): 1205
# Sum of all Buy/Sell Pairs (periods): 8484.54008102417
# Number of investments: 1205
# Sum of investments: 178878.48370742798
#
# Number of Pairs (periods) with positive result (win): 773
# Sum of Pairs (periods) with positive result (win): 13498.096881866455
#
# Number of Pairs (periods) with negative result (lost): 432
# Sum of Pairs (periods) with negative result (lost): -5013.556800842285
#
# ------------------------------------------------------
# Length of period: 53
# Number of all Buy/Sell Pairs (periods): 1204
# Sum of all Buy/Sell Pairs (periods): 8658.014911651611
# Number of investments: 1204
# Sum of investments: 178645.14725112915
#
# Number of Pairs (periods) with positive result (win): 775
# Sum of Pairs (periods) with positive result (win): 13636.795207977295
#
# Number of Pairs (periods) with negative result (lost): 429
# Sum of Pairs (periods) with negative result (lost): -4978.780296325684
#
# ------------------------------------------------------
# Length of period: 54
# Number of all Buy/Sell Pairs (periods): 1203
# Sum of all Buy/Sell Pairs (periods): 8829.403987884521
# Number of investments: 1203
# Sum of investments: 178414.3551979065
#
# Number of Pairs (periods) with positive result (win): 777
# Sum of Pairs (periods) with positive result (win): 13790.702083587646
#
# Number of Pairs (periods) with negative result (lost): 426
# Sum of Pairs (periods) with negative result (lost): -4961.298095703125
#
# ------------------------------------------------------
# Length of period: 55
# Number of all Buy/Sell Pairs (periods): 1202
# Sum of all Buy/Sell Pairs (periods): 9000.822551727295
# Number of investments: 1202
# Sum of investments: 178187.30490493774
#
# Number of Pairs (periods) with positive result (win): 783
# Sum of Pairs (periods) with positive result (win): 13945.574466705322
#
# Number of Pairs (periods) with negative result (lost): 419
# Sum of Pairs (periods) with negative result (lost): -4944.751914978027
#
# ------------------------------------------------------
# Length of period: 56
# Number of all Buy/Sell Pairs (periods): 1201
# Sum of all Buy/Sell Pairs (periods): 9174.909660339355
# Number of investments: 1201
# Sum of investments: 177958.76790237427
#
# Number of Pairs (periods) with positive result (win): 783
# Sum of Pairs (periods) with positive result (win): 14102.651927947998
#
# Number of Pairs (periods) with negative result (lost): 418
# Sum of Pairs (periods) with negative result (lost): -4927.742267608643
#
# ------------------------------------------------------
# Length of period: 57
# Number of all Buy/Sell Pairs (periods): 1200
# Sum of all Buy/Sell Pairs (periods): 9344.032974243164
# Number of investments: 1200
# Sum of investments: 177729.7319831848
#
# Number of Pairs (periods) with positive result (win): 787
# Sum of Pairs (periods) with positive result (win): 14249.875827789307
#
# Number of Pairs (periods) with negative result (lost): 413
# Sum of Pairs (periods) with negative result (lost): -4905.842853546143
#
# ------------------------------------------------------
# Length of period: 58
# Number of all Buy/Sell Pairs (periods): 1199
# Sum of all Buy/Sell Pairs (periods): 9509.724613189697
# Number of investments: 1199
# Sum of investments: 177504.45778274536
#
# Number of Pairs (periods) with positive result (win): 788
# Sum of Pairs (periods) with positive result (win): 14419.970058441162
#
# Number of Pairs (periods) with negative result (lost): 411
# Sum of Pairs (periods) with negative result (lost): -4910.245445251465
#
# ------------------------------------------------------
# Length of period: 59
# Number of all Buy/Sell Pairs (periods): 1198
# Sum of all Buy/Sell Pairs (periods): 9668.209823608398
# Number of investments: 1198
# Sum of investments: 177283.254611969
#
# Number of Pairs (periods) with positive result (win): 789
# Sum of Pairs (periods) with positive result (win): 14554.647029876709
#
# Number of Pairs (periods) with negative result (lost): 409
# Sum of Pairs (periods) with negative result (lost): -4886.437206268311
#
# ------------------------------------------------------
# Length of period: 60
# Number of all Buy/Sell Pairs (periods): 1197
# Sum of all Buy/Sell Pairs (periods): 9834.390464782715
# Number of investments: 1197
# Sum of investments: 177056.95267105103
#
# Number of Pairs (periods) with positive result (win): 788
# Sum of Pairs (periods) with positive result (win): 14703.947078704834
#
# Number of Pairs (periods) with negative result (lost): 409
# Sum of Pairs (periods) with negative result (lost): -4869.556613922119
#
# ------------------------------------------------------
# Length of period: 61
# Number of all Buy/Sell Pairs (periods): 1196
# Sum of all Buy/Sell Pairs (periods): 9997.727840423584
# Number of investments: 1196
# Sum of investments: 176831.77826309204
#
# Number of Pairs (periods) with positive result (win): 789
# Sum of Pairs (periods) with positive result (win): 14850.99182510376
#
# Number of Pairs (periods) with negative result (lost): 407
# Sum of Pairs (periods) with negative result (lost): -4853.263984680176
#
# ------------------------------------------------------
# Length of period: 62
# Number of all Buy/Sell Pairs (periods): 1195
# Sum of all Buy/Sell Pairs (periods): 10162.29895401001
# Number of investments: 1195
# Sum of investments: 176605.49629592896
#
# Number of Pairs (periods) with positive result (win): 797
# Sum of Pairs (periods) with positive result (win): 14981.200954437256
#
# Number of Pairs (periods) with negative result (lost): 398
# Sum of Pairs (periods) with negative result (lost): -4818.902000427246
#
# ------------------------------------------------------
# Length of period: 63
# Number of all Buy/Sell Pairs (periods): 1194
# Sum of all Buy/Sell Pairs (periods): 10329.548377990723
# Number of investments: 1194
# Sum of investments: 176379.7830696106
#
# Number of Pairs (periods) with positive result (win): 791
# Sum of Pairs (periods) with positive result (win): 15096.346088409424
#
# Number of Pairs (periods) with negative result (lost): 403
# Sum of Pairs (periods) with negative result (lost): -4766.797710418701
#
# ------------------------------------------------------
# Length of period: 64
# Number of all Buy/Sell Pairs (periods): 1193
# Sum of all Buy/Sell Pairs (periods): 10502.597316741943
# Number of investments: 1193
# Sum of investments: 176147.29475784302
#
# Number of Pairs (periods) with positive result (win): 801
# Sum of Pairs (periods) with positive result (win): 15231.102840423584
#
# Number of Pairs (periods) with negative result (lost): 392
# Sum of Pairs (periods) with negative result (lost): -4728.505523681641
#
# ------------------------------------------------------
# Length of period: 65
# Number of all Buy/Sell Pairs (periods): 1192
# Sum of all Buy/Sell Pairs (periods): 10671.301921844482
# Number of investments: 1192
# Sum of investments: 175920.0050086975
#
# Number of Pairs (periods) with positive result (win): 807
# Sum of Pairs (periods) with positive result (win): 15371.700595855713
#
# Number of Pairs (periods) with negative result (lost): 385
# Sum of Pairs (periods) with negative result (lost): -4700.3986740112305
#
# ------------------------------------------------------
# Length of period: 66
# Number of all Buy/Sell Pairs (periods): 1191
# Sum of all Buy/Sell Pairs (periods): 10834.626300811768
# Number of investments: 1191
# Sum of investments: 175692.9846534729
#
# Number of Pairs (periods) with positive result (win): 808
# Sum of Pairs (periods) with positive result (win): 15496.518314361572
#
# Number of Pairs (periods) with negative result (lost): 383
# Sum of Pairs (periods) with negative result (lost): -4661.892013549805
#
# ------------------------------------------------------
# Length of period: 67
# Number of all Buy/Sell Pairs (periods): 1190
# Sum of all Buy/Sell Pairs (periods): 10997.54097366333
# Number of investments: 1190
# Sum of investments: 175467.11177444458
#
# Number of Pairs (periods) with positive result (win): 815
# Sum of Pairs (periods) with positive result (win): 15623.675548553467
#
# Number of Pairs (periods) with negative result (lost): 375
# Sum of Pairs (periods) with negative result (lost): -4626.134574890137
#
# ------------------------------------------------------
# Length of period: 68
# Number of all Buy/Sell Pairs (periods): 1189
# Sum of all Buy/Sell Pairs (periods): 11159.842029571533
# Number of investments: 1189
# Sum of investments: 175240.24109268188
#
# Number of Pairs (periods) with positive result (win): 813
# Sum of Pairs (periods) with positive result (win): 15729.799091339111
#
# Number of Pairs (periods) with negative result (lost): 376
# Sum of Pairs (periods) with negative result (lost): -4569.957061767578
#
# ------------------------------------------------------
# Length of period: 69
# Number of all Buy/Sell Pairs (periods): 1188
# Sum of all Buy/Sell Pairs (periods): 11320.779132843018
# Number of investments: 1188
# Sum of investments: 175014.26843643188
#
# Number of Pairs (periods) with positive result (win): 827
# Sum of Pairs (periods) with positive result (win): 15858.690433502197
#
# Number of Pairs (periods) with negative result (lost): 361
# Sum of Pairs (periods) with negative result (lost): -4537.91130065918
#
# ------------------------------------------------------
# Length of period: 70
# Number of all Buy/Sell Pairs (periods): 1187
# Sum of all Buy/Sell Pairs (periods): 11482.165950775146
# Number of investments: 1187
# Sum of investments: 174786.56958389282
#
# Number of Pairs (periods) with positive result (win): 829
# Sum of Pairs (periods) with positive result (win): 15984.319492340088
#
# Number of Pairs (periods) with negative result (lost): 358
# Sum of Pairs (periods) with negative result (lost): -4502.153541564941
#
# ------------------------------------------------------
# Length of period: 71
# Number of all Buy/Sell Pairs (periods): 1186
# Sum of all Buy/Sell Pairs (periods): 11640.872325897217
# Number of investments: 1186
# Sum of investments: 174558.20219802856
#
# Number of Pairs (periods) with positive result (win): 837
# Sum of Pairs (periods) with positive result (win): 16110.912868499756
#
# Number of Pairs (periods) with negative result (lost): 349
# Sum of Pairs (periods) with negative result (lost): -4470.040542602539
#
# ------------------------------------------------------
# Length of period: 72
# Number of all Buy/Sell Pairs (periods): 1185
# Sum of all Buy/Sell Pairs (periods): 11792.052486419678
# Number of investments: 1185
# Sum of investments: 174337.99684524536
#
# Number of Pairs (periods) with positive result (win): 837
# Sum of Pairs (periods) with positive result (win): 16232.126880645752
#
# Number of Pairs (periods) with negative result (lost): 348
# Sum of Pairs (periods) with negative result (lost): -4440.074394226074
#
# ------------------------------------------------------
# Length of period: 73
# Number of all Buy/Sell Pairs (periods): 1184
# Sum of all Buy/Sell Pairs (periods): 11938.792728424072
# Number of investments: 1184
# Sum of investments: 174121.68294143677
#
# Number of Pairs (periods) with positive result (win): 841
# Sum of Pairs (periods) with positive result (win): 16353.457187652588
#
# Number of Pairs (periods) with negative result (lost): 343
# Sum of Pairs (periods) with negative result (lost): -4414.664459228516
#
# ------------------------------------------------------
# Length of period: 74
# Number of all Buy/Sell Pairs (periods): 1183
# Sum of all Buy/Sell Pairs (periods): 12086.008045196533
# Number of investments: 1183
# Sum of investments: 173905.83798599243
#
# Number of Pairs (periods) with positive result (win): 840
# Sum of Pairs (periods) with positive result (win): 16455.306453704834
#
# Number of Pairs (periods) with negative result (lost): 343
# Sum of Pairs (periods) with negative result (lost): -4369.298408508301
#
# ------------------------------------------------------
# Length of period: 75
# Number of all Buy/Sell Pairs (periods): 1182
# Sum of all Buy/Sell Pairs (periods): 12240.814311981201
# Number of investments: 1182
# Sum of investments: 173683.82661819458
#
# Number of Pairs (periods) with positive result (win): 850
# Sum of Pairs (periods) with positive result (win): 16595.50281906128
#
# Number of Pairs (periods) with negative result (lost): 332
# Sum of Pairs (periods) with negative result (lost): -4354.688507080078
#
# ------------------------------------------------------
# Length of period: 76
# Number of all Buy/Sell Pairs (periods): 1181
# Sum of all Buy/Sell Pairs (periods): 12397.96731185913
# Number of investments: 1181
# Sum of investments: 173461.54582595825
#
# Number of Pairs (periods) with positive result (win): 852
# Sum of Pairs (periods) with positive result (win): 16740.758373260498
#
# Number of Pairs (periods) with negative result (lost): 329
# Sum of Pairs (periods) with negative result (lost): -4342.791061401367
#
# ------------------------------------------------------
# Length of period: 77
# Number of all Buy/Sell Pairs (periods): 1180
# Sum of all Buy/Sell Pairs (periods): 12553.134662628174
# Number of investments: 1180
# Sum of investments: 173239.37479019165
#
# Number of Pairs (periods) with positive result (win): 854
# Sum of Pairs (periods) with positive result (win): 16871.888355255127
#
# Number of Pairs (periods) with negative result (lost): 326
# Sum of Pairs (periods) with negative result (lost): -4318.753692626953
#
# ------------------------------------------------------
# Length of period: 78
# Number of all Buy/Sell Pairs (periods): 1179
# Sum of all Buy/Sell Pairs (periods): 12706.017276763916
# Number of investments: 1179
# Sum of investments: 173019.74817276
#
# Number of Pairs (periods) with positive result (win): 851
# Sum of Pairs (periods) with positive result (win): 17003.35478591919
#
# Number of Pairs (periods) with negative result (lost): 328
# Sum of Pairs (periods) with negative result (lost): -4297.337509155273
#
# ------------------------------------------------------
# Length of period: 79
# Number of all Buy/Sell Pairs (periods): 1178
# Sum of all Buy/Sell Pairs (periods): 12857.771251678467
# Number of investments: 1178
# Sum of investments: 172799.32329177856
#
# Number of Pairs (periods) with positive result (win): 862
# Sum of Pairs (periods) with positive result (win): 17129.364086151123
#
# Number of Pairs (periods) with negative result (lost): 316
# Sum of Pairs (periods) with negative result (lost): -4271.592834472656
#
# ------------------------------------------------------
# Length of period: 80
# Number of all Buy/Sell Pairs (periods): 1177
# Sum of all Buy/Sell Pairs (periods): 13009.386898040771
# Number of investments: 1177
# Sum of investments: 172578.98822402954
#
# Number of Pairs (periods) with positive result (win): 864
# Sum of Pairs (periods) with positive result (win): 17259.613697052002
#
# Number of Pairs (periods) with negative result (lost): 313
# Sum of Pairs (periods) with negative result (lost): -4250.2267990112305
#
# ------------------------------------------------------
# Length of period: 81
# Number of all Buy/Sell Pairs (periods): 1176
# Sum of all Buy/Sell Pairs (periods): 13163.673030853271
# Number of investments: 1176
# Sum of investments: 172357.09657669067
#
# Number of Pairs (periods) with positive result (win): 863
# Sum of Pairs (periods) with positive result (win): 17381.117458343506
#
# Number of Pairs (periods) with negative result (lost): 313
# Sum of Pairs (periods) with negative result (lost): -4217.444427490234
#
# ------------------------------------------------------
# Length of period: 82
# Number of all Buy/Sell Pairs (periods): 1175
# Sum of all Buy/Sell Pairs (periods): 13314.211994171143
# Number of investments: 1175
# Sum of investments: 172136.7315711975
#
# Number of Pairs (periods) with positive result (win): 858
# Sum of Pairs (periods) with positive result (win): 17529.26704788208
#
# Number of Pairs (periods) with negative result (lost): 317
# Sum of Pairs (periods) with negative result (lost): -4215.0550537109375
#
# ------------------------------------------------------
# Length of period: 83
# Number of all Buy/Sell Pairs (periods): 1174
# Sum of all Buy/Sell Pairs (periods): 13465.193675994873
# Number of investments: 1174
# Sum of investments: 171914.45077896118
#
# Number of Pairs (periods) with positive result (win): 858
# Sum of Pairs (periods) with positive result (win): 17671.95392227173
#
# Number of Pairs (periods) with negative result (lost): 316
# Sum of Pairs (periods) with negative result (lost): -4206.7602462768555
#
# ------------------------------------------------------
# Length of period: 84
# Number of all Buy/Sell Pairs (periods): 1173
# Sum of all Buy/Sell Pairs (periods): 13623.539539337158
# Number of investments: 1173
# Sum of investments: 171685.9536781311
#
# Number of Pairs (periods) with positive result (win): 855
# Sum of Pairs (periods) with positive result (win): 17820.65156173706
#
# Number of Pairs (periods) with negative result (lost): 318
# Sum of Pairs (periods) with negative result (lost): -4197.112022399902
#
# ------------------------------------------------------
# Length of period: 85
# Number of all Buy/Sell Pairs (periods): 1172
# Sum of all Buy/Sell Pairs (periods): 13781.681118011475
# Number of investments: 1172
# Sum of investments: 171456.66830825806
#
# Number of Pairs (periods) with positive result (win): 857
# Sum of Pairs (periods) with positive result (win): 17961.518421173096
#
# Number of Pairs (periods) with negative result (lost): 315
# Sum of Pairs (periods) with negative result (lost): -4179.837303161621
#
# ------------------------------------------------------
# Length of period: 86
# Number of all Buy/Sell Pairs (periods): 1171
# Sum of all Buy/Sell Pairs (periods): 13935.462162017822
# Number of investments: 1171
# Sum of investments: 171230.67569351196
#
# Number of Pairs (periods) with positive result (win): 861
# Sum of Pairs (periods) with positive result (win): 18086.51031112671
#
# Number of Pairs (periods) with negative result (lost): 310
# Sum of Pairs (periods) with negative result (lost): -4151.048149108887
#
# ------------------------------------------------------
# Length of period: 87
# Number of all Buy/Sell Pairs (periods): 1170
# Sum of all Buy/Sell Pairs (periods): 14090.034809112549
# Number of investments: 1170
# Sum of investments: 171003.14645767212
#
# Number of Pairs (periods) with positive result (win): 864
# Sum of Pairs (periods) with positive result (win): 18189.512119293213
#
# Number of Pairs (periods) with negative result (lost): 306
# Sum of Pairs (periods) with negative result (lost): -4099.477310180664
#
# ------------------------------------------------------
# Length of period: 88
# Number of all Buy/Sell Pairs (periods): 1169
# Sum of all Buy/Sell Pairs (periods): 14243.004581451416
# Number of investments: 1169
# Sum of investments: 170776.46536636353
#
# Number of Pairs (periods) with positive result (win): 859
# Sum of Pairs (periods) with positive result (win): 18297.242252349854
#
# Number of Pairs (periods) with negative result (lost): 310
# Sum of Pairs (periods) with negative result (lost): -4054.2376708984375
#
# ------------------------------------------------------
# Length of period: 89
# Number of all Buy/Sell Pairs (periods): 1168
# Sum of all Buy/Sell Pairs (periods): 14393.88064956665
# Number of investments: 1168
# Sum of investments: 170550.12352371216
#
# Number of Pairs (periods) with positive result (win): 866
# Sum of Pairs (periods) with positive result (win): 18405.125186920166
#
# Number of Pairs (periods) with negative result (lost): 302
# Sum of Pairs (periods) with negative result (lost): -4011.2445373535156
#
# ------------------------------------------------------
# Length of period: 90
# Number of all Buy/Sell Pairs (periods): 1167
# Sum of all Buy/Sell Pairs (periods): 14541.264301300049
# Number of investments: 1167
# Sum of investments: 170326.08661270142
#
# Number of Pairs (periods) with positive result (win): 873
# Sum of Pairs (periods) with positive result (win): 18528.31788253784
#
# Number of Pairs (periods) with negative result (lost): 294
# Sum of Pairs (periods) with negative result (lost): -3987.053581237793
#
# ------------------------------------------------------
# Length of period: 91
# Number of all Buy/Sell Pairs (periods): 1166
# Sum of all Buy/Sell Pairs (periods): 14691.38985824585
# Number of investments: 1166
# Sum of investments: 170100.18379592896
#
# Number of Pairs (periods) with positive result (win): 873
# Sum of Pairs (periods) with positive result (win): 18631.25947189331
#
# Number of Pairs (periods) with negative result (lost): 293
# Sum of Pairs (periods) with negative result (lost): -3939.869613647461
#
# ------------------------------------------------------
# Length of period: 92
# Number of all Buy/Sell Pairs (periods): 1165
# Sum of all Buy/Sell Pairs (periods): 14842.540126800537
# Number of investments: 1165
# Sum of investments: 169874.17122268677
#
# Number of Pairs (periods) with positive result (win): 871
# Sum of Pairs (periods) with positive result (win): 18751.86357498169
#
# Number of Pairs (periods) with negative result (lost): 294
# Sum of Pairs (periods) with negative result (lost): -3909.3234481811523
#
# ------------------------------------------------------
# Length of period: 93
# Number of all Buy/Sell Pairs (periods): 1164
# Sum of all Buy/Sell Pairs (periods): 14992.611827850342
# Number of investments: 1164
# Sum of investments: 169648.77730178833
#
# Number of Pairs (periods) with positive result (win): 865
# Sum of Pairs (periods) with positive result (win): 18896.757976531982
#
# Number of Pairs (periods) with negative result (lost): 299
# Sum of Pairs (periods) with negative result (lost): -3904.1461486816406
#
# ------------------------------------------------------
# Length of period: 94
# Number of all Buy/Sell Pairs (periods): 1163
# Sum of all Buy/Sell Pairs (periods): 15143.288501739502
# Number of investments: 1163
# Sum of investments: 169423.22371292114
#
# Number of Pairs (periods) with positive result (win): 867
# Sum of Pairs (periods) with positive result (win): 19021.33025741577
#
# Number of Pairs (periods) with negative result (lost): 296
# Sum of Pairs (periods) with negative result (lost): -3878.0417556762695
#
# ------------------------------------------------------
# Length of period: 95
# Number of all Buy/Sell Pairs (periods): 1162
# Sum of all Buy/Sell Pairs (periods): 15290.873905181885
# Number of investments: 1162
# Sum of investments: 169198.9972114563
#
# Number of Pairs (periods) with positive result (win): 879
# Sum of Pairs (periods) with positive result (win): 19138.289958953857
#
# Number of Pairs (periods) with negative result (lost): 283
# Sum of Pairs (periods) with negative result (lost): -3847.4160537719727
#
# ------------------------------------------------------
# Length of period: 96
# Number of all Buy/Sell Pairs (periods): 1161
# Sum of all Buy/Sell Pairs (periods): 15435.908763885498
# Number of investments: 1161
# ...
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1224
# Number of all Buy/Sell Pairs (periods): 33
# Sum of all Buy/Sell Pairs (periods): 5442.417053222656
# Number of investments: 33
# Sum of investments: 2520.6376953125
#
# Number of Pairs (periods) with positive result (win): 33
# Sum of Pairs (periods) with positive result (win): 5442.417053222656
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1225
# Number of all Buy/Sell Pairs (periods): 32
# Sum of all Buy/Sell Pairs (periods): 5296.969100952148
# Number of investments: 32
# Sum of investments: 2442.1019134521484
#
# Number of Pairs (periods) with positive result (win): 32
# Sum of Pairs (periods) with positive result (win): 5296.969100952148
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1226
# Number of all Buy/Sell Pairs (periods): 31
# Sum of all Buy/Sell Pairs (periods): 5149.510948181152
# Number of investments: 31
# Sum of investments: 2364.6873092651367
#
# Number of Pairs (periods) with positive result (win): 31
# Sum of Pairs (periods) with positive result (win): 5149.510948181152
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1227
# Number of all Buy/Sell Pairs (periods): 30
# Sum of all Buy/Sell Pairs (periods): 5000.4001388549805
# Number of investments: 30
# Sum of investments: 2285.828758239746
#
# Number of Pairs (periods) with positive result (win): 30
# Sum of Pairs (periods) with positive result (win): 5000.4001388549805
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1228
# Number of all Buy/Sell Pairs (periods): 29
# Sum of all Buy/Sell Pairs (periods): 4854.486389160156
# Number of investments: 29
# Sum of investments: 2206.9896240234375
#
# Number of Pairs (periods) with positive result (win): 29
# Sum of Pairs (periods) with positive result (win): 4854.486389160156
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1229
# Number of all Buy/Sell Pairs (periods): 28
# Sum of all Buy/Sell Pairs (periods): 4706.121391296387
# Number of investments: 28
# Sum of investments: 2127.58504486084
#
# Number of Pairs (periods) with positive result (win): 28
# Sum of Pairs (periods) with positive result (win): 4706.121391296387
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1230
# Number of all Buy/Sell Pairs (periods): 27
# Sum of all Buy/Sell Pairs (periods): 4555.654754638672
# Number of investments: 27
# Sum of investments: 2050.0223999023438
#
# Number of Pairs (periods) with positive result (win): 27
# Sum of Pairs (periods) with positive result (win): 4555.654754638672
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1231
# Number of all Buy/Sell Pairs (periods): 26
# Sum of all Buy/Sell Pairs (periods): 4404.9397048950195
# Number of investments: 26
# Sum of investments: 1971.9889602661133
#
# Number of Pairs (periods) with positive result (win): 26
# Sum of Pairs (periods) with positive result (win): 4404.9397048950195
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1232
# Number of all Buy/Sell Pairs (periods): 25
# Sum of all Buy/Sell Pairs (periods): 4254.335258483887
# Number of investments: 25
# Sum of investments: 1894.3243789672852
#
# Number of Pairs (periods) with positive result (win): 25
# Sum of Pairs (periods) with positive result (win): 4254.335258483887
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1233
# Number of all Buy/Sell Pairs (periods): 24
# Sum of all Buy/Sell Pairs (periods): 4103.452491760254
# Number of investments: 24
# Sum of investments: 1815.5896072387695
#
# Number of Pairs (periods) with positive result (win): 24
# Sum of Pairs (periods) with positive result (win): 4103.452491760254
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1234
# Number of all Buy/Sell Pairs (periods): 23
# Sum of all Buy/Sell Pairs (periods): 3948.662727355957
# Number of investments: 23
# Sum of investments: 1737.7651290893555
#
# Number of Pairs (periods) with positive result (win): 23
# Sum of Pairs (periods) with positive result (win): 3948.662727355957
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1235
# Number of all Buy/Sell Pairs (periods): 22
# Sum of all Buy/Sell Pairs (periods): 3791.055892944336
# Number of investments: 22
# Sum of investments: 1660.5701293945312
#
# Number of Pairs (periods) with positive result (win): 22
# Sum of Pairs (periods) with positive result (win): 3791.055892944336
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1236
# Number of all Buy/Sell Pairs (periods): 21
# Sum of all Buy/Sell Pairs (periods): 3631.1118545532227
# Number of investments: 21
# Sum of investments: 1585.842185974121
#
# Number of Pairs (periods) with positive result (win): 21
# Sum of Pairs (periods) with positive result (win): 3631.1118545532227
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1237
# Number of all Buy/Sell Pairs (periods): 20
# Sum of all Buy/Sell Pairs (periods): 3468.976249694824
# Number of investments: 20
# Sum of investments: 1510.9084396362305
#
# Number of Pairs (periods) with positive result (win): 20
# Sum of Pairs (periods) with positive result (win): 3468.976249694824
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1238
# Number of all Buy/Sell Pairs (periods): 19
# Sum of all Buy/Sell Pairs (periods): 3308.0597534179688
# Number of investments: 19
# Sum of investments: 1432.4980773925781
#
# Number of Pairs (periods) with positive result (win): 19
# Sum of Pairs (periods) with positive result (win): 3308.0597534179688
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1239
# Number of all Buy/Sell Pairs (periods): 18
# Sum of all Buy/Sell Pairs (periods): 3144.200424194336
# Number of investments: 18
# Sum of investments: 1353.9739074707031
#
# Number of Pairs (periods) with positive result (win): 18
# Sum of Pairs (periods) with positive result (win): 3144.200424194336
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1240
# Number of all Buy/Sell Pairs (periods): 17
# Sum of all Buy/Sell Pairs (periods): 2978.3714752197266
# Number of investments: 17
# Sum of investments: 1277.0597534179688
#
# Number of Pairs (periods) with positive result (win): 17
# Sum of Pairs (periods) with positive result (win): 2978.3714752197266
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1241
# Number of all Buy/Sell Pairs (periods): 16
# Sum of all Buy/Sell Pairs (periods): 2810.39656829834
# Number of investments: 16
# Sum of investments: 1202.261589050293
#
# Number of Pairs (periods) with positive result (win): 16
# Sum of Pairs (periods) with positive result (win): 2810.39656829834
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1242
# Number of all Buy/Sell Pairs (periods): 15
# Sum of all Buy/Sell Pairs (periods): 2644.8875427246094
# Number of investments: 15
# Sum of investments: 1125.1973266601562
#
# Number of Pairs (periods) with positive result (win): 15
# Sum of Pairs (periods) with positive result (win): 2644.8875427246094
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1243
# Number of all Buy/Sell Pairs (periods): 14
# Sum of all Buy/Sell Pairs (periods): 2475.695541381836
# Number of investments: 14
# Sum of investments: 1047.9103240966797
#
# Number of Pairs (periods) with positive result (win): 14
# Sum of Pairs (periods) with positive result (win): 2475.695541381836
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1244
# Number of all Buy/Sell Pairs (periods): 13
# Sum of all Buy/Sell Pairs (periods): 2305.114242553711
# Number of investments: 13
# Sum of investments: 970.9937438964844
#
# Number of Pairs (periods) with positive result (win): 13
# Sum of Pairs (periods) with positive result (win): 2305.114242553711
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1245
# Number of all Buy/Sell Pairs (periods): 12
# Sum of all Buy/Sell Pairs (periods): 2135.537956237793
# Number of investments: 12
# Sum of investments: 894.3507461547852
#
# Number of Pairs (periods) with positive result (win): 12
# Sum of Pairs (periods) with positive result (win): 2135.537956237793
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1246
# Number of all Buy/Sell Pairs (periods): 11
# Sum of all Buy/Sell Pairs (periods): 1965.016212463379
# Number of investments: 11
# Sum of investments: 817.1848068237305
#
# Number of Pairs (periods) with positive result (win): 11
# Sum of Pairs (periods) with positive result (win): 1965.016212463379
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1247
# Number of all Buy/Sell Pairs (periods): 10
# Sum of all Buy/Sell Pairs (periods): 1793.479736328125
# Number of investments: 10
# Sum of investments: 740.8638000488281
#
# Number of Pairs (periods) with positive result (win): 10
# Sum of Pairs (periods) with positive result (win): 1793.479736328125
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1248
# Number of all Buy/Sell Pairs (periods): 9
# Sum of all Buy/Sell Pairs (periods): 1618.0922622680664
# Number of investments: 9
# Sum of investments: 665.4869918823242
#
# Number of Pairs (periods) with positive result (win): 9
# Sum of Pairs (periods) with positive result (win): 1618.0922622680664
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1249
# Number of all Buy/Sell Pairs (periods): 8
# Sum of all Buy/Sell Pairs (periods): 1440.5918807983398
# Number of investments: 8
# Sum of investments: 589.785774230957
#
# Number of Pairs (periods) with positive result (win): 8
# Sum of Pairs (periods) with positive result (win): 1440.5918807983398
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1250
# Number of all Buy/Sell Pairs (periods): 7
# Sum of all Buy/Sell Pairs (periods): 1269.5517501831055
# Number of investments: 7
# Sum of investments: 513.0483322143555
#
# Number of Pairs (periods) with positive result (win): 7
# Sum of Pairs (periods) with positive result (win): 1269.5517501831055
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1251
# Number of all Buy/Sell Pairs (periods): 6
# Sum of all Buy/Sell Pairs (periods): 1095.1683654785156
# Number of investments: 6
# Sum of investments: 437.9160614013672
#
# Number of Pairs (periods) with positive result (win): 6
# Sum of Pairs (periods) with positive result (win): 1095.1683654785156
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1252
# Number of all Buy/Sell Pairs (periods): 5
# Sum of all Buy/Sell Pairs (periods): 915.920654296875
# Number of investments: 5
# Sum of investments: 362.95326232910156
#
# Number of Pairs (periods) with positive result (win): 5
# Sum of Pairs (periods) with positive result (win): 915.920654296875
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1253
# Number of all Buy/Sell Pairs (periods): 4
# Sum of all Buy/Sell Pairs (periods): 734.3346481323242
# Number of investments: 4
# Sum of investments: 289.5496139526367
#
# Number of Pairs (periods) with positive result (win): 4
# Sum of Pairs (periods) with positive result (win): 734.3346481323242
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1254
# Number of all Buy/Sell Pairs (periods): 3
# Sum of all Buy/Sell Pairs (periods): 548.6597442626953
# Number of investments: 3
# Sum of investments: 217.30807495117188
#
# Number of Pairs (periods) with positive result (win): 3
# Sum of Pairs (periods) with positive result (win): 548.6597442626953
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1255
# Number of all Buy/Sell Pairs (periods): 2
# Sum of all Buy/Sell Pairs (periods): 362.5071334838867
# Number of investments: 2
# Sum of investments: 144.72518157958984
#
# Number of Pairs (periods) with positive result (win): 2
# Sum of Pairs (periods) with positive result (win): 362.5071334838867
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 1256
# Number of all Buy/Sell Pairs (periods): 1
# Sum of all Buy/Sell Pairs (periods): 179.20694732666016
# Number of investments: 1
# Sum of investments: 72.71607208251953
#
# Number of Pairs (periods) with positive result (win): 1
# Sum of Pairs (periods) with positive result (win): 179.20694732666016
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# Creating the plot
plt.plot(period_lengths, corresponding_results)

# Adding title and labels
plt.title("Result vs. period length")
plt.xlabel("Length of Stay in Market")
plt.ylabel("Result")

# Enabling grid
plt.grid(True)

# Finding the maximum y value and its corresponding x
max_y = max(corresponding_results)
max_x = period_lengths[corresponding_results.index(max_y)]

# Plotting the maximum y value
plt.plot(max_x, max_y, 'ro')  # 'ro' stands for red circle marker

# Annotating the maximum y value and corresponding x value
plt.annotate(f'Max y = {max_y} at x = {max_x}', 
             (max_x, max_y), 
             textcoords="offset points", 
             xytext=(0, 10), 
             ha='center')

# Display the plot
plt.show()

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=max_x)

print(f"Period length (stay in market): {max_x}")
print(f"Max Result: {max_y}")
print()

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Period length (stay in market): 474
# Max Result: 37693.77587509155
#
# Number of all Buy/Sell Pairs (periods): 783
# Sum of all Buy/Sell Pairs (periods): 37693.77587509155
# Number of investments: 783
# Sum of investments: 100349.2654914856
#
# Number of Pairs (periods) with positive result (win): 765
# Sum of Pairs (periods) with positive result (win): 37753.11684799194
#
# Number of Pairs (periods) with negative result (lost): 18
# Sum of Pairs (periods) with negative result (lost): -59.340972900390625

# %%
total_investement = sum(investments)

share_return = round((max_y/total_investement) * 100, 2) 

print("Invested: ", total_investement)
print("Lost/Win: ", max_y)
print(f"Share Return: {share_return} %")
# Out:
# Invested:  100349.2654914856
# Lost/Win:  37693.77587509155
# Share Return: 37.56 %

# %%
buy_price_at_start = stock_close_prices.values[0][0]
bought_shares = total_investement/buy_price_at_start
sell_price_at_end = stock_close_prices.values[len(stock_close_prices)-1][0]
profit = (bought_shares*sell_price_at_end) - (bought_shares*buy_price_at_start)

print("One-time Investment: ", total_investement)
print("One-time Investment - Lost/Win: ", profit)
print(f"One-time Investment Share Return: {(profit/total_investement) * 100} %")
# Out:
# One-time Investment:  100349.2654914856
# One-time Investment - Lost/Win:  247308.26377412042
# One-time Investment Share Return: 246.44750767518468 %
