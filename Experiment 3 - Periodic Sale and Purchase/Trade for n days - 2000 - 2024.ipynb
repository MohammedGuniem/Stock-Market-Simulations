# %%
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
# Download historical stock data for a specific ticker
ticker = 'AAPL'

stock_data = yf.download(ticker, start='2000-01-01', end='2024-12-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
display(stock_data)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2000-01-03    0.842151    0.846382    0.765036    0.789017  535796800
# 2000-01-04    0.771149    0.832276    0.761274    0.814408  512377600
# 2000-01-05    0.782433    0.831806    0.774910    0.780552  778321600
# 2000-01-06    0.714723    0.805004    0.714723    0.798421  767972800
# 2000-01-07    0.748578    0.759863    0.718485    0.726008  460734400
# ...                ...         ...         ...         ...        ...
# 2024-12-23  254.989655  255.369227  253.171646  254.490204   40858800
# 2024-12-24  257.916443  257.926411  255.009620  255.209412   23234700
# 2024-12-26  258.735504  259.814335  257.347047  257.906429   27237100
# 2024-12-27  255.309296  258.415896  252.782075  257.546826   42355300
# 2024-12-30  251.923019  253.221595  250.474615  251.952985   35557500
#
# [6288 rows x 5 columns]

# %%
print("Number of open trading days in market: ", len(stock_data))
# Out:
# Number of open trading days in market:  6288

# %%
stock_close_prices = stock_data['Close']

# %%
def evaluate_trade_period(prices, period_length):
    investments = []
    prices_values = stock_close_prices.values
    if period_length >= len(prices) or period_length <= 0:
        raise ValueError("period_length should be less than len(prices) and bigger than 0")
        
    result_list = []
    for i in range(0, len(prices_values)-period_length, 1):
        buy_price = prices_values[i][0]
        investments.append(buy_price)
        sell_price = prices_values[i+period_length][0]
        result_list.append(float(sell_price-buy_price))
        
    return np.array(result_list), np.array(investments)

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=1)

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Number of all Buy/Sell Pairs (periods): 6287
# Sum of all Buy/Sell Pairs (periods): 251.08086878061295
# Number of investments: 6287
# Sum of investments: 258903.28950679302
#
# Number of Pairs (periods) with positive result (win): 3289
# Sum of Pairs (periods) with positive result (win): 1771.8554759770632
#
# Number of Pairs (periods) with negative result (lost): 2966
# Sum of Pairs (periods) with negative result (lost): -1520.7746071964502

# %%
period_lengths, corresponding_results = [], []
for i in range(1, len(stock_close_prices), 1):
    result_list, investments = evaluate_trade_period(stock_close_prices, period_length=i)
    period_lengths.append(i)
    corresponding_results.append(sum(result_list))

    print(f"Length of period: {i}")
    print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
    print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
    print(f"Number of investments: {len(investments)}")
    print(f"Sum of investments: {sum(investments)}")
    print()
    
    positive_results = result_list[result_list > 0]
    print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
    print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
    print()
    
    negative_results = result_list[result_list < 0]
    print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
    print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
    print()
    print("------------------------------------------------------")
# Out:
# Length of period: 1
# Number of all Buy/Sell Pairs (periods): 6287
# Sum of all Buy/Sell Pairs (periods): 251.08086878061295
# Number of investments: 6287
# Sum of investments: 258903.28950679302
#
# Number of Pairs (periods) with positive result (win): 3289
# Sum of Pairs (periods) with positive result (win): 1771.8554759770632
#
# Number of Pairs (periods) with negative result (lost): 2966
# Sum of Pairs (periods) with negative result (lost): -1520.7746071964502
#
# ------------------------------------------------------
# Length of period: 2
# Number of all Buy/Sell Pairs (periods): 6286
# Sum of all Buy/Sell Pairs (periods): 505.61901557445526
# Number of investments: 6286
# Sum of investments: 258647.98021113873
#
# Number of Pairs (periods) with positive result (win): 3391
# Sum of Pairs (periods) with positive result (win): 2627.495499640703
#
# Number of Pairs (periods) with negative result (lost): 2879
# Sum of Pairs (periods) with negative result (lost): -2121.876484066248
#
# ------------------------------------------------------
# Length of period: 3
# Number of all Buy/Sell Pairs (periods): 6285
# Sum of all Buy/Sell Pairs (periods): 763.5720866322517
# Number of investments: 6285
# Sum of investments: 258389.24470698833
#
# Number of Pairs (periods) with positive result (win): 3473
# Sum of Pairs (periods) with positive result (win): 3286.783635661006
#
# Number of Pairs (periods) with negative result (lost): 2795
# Sum of Pairs (periods) with negative result (lost): -2523.2115490287542
#
# ------------------------------------------------------
# Length of period: 4
# Number of all Buy/Sell Pairs (periods): 6284
# Sum of all Buy/Sell Pairs (periods): 1020.7738068699837
# Number of investments: 6284
# Sum of investments: 258131.32826411724
#
# Number of Pairs (periods) with positive result (win): 3528
# Sum of Pairs (periods) with positive result (win): 3868.7466601878405
#
# Number of Pairs (periods) with negative result (lost): 2746
# Sum of Pairs (periods) with negative result (lost): -2847.972853317857
#
# ------------------------------------------------------
# Length of period: 5
# Number of all Buy/Sell Pairs (periods): 6283
# Sum of all Buy/Sell Pairs (periods): 1275.0148832201958
# Number of investments: 6283
# Sum of investments: 257876.33860957623
#
# Number of Pairs (periods) with positive result (win): 3587
# Sum of Pairs (periods) with positive result (win): 4430.466010928154
#
# Number of Pairs (periods) with negative result (lost): 2689
# Sum of Pairs (periods) with negative result (lost): -3155.451127707958
#
# ------------------------------------------------------
# Length of period: 6
# Number of all Buy/Sell Pairs (periods): 6282
# Sum of all Buy/Sell Pairs (periods): 1528.489981174469
# Number of investments: 6282
# Sum of investments: 257622.12809932232
#
# Number of Pairs (periods) with positive result (win): 3620
# Sum of Pairs (periods) with positive result (win): 4943.2351200431585
#
# Number of Pairs (periods) with negative result (lost): 2655
# Sum of Pairs (periods) with negative result (lost): -3414.7451388686895
#
# ------------------------------------------------------
# Length of period: 7
# Number of all Buy/Sell Pairs (periods): 6281
# Sum of all Buy/Sell Pairs (periods): 1777.3078414201736
# Number of investments: 6281
# Sum of investments: 257372.61244380474
#
# Number of Pairs (periods) with positive result (win): 3627
# Sum of Pairs (periods) with positive result (win): 5441.113886758685
#
# Number of Pairs (periods) with negative result (lost): 2644
# Sum of Pairs (periods) with negative result (lost): -3663.8060453385115
#
# ------------------------------------------------------
# Length of period: 8
# Number of all Buy/Sell Pairs (periods): 6280
# Sum of all Buy/Sell Pairs (periods): 2024.4294674396515
# Number of investments: 6280
# Sum of investments: 257124.8348711729
#
# Number of Pairs (periods) with positive result (win): 3659
# Sum of Pairs (periods) with positive result (win): 5951.177697554231
#
# Number of Pairs (periods) with negative result (lost): 2618
# Sum of Pairs (periods) with negative result (lost): -3926.748230114579
#
# ------------------------------------------------------
# Length of period: 9
# Number of all Buy/Sell Pairs (periods): 6279
# Sum of all Buy/Sell Pairs (periods): 2276.9031779170036
# Number of investments: 6279
# Sum of investments: 256871.6332720518
#
# Number of Pairs (periods) with positive result (win): 3677
# Sum of Pairs (periods) with positive result (win): 6416.356448486447
#
# Number of Pairs (periods) with negative result (lost): 2600
# Sum of Pairs (periods) with negative result (lost): -4139.453270569444
#
# ------------------------------------------------------
# Length of period: 10
# Number of all Buy/Sell Pairs (periods): 6278
# Sum of all Buy/Sell Pairs (periods): 2526.9118290543556
# Number of investments: 6278
# Sum of investments: 256620.86898982525
#
# Number of Pairs (periods) with positive result (win): 3700
# Sum of Pairs (periods) with positive result (win): 6865.694727540016
#
# Number of Pairs (periods) with negative result (lost): 2571
# Sum of Pairs (periods) with negative result (lost): -4338.782898485661
#
# ------------------------------------------------------
# Length of period: 11
# Number of all Buy/Sell Pairs (periods): 6277
# Sum of all Buy/Sell Pairs (periods): 2773.9873489141464
# Number of investments: 6277
# Sum of investments: 256373.0115069151
#
# Number of Pairs (periods) with positive result (win): 3725
# Sum of Pairs (periods) with positive result (win): 7311.615959942341
#
# Number of Pairs (periods) with negative result (lost): 2549
# Sum of Pairs (periods) with negative result (lost): -4537.628611028194
#
# ------------------------------------------------------
# Length of period: 12
# Number of all Buy/Sell Pairs (periods): 6276
# Sum of all Buy/Sell Pairs (periods): 3020.8733196258545
# Number of investments: 6276
# Sum of investments: 256125.32382380962
#
# Number of Pairs (periods) with positive result (win): 3754
# Sum of Pairs (periods) with positive result (win): 7732.623321458697
#
# Number of Pairs (periods) with negative result (lost): 2516
# Sum of Pairs (periods) with negative result (lost): -4711.750001832843
#
# ------------------------------------------------------
# Length of period: 13
# Number of all Buy/Sell Pairs (periods): 6275
# Sum of all Buy/Sell Pairs (periods): 3266.2386976480484
# Number of investments: 6275
# Sum of investments: 255879.104539752
#
# Number of Pairs (periods) with positive result (win): 3787
# Sum of Pairs (periods) with positive result (win): 8117.73912166059
#
# Number of Pairs (periods) with negative result (lost): 2484
# Sum of Pairs (periods) with negative result (lost): -4851.500424012542
#
# ------------------------------------------------------
# Length of period: 14
# Number of all Buy/Sell Pairs (periods): 6274
# Sum of all Buy/Sell Pairs (periods): 3512.8991280794144
# Number of investments: 6274
# Sum of investments: 255631.6066607237
#
# Number of Pairs (periods) with positive result (win): 3792
# Sum of Pairs (periods) with positive result (win): 8490.435727894306
#
# Number of Pairs (periods) with negative result (lost): 2474
# Sum of Pairs (periods) with negative result (lost): -4977.536599814892
#
# ------------------------------------------------------
# Length of period: 15
# Number of all Buy/Sell Pairs (periods): 6273
# Sum of all Buy/Sell Pairs (periods): 3758.5787704586983
# Number of investments: 6273
# Sum of investments: 255385.12765681744
#
# Number of Pairs (periods) with positive result (win): 3807
# Sum of Pairs (periods) with positive result (win): 8872.82023063302
#
# Number of Pairs (periods) with negative result (lost): 2462
# Sum of Pairs (periods) with negative result (lost): -5114.241460174322
#
# ------------------------------------------------------
# Length of period: 16
# Number of all Buy/Sell Pairs (periods): 6272
# Sum of all Buy/Sell Pairs (periods): 4000.3075568675995
# Number of investments: 6272
# Sum of investments: 255142.55436885357
#
# Number of Pairs (periods) with positive result (win): 3820
# Sum of Pairs (periods) with positive result (win): 9236.64027133584
#
# Number of Pairs (periods) with negative result (lost): 2447
# Sum of Pairs (periods) with negative result (lost): -5236.332714468241
#
# ------------------------------------------------------
# Length of period: 17
# Number of all Buy/Sell Pairs (periods): 6271
# Sum of all Buy/Sell Pairs (periods): 4242.25164359808
# Number of investments: 6271
# Sum of investments: 254899.7812975645
#
# Number of Pairs (periods) with positive result (win): 3862
# Sum of Pairs (periods) with positive result (win): 9621.08300742507
#
# Number of Pairs (periods) with negative result (lost): 2404
# Sum of Pairs (periods) with negative result (lost): -5378.83136382699
#
# ------------------------------------------------------
# Length of period: 18
# Number of all Buy/Sell Pairs (periods): 6270
# Sum of all Buy/Sell Pairs (periods): 4484.167172431946
# Number of investments: 6270
# Sum of investments: 254657.03819453716
#
# Number of Pairs (periods) with positive result (win): 3857
# Sum of Pairs (periods) with positive result (win): 9938.393600255251
#
# Number of Pairs (periods) with negative result (lost): 2405
# Sum of Pairs (periods) with negative result (lost): -5454.226427823305
#
# ------------------------------------------------------
# Length of period: 19
# Number of all Buy/Sell Pairs (periods): 6269
# Sum of all Buy/Sell Pairs (periods): 4725.786106109619
# Number of investments: 6269
# Sum of investments: 254414.65469539165
#
# Number of Pairs (periods) with positive result (win): 3889
# Sum of Pairs (periods) with positive result (win): 10262.859196037054
#
# Number of Pairs (periods) with negative result (lost): 2376
# Sum of Pairs (periods) with negative result (lost): -5537.073089927435
#
# ------------------------------------------------------
# Length of period: 20
# Number of all Buy/Sell Pairs (periods): 6268
# Sum of all Buy/Sell Pairs (periods): 4964.332412183285
# Number of investments: 6268
# Sum of investments: 254175.32783687115
#
# Number of Pairs (periods) with positive result (win): 3879
# Sum of Pairs (periods) with positive result (win): 10576.900295704603
#
# Number of Pairs (periods) with negative result (lost): 2386
# Sum of Pairs (periods) with negative result (lost): -5612.567883521318
#
# ------------------------------------------------------
# Length of period: 21
# Number of all Buy/Sell Pairs (periods): 6267
# Sum of all Buy/Sell Pairs (periods): 5200.647542834282
# Number of investments: 6267
# Sum of investments: 253938.25848567486
#
# Number of Pairs (periods) with positive result (win): 3875
# Sum of Pairs (periods) with positive result (win): 10926.609555989504
#
# Number of Pairs (periods) with negative result (lost): 2391
# Sum of Pairs (periods) with negative result (lost): -5725.962013155222
#
# ------------------------------------------------------
# Length of period: 22
# Number of all Buy/Sell Pairs (periods): 6266
# Sum of all Buy/Sell Pairs (periods): 5434.576119244099
# Number of investments: 6266
# Sum of investments: 253703.58650386333
#
# Number of Pairs (periods) with positive result (win): 3885
# Sum of Pairs (periods) with positive result (win): 11279.773246452212
#
# Number of Pairs (periods) with negative result (lost): 2373
# Sum of Pairs (periods) with negative result (lost): -5845.197127208114
#
# ------------------------------------------------------
# Length of period: 23
# Number of all Buy/Sell Pairs (periods): 6265
# Sum of all Buy/Sell Pairs (periods): 5668.600692093372
# Number of investments: 6265
# Sum of investments: 253468.7846697569
#
# Number of Pairs (periods) with positive result (win): 3898
# Sum of Pairs (periods) with positive result (win): 11636.143509373069
#
# Number of Pairs (periods) with negative result (lost): 2361
# Sum of Pairs (periods) with negative result (lost): -5967.5428172796965
#
# ------------------------------------------------------
# Length of period: 24
# Number of all Buy/Sell Pairs (periods): 6264
# Sum of all Buy/Sell Pairs (periods): 5900.402407348156
# Number of investments: 6264
# Sum of investments: 253236.17042720318
#
# Number of Pairs (periods) with positive result (win): 3886
# Sum of Pairs (periods) with positive result (win): 11961.242185801268
#
# Number of Pairs (periods) with negative result (lost): 2376
# Sum of Pairs (periods) with negative result (lost): -6060.839778453112
#
# ------------------------------------------------------
# Length of period: 25
# Number of all Buy/Sell Pairs (periods): 6263
# Sum of all Buy/Sell Pairs (periods): 6129.161808371544
# Number of investments: 6263
# Sum of investments: 253006.55288875103
#
# Number of Pairs (periods) with positive result (win): 3907
# Sum of Pairs (periods) with positive result (win): 12237.330686122179
#
# Number of Pairs (periods) with negative result (lost): 2348
# Sum of Pairs (periods) with negative result (lost): -6108.168877750635
#
# ------------------------------------------------------
# Length of period: 26
# Number of all Buy/Sell Pairs (periods): 6262
# Sum of all Buy/Sell Pairs (periods): 6356.566584825516
# Number of investments: 6262
# Sum of investments: 252778.28386104107
#
# Number of Pairs (periods) with positive result (win): 3919
# Sum of Pairs (periods) with positive result (win): 12505.606790021062
#
# Number of Pairs (periods) with negative result (lost): 2341
# Sum of Pairs (periods) with negative result (lost): -6149.040205195546
#
# ------------------------------------------------------
# Length of period: 27
# Number of all Buy/Sell Pairs (periods): 6261
# Sum of all Buy/Sell Pairs (periods): 6584.467751741409
# Number of investments: 6261
# Sum of investments: 252549.5353716612
#
# Number of Pairs (periods) with positive result (win): 3928
# Sum of Pairs (periods) with positive result (win): 12765.01755823195
#
# Number of Pairs (periods) with negative result (lost): 2326
# Sum of Pairs (periods) with negative result (lost): -6180.5498064905405
#
# ------------------------------------------------------
# Length of period: 28
# Number of all Buy/Sell Pairs (periods): 6260
# Sum of all Buy/Sell Pairs (periods): 6811.643127322197
# Number of investments: 6260
# Sum of investments: 252321.50609004498
#
# Number of Pairs (periods) with positive result (win): 3940
# Sum of Pairs (periods) with positive result (win): 13040.860253036022
#
# Number of Pairs (periods) with negative result (lost): 2317
# Sum of Pairs (periods) with negative result (lost): -6229.217125713825
#
# ------------------------------------------------------
# Length of period: 29
# Number of all Buy/Sell Pairs (periods): 6259
# Sum of all Buy/Sell Pairs (periods): 7038.594534635544
# Number of investments: 6259
# Sum of investments: 252093.7365130186
#
# Number of Pairs (periods) with positive result (win): 3942
# Sum of Pairs (periods) with positive result (win): 13323.338180929422
#
# Number of Pairs (periods) with negative result (lost): 2315
# Sum of Pairs (periods) with negative result (lost): -6284.743646293879
#
# ------------------------------------------------------
# Length of period: 30
# Number of all Buy/Sell Pairs (periods): 6258
# Sum of all Buy/Sell Pairs (periods): 7262.476115047932
# Number of investments: 6258
# Sum of investments: 251868.98362910748
#
# Number of Pairs (periods) with positive result (win): 3971
# Sum of Pairs (periods) with positive result (win): 13627.040323391557
#
# Number of Pairs (periods) with negative result (lost): 2284
# Sum of Pairs (periods) with negative result (lost): -6364.564208343625
#
# ------------------------------------------------------
# Length of period: 31
# Number of all Buy/Sell Pairs (periods): 6257
# Sum of all Buy/Sell Pairs (periods): 7489.550191044807
# Number of investments: 6257
# Sum of investments: 251641.0142687559
#
# Number of Pairs (periods) with positive result (win): 3978
# Sum of Pairs (periods) with positive result (win): 13916.3112770468
#
# Number of Pairs (periods) with negative result (lost): 2275
# Sum of Pairs (periods) with negative result (lost): -6426.761086001992
#
# ------------------------------------------------------
# Length of period: 32
# Number of all Buy/Sell Pairs (periods): 6256
# Sum of all Buy/Sell Pairs (periods): 7713.564340054989
# Number of investments: 6256
# Sum of investments: 251416.1415117979
#
# Number of Pairs (periods) with positive result (win): 4022
# Sum of Pairs (periods) with positive result (win): 14207.931505694985
#
# Number of Pairs (periods) with negative result (lost): 2232
# Sum of Pairs (periods) with negative result (lost): -6494.3671656399965
#
# ------------------------------------------------------
# Length of period: 33
# Number of all Buy/Sell Pairs (periods): 6255
# Sum of all Buy/Sell Pairs (periods): 7936.683822929859
# Number of investments: 6255
# Sum of investments: 251192.15777766705
#
# Number of Pairs (periods) with positive result (win): 4031
# Sum of Pairs (periods) with positive result (win): 14493.687289059162
#
# Number of Pairs (periods) with negative result (lost): 2223
# Sum of Pairs (periods) with negative result (lost): -6557.003466129303
#
# ------------------------------------------------------
# Length of period: 34
# Number of all Buy/Sell Pairs (periods): 6254
# Sum of all Buy/Sell Pairs (periods): 8159.8305785655975
# Number of investments: 6254
# Sum of investments: 250968.1740435362
#
# Number of Pairs (periods) with positive result (win): 4043
# Sum of Pairs (periods) with positive result (win): 14766.56946234405
#
# Number of Pairs (periods) with negative result (lost): 2208
# Sum of Pairs (periods) with negative result (lost): -6606.738883778453
#
# ------------------------------------------------------
# Length of period: 35
# Number of all Buy/Sell Pairs (periods): 6253
# Sum of all Buy/Sell Pairs (periods): 8385.685060620308
# Number of investments: 6253
# Sum of investments: 250741.46330440044
#
# Number of Pairs (periods) with positive result (win): 4059
# Sum of Pairs (periods) with positive result (win): 15043.571788579226
#
# Number of Pairs (periods) with negative result (lost): 2189
# Sum of Pairs (periods) with negative result (lost): -6657.886727958918
#
# ------------------------------------------------------
# Length of period: 36
# Number of all Buy/Sell Pairs (periods): 6252
# Sum of all Buy/Sell Pairs (periods): 8611.7909039855
# Number of investments: 6252
# Sum of investments: 250514.48286616802
#
# Number of Pairs (periods) with positive result (win): 4078
# Sum of Pairs (periods) with positive result (win): 15334.828896328807
#
# Number of Pairs (periods) with negative result (lost): 2172
# Sum of Pairs (periods) with negative result (lost): -6723.0379923433065
#
# ------------------------------------------------------
# Length of period: 37
# Number of all Buy/Sell Pairs (periods): 6251
# Sum of all Buy/Sell Pairs (periods): 8833.155081152916
# Number of investments: 6251
# Sum of investments: 250292.25197017193
#
# Number of Pairs (periods) with positive result (win): 4091
# Sum of Pairs (periods) with positive result (win): 15604.949844837189
#
# Number of Pairs (periods) with negative result (lost): 2157
# Sum of Pairs (periods) with negative result (lost): -6771.794763684273
#
# ------------------------------------------------------
# Length of period: 38
# Number of all Buy/Sell Pairs (periods): 6250
# Sum of all Buy/Sell Pairs (periods): 9055.283975481987
# Number of investments: 6250
# Sum of investments: 250069.29268062115
#
# Number of Pairs (periods) with positive result (win): 4124
# Sum of Pairs (periods) with positive result (win): 15887.884912192822
#
# Number of Pairs (periods) with negative result (lost): 2125
# Sum of Pairs (periods) with negative result (lost): -6832.6009367108345
#
# ------------------------------------------------------
# Length of period: 39
# Number of all Buy/Sell Pairs (periods): 6249
# Sum of all Buy/Sell Pairs (periods): 9275.95439606905
# Number of investments: 6249
# Sum of investments: 249847.77023494244
#
# Number of Pairs (periods) with positive result (win): 4136
# Sum of Pairs (periods) with positive result (win): 16163.87203411758
#
# Number of Pairs (periods) with negative result (lost): 2112
# Sum of Pairs (periods) with negative result (lost): -6887.91763804853
#
# ------------------------------------------------------
# Length of period: 40
# Number of all Buy/Sell Pairs (periods): 6248
# Sum of all Buy/Sell Pairs (periods): 9497.51249718666
# Number of investments: 6248
# Sum of investments: 249625.34976375103
#
# Number of Pairs (periods) with positive result (win): 4122
# Sum of Pairs (periods) with positive result (win): 16431.574966058135
#
# Number of Pairs (periods) with negative result (lost): 2125
# Sum of Pairs (periods) with negative result (lost): -6934.062468871474
#
# ------------------------------------------------------
# Length of period: 41
# Number of all Buy/Sell Pairs (periods): 6247
# Sum of all Buy/Sell Pairs (periods): 9721.945999145508
# Number of investments: 6247
# Sum of investments: 249399.9358690977
#
# Number of Pairs (periods) with positive result (win): 4157
# Sum of Pairs (periods) with positive result (win): 16675.661458790302
#
# Number of Pairs (periods) with negative result (lost): 2084
# Sum of Pairs (periods) with negative result (lost): -6953.7154596447945
#
# ------------------------------------------------------
# Length of period: 42
# Number of all Buy/Sell Pairs (periods): 6246
# Sum of all Buy/Sell Pairs (periods): 9950.622824847698
# Number of investments: 6246
# Sum of investments: 249170.34118831158
#
# Number of Pairs (periods) with positive result (win): 4149
# Sum of Pairs (periods) with positive result (win): 16931.213156849146
#
# Number of Pairs (periods) with negative result (lost): 2096
# Sum of Pairs (periods) with negative result (lost): -6980.590332001448
#
# ------------------------------------------------------
# Length of period: 43
# Number of all Buy/Sell Pairs (periods): 6245
# Sum of all Buy/Sell Pairs (periods): 10182.816675126553
# Number of investments: 6245
# Sum of investments: 248937.1843432188
#
# Number of Pairs (periods) with positive result (win): 4156
# Sum of Pairs (periods) with positive result (win): 17209.22071224451
#
# Number of Pairs (periods) with negative result (lost): 2086
# Sum of Pairs (periods) with negative result (lost): -7026.404037117958
#
# ------------------------------------------------------
# Length of period: 44
# Number of all Buy/Sell Pairs (periods): 6244
# Sum of all Buy/Sell Pairs (periods): 10414.758513867855
# Number of investments: 6244
# Sum of investments: 248704.29690730572
#
# Number of Pairs (periods) with positive result (win): 4173
# Sum of Pairs (periods) with positive result (win): 17476.683825969696
#
# Number of Pairs (periods) with negative result (lost): 2068
# Sum of Pairs (periods) with negative result (lost): -7061.925312101841
#
# ------------------------------------------------------
# Length of period: 45
# Number of all Buy/Sell Pairs (periods): 6243
# Sum of all Buy/Sell Pairs (periods): 10644.73588603735
# Number of investments: 6243
# Sum of investments: 248473.39509761333
#
# Number of Pairs (periods) with positive result (win): 4172
# Sum of Pairs (periods) with positive result (win): 17721.675552085042
#
# Number of Pairs (periods) with negative result (lost): 2068
# Sum of Pairs (periods) with negative result (lost): -7076.939666047692
#
# ------------------------------------------------------
# Length of period: 46
# Number of all Buy/Sell Pairs (periods): 6242
# Sum of all Buy/Sell Pairs (periods): 10873.881705880165
# Number of investments: 6242
# Sum of investments: 248243.33142268658
#
# Number of Pairs (periods) with positive result (win): 4177
# Sum of Pairs (periods) with positive result (win): 17968.17458626628
#
# Number of Pairs (periods) with negative result (lost): 2063
# Sum of Pairs (periods) with negative result (lost): -7094.292880386114
#
# ------------------------------------------------------
# Length of period: 47
# Number of all Buy/Sell Pairs (periods): 6241
# Sum of all Buy/Sell Pairs (periods): 11103.215204954147
# Number of investments: 6241
# Sum of investments: 248013.0781878233
#
# Number of Pairs (periods) with positive result (win): 4190
# Sum of Pairs (periods) with positive result (win): 18201.085392549634
#
# Number of Pairs (periods) with negative result (lost): 2049
# Sum of Pairs (periods) with negative result (lost): -7097.870187595487
#
# ------------------------------------------------------
# Length of period: 48
# Number of all Buy/Sell Pairs (periods): 6240
# Sum of all Buy/Sell Pairs (periods): 11337.611178398132
# Number of investments: 6240
# Sum of investments: 247777.73614680767
#
# Number of Pairs (periods) with positive result (win): 4193
# Sum of Pairs (periods) with positive result (win): 18447.98333746195
#
# Number of Pairs (periods) with negative result (lost): 2047
# Sum of Pairs (periods) with negative result (lost): -7110.372159063816
#
# ------------------------------------------------------
# Length of period: 49
# Number of all Buy/Sell Pairs (periods): 6239
# Sum of all Buy/Sell Pairs (periods): 11572.659173846245
# Number of investments: 6239
# Sum of investments: 247541.77546870708
#
# Number of Pairs (periods) with positive result (win): 4195
# Sum of Pairs (periods) with positive result (win): 18701.508902817965
#
# Number of Pairs (periods) with negative result (lost): 2043
# Sum of Pairs (periods) with negative result (lost): -7128.84972897172
#
# ------------------------------------------------------
# Length of period: 50
# Number of all Buy/Sell Pairs (periods): 6238
# Sum of all Buy/Sell Pairs (periods): 11806.28354281187
# Number of investments: 6238
# Sum of investments: 247307.29155147076
#
# Number of Pairs (periods) with positive result (win): 4203
# Sum of Pairs (periods) with positive result (win): 18930.76588743925
#
# Number of Pairs (periods) with negative result (lost): 2034
# Sum of Pairs (periods) with negative result (lost): -7124.48234462738
#
# ------------------------------------------------------
# Length of period: 51
# Number of all Buy/Sell Pairs (periods): 6237
# Sum of all Buy/Sell Pairs (periods): 12037.049130439758
# Number of investments: 6237
# Sum of investments: 247075.65136897564
#
# Number of Pairs (periods) with positive result (win): 4219
# Sum of Pairs (periods) with positive result (win): 19164.92596255243
#
# Number of Pairs (periods) with negative result (lost): 2016
# Sum of Pairs (periods) with negative result (lost): -7127.87683211267
#
# ------------------------------------------------------
# Length of period: 52
# Number of all Buy/Sell Pairs (periods): 6236
# Sum of all Buy/Sell Pairs (periods): 12267.40556359291
# Number of investments: 6236
# Sum of investments: 246844.3803728819
#
# Number of Pairs (periods) with positive result (win): 4220
# Sum of Pairs (periods) with positive result (win): 19391.349689364433
#
# Number of Pairs (periods) with negative result (lost): 2014
# Sum of Pairs (periods) with negative result (lost): -7123.9441257715225
#
# ------------------------------------------------------
# Length of period: 53
# Number of all Buy/Sell Pairs (periods): 6235
# Sum of all Buy/Sell Pairs (periods): 12499.801595687866
# Number of investments: 6235
# Sum of investments: 246611.04391658306
#
# Number of Pairs (periods) with positive result (win): 4213
# Sum of Pairs (periods) with positive result (win): 19613.08399568498
#
# Number of Pairs (periods) with negative result (lost): 2021
# Sum of Pairs (periods) with negative result (lost): -7113.282399997115
#
# ------------------------------------------------------
# Length of period: 54
# Number of all Buy/Sell Pairs (periods): 6234
# Sum of all Buy/Sell Pairs (periods): 12729.668271124363
# Number of investments: 6234
# Sum of investments: 246380.2518633604
#
# Number of Pairs (periods) with positive result (win): 4215
# Sum of Pairs (periods) with positive result (win): 19848.15854997933
#
# Number of Pairs (periods) with negative result (lost): 2019
# Sum of Pairs (periods) with negative result (lost): -7118.490278854966
#
# ------------------------------------------------------
# Length of period: 55
# Number of all Buy/Sell Pairs (periods): 6233
# Sum of all Buy/Sell Pairs (periods): 12955.703375399113
# Number of investments: 6233
# Sum of investments: 246153.20157039165
#
# Number of Pairs (periods) with positive result (win): 4222
# Sum of Pairs (periods) with positive result (win): 20082.428127989173
#
# Number of Pairs (periods) with negative result (lost): 2010
# Sum of Pairs (periods) with negative result (lost): -7126.72475259006
#
# ------------------------------------------------------
# Length of period: 56
# Number of all Buy/Sell Pairs (periods): 6232
# Sum of all Buy/Sell Pairs (periods): 13183.15561336279
# Number of investments: 6232
# Sum of investments: 245924.6645525694
#
# Number of Pairs (periods) with positive result (win): 4233
# Sum of Pairs (periods) with positive result (win): 20312.56533560157
#
# Number of Pairs (periods) with negative result (lost): 1997
# Sum of Pairs (periods) with negative result (lost): -7129.409722238779
#
# ------------------------------------------------------
# Length of period: 57
# Number of all Buy/Sell Pairs (periods): 6231
# Sum of all Buy/Sell Pairs (periods): 13411.128381669521
# Number of investments: 6231
# Sum of investments: 245695.62863337994
#
# Number of Pairs (periods) with positive result (win): 4235
# Sum of Pairs (periods) with positive result (win): 20534.21789638698
#
# Number of Pairs (periods) with negative result (lost): 1995
# Sum of Pairs (periods) with negative result (lost): -7123.08951471746
#
# ------------------------------------------------------
# Length of period: 58
# Number of all Buy/Sell Pairs (periods): 6230
# Sum of all Buy/Sell Pairs (periods): 13635.359180986881
# Number of investments: 6230
# Sum of investments: 245470.35443294048
#
# Number of Pairs (periods) with positive result (win): 4225
# Sum of Pairs (periods) with positive result (win): 20780.64100985229
#
# Number of Pairs (periods) with negative result (lost): 2004
# Sum of Pairs (periods) with negative result (lost): -7145.281828865409
#
# ------------------------------------------------------
# Length of period: 59
# Number of all Buy/Sell Pairs (periods): 6229
# Sum of all Buy/Sell Pairs (periods): 13855.512351810932
# Number of investments: 6229
# Sum of investments: 245249.1512774229
#
# Number of Pairs (periods) with positive result (win): 4232
# Sum of Pairs (periods) with positive result (win): 20994.550359219313
#
# Number of Pairs (periods) with negative result (lost): 1994
# Sum of Pairs (periods) with negative result (lost): -7139.0380074083805
#
# ------------------------------------------------------
# Length of period: 60
# Number of all Buy/Sell Pairs (periods): 6228
# Sum of all Buy/Sell Pairs (periods): 14080.767599284649
# Number of investments: 6228
# Sum of investments: 245022.84933650494
#
# Number of Pairs (periods) with positive result (win): 4240
# Sum of Pairs (periods) with positive result (win): 21227.927860826254
#
# Number of Pairs (periods) with negative result (lost): 1986
# Sum of Pairs (periods) with negative result (lost): -7147.160261541605
#
# ------------------------------------------------------
# Length of period: 61
# Number of all Buy/Sell Pairs (periods): 6227
# Sum of all Buy/Sell Pairs (periods): 14304.91929501295
# Number of investments: 6227
# Sum of investments: 244797.67492854595
#
# Number of Pairs (periods) with positive result (win): 4256
# Sum of Pairs (periods) with positive result (win): 21459.162375971675
#
# Number of Pairs (periods) with negative result (lost): 1969
# Sum of Pairs (periods) with negative result (lost): -7154.243080958724
#
# ------------------------------------------------------
# Length of period: 62
# Number of all Buy/Sell Pairs (periods): 6226
# Sum of all Buy/Sell Pairs (periods): 14530.255209863186
# Number of investments: 6226
# Sum of investments: 244571.39294612408
#
# Number of Pairs (periods) with positive result (win): 4269
# Sum of Pairs (periods) with positive result (win): 21677.358653381467
#
# Number of Pairs (periods) with negative result (lost): 1954
# Sum of Pairs (periods) with negative result (lost): -7147.103443518281
#
# ------------------------------------------------------
# Length of period: 63
# Number of all Buy/Sell Pairs (periods): 6225
# Sum of all Buy/Sell Pairs (periods): 14754.946679413319
# Number of investments: 6225
# Sum of investments: 244345.67970454693
#
# Number of Pairs (periods) with positive result (win): 4280
# Sum of Pairs (periods) with positive result (win): 21877.09593358636
#
# Number of Pairs (periods) with negative result (lost): 1944
# Sum of Pairs (periods) with negative result (lost): -7122.14925417304
#
# ------------------------------------------------------
# Length of period: 64
# Number of all Buy/Sell Pairs (periods): 6224
# Sum of all Buy/Sell Pairs (periods): 14986.432043731213
# Number of investments: 6224
# Sum of investments: 244113.19137752056
#
# Number of Pairs (periods) with positive result (win): 4293
# Sum of Pairs (periods) with positive result (win): 22091.896708235145
#
# Number of Pairs (periods) with negative result (lost): 1930
# Sum of Pairs (periods) with negative result (lost): -7105.464664503932
#
# ------------------------------------------------------
# Length of period: 65
# Number of all Buy/Sell Pairs (periods): 6223
# Sum of all Buy/Sell Pairs (periods): 15212.76396971941
# Number of investments: 6223
# Sum of investments: 243885.90162837505
#
# Number of Pairs (periods) with positive result (win): 4314
# Sum of Pairs (periods) with positive result (win): 22310.27347716689
#
# Number of Pairs (periods) with negative result (lost): 1907
# Sum of Pairs (periods) with negative result (lost): -7097.509507447481
#
# ------------------------------------------------------
# Length of period: 66
# Number of all Buy/Sell Pairs (periods): 6222
# Sum of all Buy/Sell Pairs (periods): 15438.803461432457
# Number of investments: 6222
# Sum of investments: 243658.88127315044
#
# Number of Pairs (periods) with positive result (win): 4312
# Sum of Pairs (periods) with positive result (win): 22506.050327137113
#
# Number of Pairs (periods) with negative result (lost): 1909
# Sum of Pairs (periods) with negative result (lost): -7067.246865704656
#
# ------------------------------------------------------
# Length of period: 67
# Number of all Buy/Sell Pairs (periods): 6221
# Sum of all Buy/Sell Pairs (periods): 15663.734504282475
# Number of investments: 6221
# Sum of investments: 243433.00839412212
#
# Number of Pairs (periods) with positive result (win): 4325
# Sum of Pairs (periods) with positive result (win): 22704.476126015186
#
# Number of Pairs (periods) with negative result (lost): 1894
# Sum of Pairs (periods) with negative result (lost): -7040.741621732712
#
# ------------------------------------------------------
# Length of period: 68
# Number of all Buy/Sell Pairs (periods): 6220
# Sum of all Buy/Sell Pairs (periods): 15889.613978505135
# Number of investments: 6220
# Sum of investments: 243206.13771235943
#
# Number of Pairs (periods) with positive result (win): 4327
# Sum of Pairs (periods) with positive result (win): 22881.271588400006
#
# Number of Pairs (periods) with negative result (lost): 1891
# Sum of Pairs (periods) with negative result (lost): -6991.657609894872
#
# ------------------------------------------------------
# Length of period: 69
# Number of all Buy/Sell Pairs (periods): 6219
# Sum of all Buy/Sell Pairs (periods): 16114.646210551262
# Number of investments: 6219
# Sum of investments: 242980.16505610943
#
# Number of Pairs (periods) with positive result (win): 4340
# Sum of Pairs (periods) with positive result (win): 23081.793171972036
#
# Number of Pairs (periods) with negative result (lost): 1877
# Sum of Pairs (periods) with negative result (lost): -6967.1469614207745
#
# ------------------------------------------------------
# Length of period: 70
# Number of all Buy/Sell Pairs (periods): 6218
# Sum of all Buy/Sell Pairs (periods): 16341.446487247944
# Number of investments: 6218
# Sum of investments: 242752.46620357037
#
# Number of Pairs (periods) with positive result (win): 4351
# Sum of Pairs (periods) with positive result (win): 23280.23932825029
#
# Number of Pairs (periods) with negative result (lost): 1866
# Sum of Pairs (periods) with negative result (lost): -6938.792841002345
#
# ------------------------------------------------------
# Length of period: 71
# Number of all Buy/Sell Pairs (periods): 6217
# Sum of all Buy/Sell Pairs (periods): 16568.991942048073
# Number of investments: 6217
# Sum of investments: 242524.0988177061
#
# Number of Pairs (periods) with positive result (win): 4360
# Sum of Pairs (periods) with positive result (win): 23481.26603268087
#
# Number of Pairs (periods) with negative result (lost): 1855
# Sum of Pairs (periods) with negative result (lost): -6912.274090632796
#
# ------------------------------------------------------
# Length of period: 72
# Number of all Buy/Sell Pairs (periods): 6216
# Sum of all Buy/Sell Pairs (periods): 16788.341037750244
# Number of investments: 6216
# Sum of investments: 242303.8934649229
#
# Number of Pairs (periods) with positive result (win): 4368
# Sum of Pairs (periods) with positive result (win): 23671.255316644907
#
# Number of Pairs (periods) with negative result (lost): 1846
# Sum of Pairs (periods) with negative result (lost): -6882.914278894663
#
# ------------------------------------------------------
# Length of period: 73
# Number of all Buy/Sell Pairs (periods): 6215
# Sum of all Buy/Sell Pairs (periods): 17003.813261151314
# Number of investments: 6215
# Sum of investments: 242087.5795611143
#
# Number of Pairs (periods) with positive result (win): 4381
# Sum of Pairs (periods) with positive result (win): 23865.731581762433
#
# Number of Pairs (periods) with negative result (lost): 1833
# Sum of Pairs (periods) with negative result (lost): -6861.918320611119
#
# ------------------------------------------------------
# Length of period: 74
# Number of all Buy/Sell Pairs (periods): 6214
# Sum of all Buy/Sell Pairs (periods): 17218.726255118847
# Number of investments: 6214
# Sum of investments: 241871.73460566998
#
# Number of Pairs (periods) with positive result (win): 4373
# Sum of Pairs (periods) with positive result (win): 24037.337656632066
#
# Number of Pairs (periods) with negative result (lost): 1840
# Sum of Pairs (periods) with negative result (lost): -6818.611401513219
#
# ------------------------------------------------------
# Length of period: 75
# Number of all Buy/Sell Pairs (periods): 6213
# Sum of all Buy/Sell Pairs (periods): 17439.78310662508
# Number of investments: 6213
# Sum of investments: 241649.72322261333
#
# Number of Pairs (periods) with positive result (win): 4381
# Sum of Pairs (periods) with positive result (win): 24248.93402135372
#
# Number of Pairs (periods) with negative result (lost): 1832
# Sum of Pairs (periods) with negative result (lost): -6809.1509147286415
#
# ------------------------------------------------------
# Length of period: 76
# Number of all Buy/Sell Pairs (periods): 6212
# Sum of all Buy/Sell Pairs (periods): 17661.152612149715
# Number of investments: 6212
# Sum of investments: 241427.4424456358
#
# Number of Pairs (periods) with positive result (win): 4378
# Sum of Pairs (periods) with positive result (win): 24463.566476926208
#
# Number of Pairs (periods) with negative result (lost): 1832
# Sum of Pairs (periods) with negative result (lost): -6802.413864776492
#
# ------------------------------------------------------
# Length of period: 77
# Number of all Buy/Sell Pairs (periods): 6211
# Sum of all Buy/Sell Pairs (periods): 17882.42928880453
# Number of investments: 6211
# Sum of investments: 241205.27142512798
#
# Number of Pairs (periods) with positive result (win): 4383
# Sum of Pairs (periods) with positive result (win): 24666.826073274016
#
# Number of Pairs (periods) with negative result (lost): 1825
# Sum of Pairs (periods) with negative result (lost): -6784.396784469485
#
# ------------------------------------------------------
# Length of period: 78
# Number of all Buy/Sell Pairs (periods): 6210
# Sum of all Buy/Sell Pairs (periods): 18101.14935195446
# Number of investments: 6210
# Sum of investments: 240985.64479243755
#
# Number of Pairs (periods) with positive result (win): 4378
# Sum of Pairs (periods) with positive result (win): 24871.449394464493
#
# Number of Pairs (periods) with negative result (lost): 1830
# Sum of Pairs (periods) with negative result (lost): -6770.300042510033
#
# ------------------------------------------------------
# Length of period: 79
# Number of all Buy/Sell Pairs (periods): 6209
# Sum of all Buy/Sell Pairs (periods): 18320.60887181759
# Number of investments: 6209
# Sum of investments: 240765.2199267149
#
# Number of Pairs (periods) with positive result (win): 4383
# Sum of Pairs (periods) with positive result (win): 25070.868437811732
#
# Number of Pairs (periods) with negative result (lost): 1825
# Sum of Pairs (periods) with negative result (lost): -6750.2595659941435
#
# ------------------------------------------------------
# Length of period: 80
# Number of all Buy/Sell Pairs (periods): 6208
# Sum of all Buy/Sell Pairs (periods): 18540.031272172928
# Number of investments: 6208
# Sum of investments: 240544.88484370708
#
# Number of Pairs (periods) with positive result (win): 4383
# Sum of Pairs (periods) with positive result (win): 25270.641372427344
#
# Number of Pairs (periods) with negative result (lost): 1825
# Sum of Pairs (periods) with negative result (lost): -6730.6101002544165
#
# ------------------------------------------------------
# Length of period: 81
# Number of all Buy/Sell Pairs (periods): 6207
# Sum of all Buy/Sell Pairs (periods): 18760.969313442707
# Number of investments: 6207
# Sum of investments: 240322.993211627
#
# Number of Pairs (periods) with positive result (win): 4389
# Sum of Pairs (periods) with positive result (win): 25460.942649304867
#
# Number of Pairs (periods) with negative result (lost): 1814
# Sum of Pairs (periods) with negative result (lost): -6699.97333586216
#
# ------------------------------------------------------
# Length of period: 82
# Number of all Buy/Sell Pairs (periods): 6206
# Sum of all Buy/Sell Pairs (periods): 18980.40094715357
# Number of investments: 6206
# Sum of investments: 240102.62820613384
#
# Number of Pairs (periods) with positive result (win): 4389
# Sum of Pairs (periods) with positive result (win): 25681.765784427524
#
# Number of Pairs (periods) with negative result (lost): 1817
# Sum of Pairs (periods) with negative result (lost): -6701.364837273955
#
# ------------------------------------------------------
# Length of period: 83
# Number of all Buy/Sell Pairs (periods): 6205
# Sum of all Buy/Sell Pairs (periods): 19201.746471464634
# Number of investments: 6205
# Sum of investments: 239880.3474291563
#
# Number of Pairs (periods) with positive result (win): 4402
# Sum of Pairs (periods) with positive result (win): 25894.52778378129
#
# Number of Pairs (periods) with negative result (lost): 1801
# Sum of Pairs (periods) with negative result (lost): -6692.781312316656
#
# ------------------------------------------------------
# Length of period: 84
# Number of all Buy/Sell Pairs (periods): 6204
# Sum of all Buy/Sell Pairs (periods): 19429.356751799583
# Number of investments: 6204
# Sum of investments: 239651.85032832623
#
# Number of Pairs (periods) with positive result (win): 4410
# Sum of Pairs (periods) with positive result (win): 26117.207642912865
#
# Number of Pairs (periods) with negative result (lost): 1793
# Sum of Pairs (periods) with negative result (lost): -6687.850891113281
#
# ------------------------------------------------------
# Length of period: 85
# Number of all Buy/Sell Pairs (periods): 6203
# Sum of all Buy/Sell Pairs (periods): 19657.776460170746
# Number of investments: 6203
# Sum of investments: 239422.56495845318
#
# Number of Pairs (periods) with positive result (win): 4410
# Sum of Pairs (periods) with positive result (win): 26335.940781772137
#
# Number of Pairs (periods) with negative result (lost): 1790
# Sum of Pairs (periods) with negative result (lost): -6678.164321601391
#
# ------------------------------------------------------
# Length of period: 86
# Number of all Buy/Sell Pairs (periods): 6202
# Sum of all Buy/Sell Pairs (periods): 19882.936328709126
# Number of investments: 6202
# Sum of investments: 239196.57234370708
#
# Number of Pairs (periods) with positive result (win): 4423
# Sum of Pairs (periods) with positive result (win): 26534.485592246056
#
# Number of Pairs (periods) with negative result (lost): 1776
# Sum of Pairs (periods) with negative result (lost): -6651.54926353693
#
# ------------------------------------------------------
# Length of period: 87
# Number of all Buy/Sell Pairs (periods): 6201
# Sum of all Buy/Sell Pairs (periods): 20109.61446416378
# Number of investments: 6201
# Sum of investments: 238969.04312312603
#
# Number of Pairs (periods) with positive result (win): 4428
# Sum of Pairs (periods) with positive result (win): 26710.181911990047
#
# Number of Pairs (periods) with negative result (lost): 1771
# Sum of Pairs (periods) with negative result (lost): -6600.567447826266
#
# ------------------------------------------------------
# Length of period: 88
# Number of all Buy/Sell Pairs (periods): 6200
# Sum of all Buy/Sell Pairs (periods): 20335.46704083681
# Number of investments: 6200
# Sum of investments: 238742.36203181744
#
# Number of Pairs (periods) with positive result (win): 4425
# Sum of Pairs (periods) with positive result (win): 26891.611476436257
#
# Number of Pairs (periods) with negative result (lost): 1774
# Sum of Pairs (periods) with negative result (lost): -6556.144435599446
#
# ------------------------------------------------------
# Length of period: 89
# Number of all Buy/Sell Pairs (periods): 6199
# Sum of all Buy/Sell Pairs (periods): 20561.015635311604
# Number of investments: 6199
# Sum of investments: 238516.02018916607
#
# Number of Pairs (periods) with positive result (win): 4427
# Sum of Pairs (periods) with positive result (win): 27072.414893463254
#
# Number of Pairs (periods) with negative result (lost): 1770
# Sum of Pairs (periods) with negative result (lost): -6511.39925815165
#
# ------------------------------------------------------
# Length of period: 90
# Number of all Buy/Sell Pairs (periods): 6198
# Sum of all Buy/Sell Pairs (periods): 20784.305393636227
# Number of investments: 6198
# Sum of investments: 238291.98326289654
#
# Number of Pairs (periods) with positive result (win): 4440
# Sum of Pairs (periods) with positive result (win): 27269.739601433277
#
# Number of Pairs (periods) with negative result (lost): 1754
# Sum of Pairs (periods) with negative result (lost): -6485.4342077970505
#
# ------------------------------------------------------
# Length of period: 91
# Number of all Buy/Sell Pairs (periods): 6197
# Sum of all Buy/Sell Pairs (periods): 21009.434695363045
# Number of investments: 6197
# Sum of investments: 238066.08046138287
#
# Number of Pairs (periods) with positive result (win): 4439
# Sum of Pairs (periods) with positive result (win): 27448.40261349082
#
# Number of Pairs (periods) with negative result (lost): 1754
# Sum of Pairs (periods) with negative result (lost): -6438.967918127775
#
# ------------------------------------------------------
# Length of period: 92
# Number of all Buy/Sell Pairs (periods): 6196
# Sum of all Buy/Sell Pairs (periods): 21234.63756251335
# Number of investments: 6196
# Sum of investments: 237840.06788814068
#
# Number of Pairs (periods) with positive result (win): 4442
# Sum of Pairs (periods) with positive result (win): 27640.03744621575
#
# Number of Pairs (periods) with negative result (lost): 1752
# Sum of Pairs (periods) with negative result (lost): -6405.399883702397
#
# ------------------------------------------------------
# Length of period: 93
# Number of all Buy/Sell Pairs (periods): 6195
# Sum of all Buy/Sell Pairs (periods): 21459.271634936333
# Number of investments: 6195
# Sum of investments: 237614.67395198345
#
# Number of Pairs (periods) with positive result (win): 4452
# Sum of Pairs (periods) with positive result (win): 27856.592753976583
#
# Number of Pairs (periods) with negative result (lost): 1742
# Sum of Pairs (periods) with negative result (lost): -6397.321119040251
#
# ------------------------------------------------------
# Length of period: 94
# Number of all Buy/Sell Pairs (periods): 6194
# Sum of all Buy/Sell Pairs (periods): 21684.03009456396
# Number of investments: 6194
# Sum of investments: 237389.12036311626
#
# Number of Pairs (periods) with positive result (win): 4456
# Sum of Pairs (periods) with positive result (win): 28056.42092745006
#
# Number of Pairs (periods) with negative result (lost): 1736
# Sum of Pairs (periods) with negative result (lost): -6372.3908328861
#
# ------------------------------------------------------
# Length of period: 95
# Number of all Buy/Sell Pairs (periods): 6193
# Sum of all Buy/Sell Pairs (periods): 21907.493911266327
# Number of investments: 6193
# Sum of investments: 237164.89386165142
#
# Number of Pairs (periods) with positive result (win): 4467
# Sum of Pairs (periods) with positive result (win): 28249.835963577032
#
# Number of Pairs (periods) with negative result (lost): 1725
# Sum of Pairs (periods) with negative result (lost): -6342.342052310705
#
# ...
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6255
# Number of all Buy/Sell Pairs (periods): 33
# Sum of all Buy/Sell Pairs (periods): 7936.683822929859
# Number of investments: 33
# Sum of investments: 26.37092560529709
#
# Number of Pairs (periods) with positive result (win): 33
# Sum of Pairs (periods) with positive result (win): 7936.683822929859
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6256
# Number of all Buy/Sell Pairs (periods): 32
# Sum of all Buy/Sell Pairs (periods): 7713.564340054989
# Number of investments: 32
# Sum of investments: 25.506674349308014
#
# Number of Pairs (periods) with positive result (win): 32
# Sum of Pairs (periods) with positive result (win): 7713.564340054989
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6257
# Number of all Buy/Sell Pairs (periods): 31
# Sum of all Buy/Sell Pairs (periods): 7489.550191044807
# Number of investments: 31
# Sum of investments: 24.64806640148163
#
# Number of Pairs (periods) with positive result (win): 31
# Sum of Pairs (periods) with positive result (win): 7489.550191044807
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6258
# Number of all Buy/Sell Pairs (periods): 30
# Sum of all Buy/Sell Pairs (periods): 7262.476115047932
# Number of investments: 30
# Sum of investments: 23.75278204679489
#
# Number of Pairs (periods) with positive result (win): 30
# Sum of Pairs (periods) with positive result (win): 7262.476115047932
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6259
# Number of all Buy/Sell Pairs (periods): 29
# Sum of all Buy/Sell Pairs (periods): 7038.594534635544
# Number of investments: 29
# Sum of investments: 22.881478548049927
#
# Number of Pairs (periods) with positive result (win): 29
# Sum of Pairs (periods) with positive result (win): 7038.594534635544
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6260
# Number of all Buy/Sell Pairs (periods): 28
# Sum of all Buy/Sell Pairs (periods): 6811.643127322197
# Number of investments: 28
# Sum of investments: 22.063308835029602
#
# Number of Pairs (periods) with positive result (win): 28
# Sum of Pairs (periods) with positive result (win): 6811.643127322197
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6261
# Number of all Buy/Sell Pairs (periods): 27
# Sum of all Buy/Sell Pairs (periods): 6584.467751741409
# Number of investments: 27
# Sum of investments: 21.209402799606323
#
# Number of Pairs (periods) with positive result (win): 27
# Sum of Pairs (periods) with positive result (win): 6584.467751741409
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6262
# Number of all Buy/Sell Pairs (periods): 26
# Sum of all Buy/Sell Pairs (periods): 6356.566584825516
# Number of investments: 26
# Sum of investments: 20.362080335617065
#
# Number of Pairs (periods) with positive result (win): 26
# Sum of Pairs (periods) with positive result (win): 6356.566584825516
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6263
# Number of all Buy/Sell Pairs (periods): 25
# Sum of all Buy/Sell Pairs (periods): 6129.161808371544
# Number of investments: 25
# Sum of investments: 19.49782907962799
#
# Number of Pairs (periods) with positive result (win): 25
# Sum of Pairs (periods) with positive result (win): 6129.161808371544
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6264
# Number of all Buy/Sell Pairs (periods): 24
# Sum of all Buy/Sell Pairs (periods): 5900.402407348156
# Number of investments: 24
# Sum of investments: 18.639691650867462
#
# Number of Pairs (periods) with positive result (win): 24
# Sum of Pairs (periods) with positive result (win): 5900.402407348156
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6265
# Number of all Buy/Sell Pairs (periods): 23
# Sum of all Buy/Sell Pairs (periods): 5668.600692093372
# Number of investments: 23
# Sum of investments: 17.827164351940155
#
# Number of Pairs (periods) with positive result (win): 23
# Sum of Pairs (periods) with positive result (win): 5668.600692093372
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6266
# Number of all Buy/Sell Pairs (periods): 22
# Sum of all Buy/Sell Pairs (periods): 5434.576119244099
# Number of investments: 22
# Sum of investments: 17.049903094768524
#
# Number of Pairs (periods) with positive result (win): 22
# Sum of Pairs (periods) with positive result (win): 5434.576119244099
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6267
# Number of all Buy/Sell Pairs (periods): 21
# Sum of all Buy/Sell Pairs (periods): 5200.647542834282
# Number of investments: 21
# Sum of investments: 16.30649769306183
#
# Number of Pairs (periods) with positive result (win): 21
# Sum of Pairs (periods) with positive result (win): 5200.647542834282
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6268
# Number of all Buy/Sell Pairs (periods): 20
# Sum of all Buy/Sell Pairs (periods): 4964.332412183285
# Number of investments: 20
# Sum of investments: 15.552277147769928
#
# Number of Pairs (periods) with positive result (win): 20
# Sum of Pairs (periods) with positive result (win): 4964.332412183285
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6269
# Number of all Buy/Sell Pairs (periods): 19
# Sum of all Buy/Sell Pairs (periods): 4725.786106109619
# Number of investments: 19
# Sum of investments: 14.771724700927734
#
# Number of Pairs (periods) with positive result (win): 19
# Sum of Pairs (periods) with positive result (win): 4725.786106109619
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6270
# Number of all Buy/Sell Pairs (periods): 18
# Sum of all Buy/Sell Pairs (periods): 4484.167172431946
# Number of investments: 18
# Sum of investments: 14.007159233093262
#
# Number of Pairs (periods) with positive result (win): 18
# Sum of Pairs (periods) with positive result (win): 4484.167172431946
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6271
# Number of all Buy/Sell Pairs (periods): 17
# Sum of all Buy/Sell Pairs (periods): 4242.25164359808
# Number of investments: 17
# Sum of investments: 13.179585039615631
#
# Number of Pairs (periods) with positive result (win): 17
# Sum of Pairs (periods) with positive result (win): 4242.25164359808
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6272
# Number of all Buy/Sell Pairs (periods): 16
# Sum of all Buy/Sell Pairs (periods): 4000.3075568675995
# Number of investments: 16
# Sum of investments: 12.350600481033325
#
# Number of Pairs (periods) with positive result (win): 16
# Sum of Pairs (periods) with positive result (win): 4000.3075568675995
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6273
# Number of all Buy/Sell Pairs (periods): 15
# Sum of all Buy/Sell Pairs (periods): 3758.5787704586983
# Number of investments: 15
# Sum of investments: 11.506098926067352
#
# Number of Pairs (periods) with positive result (win): 15
# Sum of Pairs (periods) with positive result (win): 3758.5787704586983
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6274
# Number of all Buy/Sell Pairs (periods): 14
# Sum of all Buy/Sell Pairs (periods): 3512.8991280794144
# Number of investments: 14
# Sum of investments: 10.706737399101257
#
# Number of Pairs (periods) with positive result (win): 14
# Sum of Pairs (periods) with positive result (win): 3512.8991280794144
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6275
# Number of all Buy/Sell Pairs (periods): 13
# Sum of all Buy/Sell Pairs (periods): 3266.2386976480484
# Number of investments: 13
# Sum of investments: 9.869288802146912
#
# Number of Pairs (periods) with positive result (win): 13
# Sum of Pairs (periods) with positive result (win): 3266.2386976480484
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6276
# Number of all Buy/Sell Pairs (periods): 12
# Sum of all Buy/Sell Pairs (periods): 3020.8733196258545
# Number of investments: 12
# Sum of investments: 9.015382766723633
#
# Number of Pairs (periods) with positive result (win): 12
# Sum of Pairs (periods) with positive result (win): 3020.8733196258545
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6277
# Number of all Buy/Sell Pairs (periods): 11
# Sum of all Buy/Sell Pairs (periods): 2773.9873489141464
# Number of investments: 11
# Sum of investments: 8.213670372962952
#
# Number of Pairs (periods) with positive result (win): 11
# Sum of Pairs (periods) with positive result (win): 2773.9873489141464
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6278
# Number of all Buy/Sell Pairs (periods): 10
# Sum of all Buy/Sell Pairs (periods): 2526.9118290543556
# Number of investments: 10
# Sum of investments: 7.431707322597504
#
# Number of Pairs (periods) with positive result (win): 10
# Sum of Pairs (periods) with positive result (win): 2526.9118290543556
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6279
# Number of all Buy/Sell Pairs (periods): 9
# Sum of all Buy/Sell Pairs (periods): 2276.9031779170036
# Number of investments: 9
# Sum of investments: 6.676076233386993
#
# Number of Pairs (periods) with positive result (win): 9
# Sum of Pairs (periods) with positive result (win): 2276.9031779170036
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6280
# Number of all Buy/Sell Pairs (periods): 8
# Sum of all Buy/Sell Pairs (periods): 2024.4294674396515
# Number of investments: 8
# Sum of investments: 5.948187589645386
#
# Number of Pairs (periods) with positive result (win): 8
# Sum of Pairs (periods) with positive result (win): 2024.4294674396515
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6281
# Number of all Buy/Sell Pairs (periods): 7
# Sum of all Buy/Sell Pairs (periods): 1777.3078414201736
# Number of investments: 7
# Sum of investments: 5.2922409772872925
#
# Number of Pairs (periods) with positive result (win): 7
# Sum of Pairs (periods) with positive result (win): 1777.3078414201736
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6282
# Number of all Buy/Sell Pairs (periods): 6
# Sum of all Buy/Sell Pairs (periods): 1528.489981174469
# Number of investments: 6
# Sum of investments: 4.594445705413818
#
# Number of Pairs (periods) with positive result (win): 6
# Sum of Pairs (periods) with positive result (win): 1528.489981174469
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6283
# Number of all Buy/Sell Pairs (periods): 5
# Sum of all Buy/Sell Pairs (periods): 1275.0148832201958
# Number of investments: 5
# Sum of investments: 3.8590334057807922
#
# Number of Pairs (periods) with positive result (win): 5
# Sum of Pairs (periods) with positive result (win): 1275.0148832201958
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6284
# Number of all Buy/Sell Pairs (periods): 4
# Sum of all Buy/Sell Pairs (periods): 1020.7738068699837
# Number of investments: 4
# Sum of investments: 3.1104552149772644
#
# Number of Pairs (periods) with positive result (win): 4
# Sum of Pairs (periods) with positive result (win): 1020.7738068699837
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6285
# Number of all Buy/Sell Pairs (periods): 3
# Sum of all Buy/Sell Pairs (periods): 763.5720866322517
# Number of investments: 3
# Sum of investments: 2.395732581615448
#
# Number of Pairs (periods) with positive result (win): 3
# Sum of Pairs (periods) with positive result (win): 763.5720866322517
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6286
# Number of all Buy/Sell Pairs (periods): 2
# Sum of all Buy/Sell Pairs (periods): 505.61901557445526
# Number of investments: 2
# Sum of investments: 1.6132994890213013
#
# Number of Pairs (periods) with positive result (win): 2
# Sum of Pairs (periods) with positive result (win): 505.61901557445526
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 6287
# Number of all Buy/Sell Pairs (periods): 1
# Sum of all Buy/Sell Pairs (periods): 251.08086878061295
# Number of investments: 1
# Sum of investments: 0.8421506285667419
#
# Number of Pairs (periods) with positive result (win): 1
# Sum of Pairs (periods) with positive result (win): 251.08086878061295
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# Creating the plot
plt.plot(period_lengths, corresponding_results)

# Adding title and labels
plt.title("Result vs. period length")
plt.xlabel("Length of Stay in Market")
plt.ylabel("Result")

# Enabling grid
plt.grid(True)

# Finding the maximum y value and its corresponding x
max_y = max(corresponding_results)
max_x = period_lengths[corresponding_results.index(max_y)]

# Plotting the maximum y value
plt.plot(max_x, max_y, 'ro')  # 'ro' stands for red circle marker

# Annotating the maximum y value and corresponding x value
plt.annotate(f'Max y = {max_y} at x = {max_x}', 
             (max_x, max_y), 
             textcoords="offset points", 
             xytext=(0, 10), 
             ha='center')

# Display the plot
plt.show()

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=max_x)

print(f"Period length (stay in market): {max_x}")
print(f"Max Result: {max_y}")
print()

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Period length (stay in market): 3144
# Max Result: 236453.31464588642
#
# Number of all Buy/Sell Pairs (periods): 3144
# Sum of all Buy/Sell Pairs (periods): 236453.31464588642
# Number of investments: 3144
# Sum of investments: 11350.94894015789
#
# Number of Pairs (periods) with positive result (win): 3144
# Sum of Pairs (periods) with positive result (win): 236453.31464588642
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0

# %%
total_investement = sum(investments)

share_return = round((max_y/total_investement) * 100, 2) 

print("Invested: ", total_investement)
print("Lost/Win: ", max_y)
print(f"Share Return: {share_return} %")
# Out:
# Invested:  11350.94894015789
# Lost/Win:  236453.31464588642
# Share Return: 2083.11 %

# %%
buy_price_at_start = stock_close_prices.values[0][0]
bought_shares = total_investement/buy_price_at_start
sell_price_at_end = stock_close_prices.values[len(stock_close_prices)-1][0]
profit = (bought_shares*sell_price_at_end) - (bought_shares*buy_price_at_start)

print("One-time Investment: ", total_investement)
print("One-time Investment - Lost/Win: ", profit)
print(f"One-time Investment Share Return: {(profit/total_investement) * 100} %")
# Out:
# One-time Investment:  11350.94894015789
# One-time Investment - Lost/Win:  3384199.957470379
# One-time Investment Share Return: 29814.247031784333 %
