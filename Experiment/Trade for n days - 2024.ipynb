# %%
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
# Download historical stock data for a specific ticker
ticker = 'AAPL'

stock_data = yf.download(ticker, start='2024-01-01', end='2024-12-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
display(stock_data)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-01-02  184.532089  187.315382  182.792533  186.033072  82488700
# 2024-01-03  183.150391  184.770668  182.335277  183.120571  58414500
# 2024-01-04  180.824341  181.997291  179.800489  181.062899  71983600
# 2024-01-05  180.098709  181.669281  179.094742  180.903888  62303300
# 2024-01-08  184.452560  184.492330  180.416793  181.003268  59144500
# ...                ...         ...         ...         ...       ...
# 2024-12-23  254.989655  255.369227  253.171646  254.490204  40858800
# 2024-12-24  257.916443  257.926411  255.009620  255.209412  23234700
# 2024-12-26  258.735504  259.814335  257.347047  257.906429  27237100
# 2024-12-27  255.309296  258.415896  252.782075  257.546826  42355300
# 2024-12-30  251.923019  253.221595  250.474615  251.952985  35557500
#
# [251 rows x 5 columns]

# %%
print("Number of open trading days in market: ", len(stock_data))
# Out:
# Number of open trading days in market:  251

# %%
stock_close_prices = stock_data['Close']

# %%
def evaluate_trade_period(prices, period_length):
    investments = []
    prices_values = stock_close_prices.values
    if period_length >= len(prices) or period_length <= 0:
        raise ValueError("period_length should be less than len(prices) and bigger than 0")
        
    result_list = []
    for i in range(0, len(prices_values)-period_length, 1):
        buy_price = prices_values[i][0]
        investments.append(buy_price)
        sell_price = prices_values[i+period_length][0]
        result_list.append(float(sell_price-buy_price))
        
    return np.array(result_list), np.array(investments)

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=1)

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Number of all Buy/Sell Pairs (periods): 250
# Sum of all Buy/Sell Pairs (periods): 67.39093017578125
# Number of investments: 250
# Sum of investments: 51546.76379394531
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 298.3389587402344
#
# Number of Pairs (periods) with negative result (lost): 107
# Sum of Pairs (periods) with negative result (lost): -230.94802856445312

# %%
period_lengths, corresponding_results = [], []
for i in range(1, len(stock_close_prices), 1):
    result_list, investments = evaluate_trade_period(stock_close_prices, period_length=i)
    period_lengths.append(i)
    corresponding_results.append(sum(result_list))

    print(f"Length of period: {i}")
    print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
    print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
    print(f"Number of investments: {len(investments)}")
    print(f"Sum of investments: {sum(investments)}")
    print()
    
    positive_results = result_list[result_list > 0]
    print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
    print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
    print()
    
    negative_results = result_list[result_list < 0]
    print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
    print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
    print()
    print("------------------------------------------------------")
# Out:
# Length of period: 1
# Number of all Buy/Sell Pairs (periods): 250
# Sum of all Buy/Sell Pairs (periods): 67.39093017578125
# Number of investments: 250
# Sum of investments: 51546.76379394531
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 298.3389587402344
#
# Number of Pairs (periods) with negative result (lost): 107
# Sum of Pairs (periods) with negative result (lost): -230.94802856445312
#
# ------------------------------------------------------
# Length of period: 2
# Number of all Buy/Sell Pairs (periods): 249
# Sum of all Buy/Sell Pairs (periods): 139.54983520507812
# Number of investments: 249
# Sum of investments: 51291.454498291016
#
# Number of Pairs (periods) with positive result (win): 143
# Sum of Pairs (periods) with positive result (win): 459.7155456542969
#
# Number of Pairs (periods) with negative result (lost): 106
# Sum of Pairs (periods) with negative result (lost): -320.16571044921875
#
# ------------------------------------------------------
# Length of period: 3
# Number of all Buy/Sell Pairs (periods): 248
# Sum of all Buy/Sell Pairs (periods): 217.46099853515625
# Number of investments: 248
# Sum of investments: 51032.718994140625
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 592.8000640869141
#
# Number of Pairs (periods) with negative result (lost): 94
# Sum of Pairs (periods) with negative result (lost): -375.3390655517578
#
# ------------------------------------------------------
# Length of period: 4
# Number of all Buy/Sell Pairs (periods): 247
# Sum of all Buy/Sell Pairs (periods): 295.2787322998047
# Number of investments: 247
# Sum of investments: 50774.80255126953
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 710.3899688720703
#
# Number of Pairs (periods) with negative result (lost): 96
# Sum of Pairs (periods) with negative result (lost): -415.1112365722656
#
# ------------------------------------------------------
# Length of period: 5
# Number of all Buy/Sell Pairs (periods): 246
# Sum of all Buy/Sell Pairs (periods): 365.8158264160156
# Number of investments: 246
# Sum of investments: 50519.812896728516
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 820.8647003173828
#
# Number of Pairs (periods) with negative result (lost): 99
# Sum of Pairs (periods) with negative result (lost): -455.0488739013672
#
# ------------------------------------------------------
# Length of period: 6
# Number of all Buy/Sell Pairs (periods): 245
# Sum of all Buy/Sell Pairs (periods): 435.9912567138672
# Number of investments: 245
# Sum of investments: 50265.60238647461
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 911.8419952392578
#
# Number of Pairs (periods) with negative result (lost): 100
# Sum of Pairs (periods) with negative result (lost): -475.8507385253906
#
# ------------------------------------------------------
# Length of period: 7
# Number of all Buy/Sell Pairs (periods): 244
# Sum of all Buy/Sell Pairs (periods): 500.4281005859375
# Number of investments: 244
# Sum of investments: 50016.08673095703
#
# Number of Pairs (periods) with positive result (win): 143
# Sum of Pairs (periods) with positive result (win): 1001.9205322265625
#
# Number of Pairs (periods) with negative result (lost): 100
# Sum of Pairs (periods) with negative result (lost): -501.492431640625
#
# ------------------------------------------------------
# Length of period: 8
# Number of all Buy/Sell Pairs (periods): 243
# Sum of all Buy/Sell Pairs (periods): 563.7232818603516
# Number of investments: 243
# Sum of investments: 49768.309158325195
#
# Number of Pairs (periods) with positive result (win): 138
# Sum of Pairs (periods) with positive result (win): 1097.756088256836
#
# Number of Pairs (periods) with negative result (lost): 105
# Sum of Pairs (periods) with negative result (lost): -534.0328063964844
#
# ------------------------------------------------------
# Length of period: 9
# Number of all Buy/Sell Pairs (periods): 242
# Sum of all Buy/Sell Pairs (periods): 632.1144714355469
# Number of investments: 242
# Sum of investments: 49515.1075592041
#
# Number of Pairs (periods) with positive result (win): 138
# Sum of Pairs (periods) with positive result (win): 1185.0366516113281
#
# Number of Pairs (periods) with negative result (lost): 104
# Sum of Pairs (periods) with negative result (lost): -552.9221801757812
#
# ------------------------------------------------------
# Length of period: 10
# Number of all Buy/Sell Pairs (periods): 241
# Sum of all Buy/Sell Pairs (periods): 700.3446807861328
# Number of investments: 241
# Sum of investments: 49264.34327697754
#
# Number of Pairs (periods) with positive result (win): 141
# Sum of Pairs (periods) with positive result (win): 1273.1364440917969
#
# Number of Pairs (periods) with negative result (lost): 100
# Sum of Pairs (periods) with negative result (lost): -572.7917633056641
#
# ------------------------------------------------------
# Length of period: 11
# Number of all Buy/Sell Pairs (periods): 240
# Sum of all Buy/Sell Pairs (periods): 766.6124267578125
# Number of investments: 240
# Sum of investments: 49016.48579406738
#
# Number of Pairs (periods) with positive result (win): 144
# Sum of Pairs (periods) with positive result (win): 1358.8113403320312
#
# Number of Pairs (periods) with negative result (lost): 96
# Sum of Pairs (periods) with negative result (lost): -592.1989135742188
#
# ------------------------------------------------------
# Length of period: 12
# Number of all Buy/Sell Pairs (periods): 239
# Sum of all Buy/Sell Pairs (periods): 826.7958679199219
# Number of investments: 239
# Sum of investments: 48768.798110961914
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 1445.609634399414
#
# Number of Pairs (periods) with negative result (lost): 94
# Sum of Pairs (periods) with negative result (lost): -618.8137664794922
#
# ------------------------------------------------------
# Length of period: 13
# Number of all Buy/Sell Pairs (periods): 238
# Sum of all Buy/Sell Pairs (periods): 882.5983734130859
# Number of investments: 238
# Sum of investments: 48522.5788269043
#
# Number of Pairs (periods) with positive result (win): 146
# Sum of Pairs (periods) with positive result (win): 1514.5496520996094
#
# Number of Pairs (periods) with negative result (lost): 92
# Sum of Pairs (periods) with negative result (lost): -631.9512786865234
#
# ------------------------------------------------------
# Length of period: 14
# Number of all Buy/Sell Pairs (periods): 237
# Sum of all Buy/Sell Pairs (periods): 937.3634185791016
# Number of investments: 237
# Sum of investments: 48275.08094787598
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 1575.7861633300781
#
# Number of Pairs (periods) with negative result (lost): 90
# Sum of Pairs (periods) with negative result (lost): -638.4227447509766
#
# ------------------------------------------------------
# Length of period: 15
# Number of all Buy/Sell Pairs (periods): 236
# Sum of all Buy/Sell Pairs (periods): 989.8272705078125
# Number of investments: 236
# Sum of investments: 48028.60194396973
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 1632.8302917480469
#
# Number of Pairs (periods) with negative result (lost): 94
# Sum of Pairs (periods) with negative result (lost): -643.0030212402344
#
# ------------------------------------------------------
# Length of period: 16
# Number of all Buy/Sell Pairs (periods): 235
# Sum of all Buy/Sell Pairs (periods): 1039.0613555908203
# Number of investments: 235
# Sum of investments: 47786.02865600586
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 1688.2776947021484
#
# Number of Pairs (periods) with negative result (lost): 93
# Sum of Pairs (periods) with negative result (lost): -649.2163391113281
#
# ------------------------------------------------------
# Length of period: 17
# Number of all Buy/Sell Pairs (periods): 234
# Sum of all Buy/Sell Pairs (periods): 1088.8232421875
# Number of investments: 234
# Sum of investments: 47543.2555847168
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 1735.7494812011719
#
# Number of Pairs (periods) with negative result (lost): 92
# Sum of Pairs (periods) with negative result (lost): -646.9262390136719
#
# ------------------------------------------------------
# Length of period: 18
# Number of all Buy/Sell Pairs (periods): 233
# Sum of all Buy/Sell Pairs (periods): 1140.2947235107422
# Number of investments: 233
# Sum of investments: 47300.51248168945
#
# Number of Pairs (periods) with positive result (win): 142
# Sum of Pairs (periods) with positive result (win): 1791.2684631347656
#
# Number of Pairs (periods) with negative result (lost): 91
# Sum of Pairs (periods) with negative result (lost): -650.9737396240234
#
# ------------------------------------------------------
# Length of period: 19
# Number of all Buy/Sell Pairs (periods): 232
# Sum of all Buy/Sell Pairs (periods): 1192.0924835205078
# Number of investments: 232
# Sum of investments: 47058.128982543945
#
# Number of Pairs (periods) with positive result (win): 144
# Sum of Pairs (periods) with positive result (win): 1838.2567291259766
#
# Number of Pairs (periods) with negative result (lost): 88
# Sum of Pairs (periods) with negative result (lost): -646.1642456054688
#
# ------------------------------------------------------
# Length of period: 20
# Number of all Buy/Sell Pairs (periods): 231
# Sum of all Buy/Sell Pairs (periods): 1244.5015869140625
# Number of investments: 231
# Sum of investments: 46818.80212402344
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 1887.8716888427734
#
# Number of Pairs (periods) with negative result (lost): 81
# Sum of Pairs (periods) with negative result (lost): -643.3701019287109
#
# ------------------------------------------------------
# Length of period: 21
# Number of all Buy/Sell Pairs (periods): 230
# Sum of all Buy/Sell Pairs (periods): 1298.2714538574219
# Number of investments: 230
# Sum of investments: 46581.73277282715
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 1940.4722137451172
#
# Number of Pairs (periods) with negative result (lost): 79
# Sum of Pairs (periods) with negative result (lost): -642.2007598876953
#
# ------------------------------------------------------
# Length of period: 22
# Number of all Buy/Sell Pairs (periods): 229
# Sum of all Buy/Sell Pairs (periods): 1347.1986083984375
# Number of investments: 229
# Sum of investments: 46347.060791015625
#
# Number of Pairs (periods) with positive result (win): 144
# Sum of Pairs (periods) with positive result (win): 1992.2705078125
#
# Number of Pairs (periods) with negative result (lost): 85
# Sum of Pairs (periods) with negative result (lost): -645.0718994140625
#
# ------------------------------------------------------
# Length of period: 23
# Number of all Buy/Sell Pairs (periods): 228
# Sum of all Buy/Sell Pairs (periods): 1397.2596130371094
# Number of investments: 228
# Sum of investments: 46112.25895690918
#
# Number of Pairs (periods) with positive result (win): 144
# Sum of Pairs (periods) with positive result (win): 2054.1400146484375
#
# Number of Pairs (periods) with negative result (lost): 84
# Sum of Pairs (periods) with negative result (lost): -656.8804016113281
#
# ------------------------------------------------------
# Length of period: 24
# Number of all Buy/Sell Pairs (periods): 227
# Sum of all Buy/Sell Pairs (periods): 1443.313949584961
# Number of investments: 227
# Sum of investments: 45879.64471435547
#
# Number of Pairs (periods) with positive result (win): 141
# Sum of Pairs (periods) with positive result (win): 2097.3173828125
#
# Number of Pairs (periods) with negative result (lost): 86
# Sum of Pairs (periods) with negative result (lost): -654.0034332275391
#
# ------------------------------------------------------
# Length of period: 25
# Number of all Buy/Sell Pairs (periods): 226
# Sum of all Buy/Sell Pairs (periods): 1484.76123046875
# Number of investments: 226
# Sum of investments: 45650.02717590332
#
# Number of Pairs (periods) with positive result (win): 138
# Sum of Pairs (periods) with positive result (win): 2126.273727416992
#
# Number of Pairs (periods) with negative result (lost): 88
# Sum of Pairs (periods) with negative result (lost): -641.5124969482422
#
# ------------------------------------------------------
# Length of period: 26
# Number of all Buy/Sell Pairs (periods): 225
# Sum of all Buy/Sell Pairs (periods): 1524.7506561279297
# Number of investments: 225
# Sum of investments: 45421.75814819336
#
# Number of Pairs (periods) with positive result (win): 141
# Sum of Pairs (periods) with positive result (win): 2164.0906982421875
#
# Number of Pairs (periods) with negative result (lost): 84
# Sum of Pairs (periods) with negative result (lost): -639.3400421142578
#
# ------------------------------------------------------
# Length of period: 27
# Number of all Buy/Sell Pairs (periods): 224
# Sum of all Buy/Sell Pairs (periods): 1566.3030242919922
# Number of investments: 224
# Sum of investments: 45193.00965881348
#
# Number of Pairs (periods) with positive result (win): 140
# Sum of Pairs (periods) with positive result (win): 2189.2217864990234
#
# Number of Pairs (periods) with negative result (lost): 84
# Sum of Pairs (periods) with negative result (lost): -622.9187622070312
#
# ------------------------------------------------------
# Length of period: 28
# Number of all Buy/Sell Pairs (periods): 223
# Sum of all Buy/Sell Pairs (periods): 1606.3698272705078
# Number of investments: 223
# Sum of investments: 44964.980377197266
#
# Number of Pairs (periods) with positive result (win): 140
# Sum of Pairs (periods) with positive result (win): 2211.562728881836
#
# Number of Pairs (periods) with negative result (lost): 83
# Sum of Pairs (periods) with negative result (lost): -605.1929016113281
#
# ------------------------------------------------------
# Length of period: 29
# Number of all Buy/Sell Pairs (periods): 222
# Sum of all Buy/Sell Pairs (periods): 1647.8689422607422
# Number of investments: 222
# Sum of investments: 44737.2108001709
#
# Number of Pairs (periods) with positive result (win): 138
# Sum of Pairs (periods) with positive result (win): 2242.6051483154297
#
# Number of Pairs (periods) with negative result (lost): 84
# Sum of Pairs (periods) with negative result (lost): -594.7362060546875
#
# ------------------------------------------------------
# Length of period: 30
# Number of all Buy/Sell Pairs (periods): 221
# Sum of all Buy/Sell Pairs (periods): 1688.4514617919922
# Number of investments: 221
# Sum of investments: 44512.457916259766
#
# Number of Pairs (periods) with positive result (win): 139
# Sum of Pairs (periods) with positive result (win): 2294.454055786133
#
# Number of Pairs (periods) with negative result (lost): 82
# Sum of Pairs (periods) with negative result (lost): -606.0025939941406
#
# ------------------------------------------------------
# Length of period: 31
# Number of all Buy/Sell Pairs (periods): 220
# Sum of all Buy/Sell Pairs (periods): 1733.1362609863281
# Number of investments: 220
# Sum of investments: 44284.4885559082
#
# Number of Pairs (periods) with positive result (win): 140
# Sum of Pairs (periods) with positive result (win): 2339.079116821289
#
# Number of Pairs (periods) with negative result (lost): 80
# Sum of Pairs (periods) with negative result (lost): -605.9428558349609
#
# ------------------------------------------------------
# Length of period: 32
# Number of all Buy/Sell Pairs (periods): 219
# Sum of all Buy/Sell Pairs (periods): 1775.0130920410156
# Number of investments: 219
# Sum of investments: 44059.615798950195
#
# Number of Pairs (periods) with positive result (win): 144
# Sum of Pairs (periods) with positive result (win): 2399.4093017578125
#
# Number of Pairs (periods) with negative result (lost): 75
# Sum of Pairs (periods) with negative result (lost): -624.3962097167969
#
# ------------------------------------------------------
# Length of period: 33
# Number of all Buy/Sell Pairs (periods): 218
# Sum of all Buy/Sell Pairs (periods): 1817.5436401367188
# Number of investments: 218
# Sum of investments: 43835.632064819336
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 2455.7108306884766
#
# Number of Pairs (periods) with negative result (lost): 73
# Sum of Pairs (periods) with negative result (lost): -638.1671905517578
#
# ------------------------------------------------------
# Length of period: 34
# Number of all Buy/Sell Pairs (periods): 217
# Sum of all Buy/Sell Pairs (periods): 1860.8206481933594
# Number of investments: 217
# Sum of investments: 43611.64833068848
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 2507.9757537841797
#
# Number of Pairs (periods) with negative result (lost): 72
# Sum of Pairs (periods) with negative result (lost): -647.1551055908203
#
# ------------------------------------------------------
# Length of period: 35
# Number of all Buy/Sell Pairs (periods): 216
# Sum of all Buy/Sell Pairs (periods): 1906.0682220458984
# Number of investments: 216
# Sum of investments: 43384.937591552734
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 2564.4186401367188
#
# Number of Pairs (periods) with negative result (lost): 71
# Sum of Pairs (periods) with negative result (lost): -658.3504180908203
#
# ------------------------------------------------------
# Length of period: 36
# Number of all Buy/Sell Pairs (periods): 215
# Sum of all Buy/Sell Pairs (periods): 1949.5451354980469
# Number of investments: 215
# Sum of investments: 43157.95715332031
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 2621.7823333740234
#
# Number of Pairs (periods) with negative result (lost): 70
# Sum of Pairs (periods) with negative result (lost): -672.2371978759766
#
# ------------------------------------------------------
# Length of period: 37
# Number of all Buy/Sell Pairs (periods): 214
# Sum of all Buy/Sell Pairs (periods): 1990.1138000488281
# Number of investments: 214
# Sum of investments: 42935.72625732422
#
# Number of Pairs (periods) with positive result (win): 146
# Sum of Pairs (periods) with positive result (win): 2665.6312713623047
#
# Number of Pairs (periods) with negative result (lost): 68
# Sum of Pairs (periods) with negative result (lost): -675.5174713134766
#
# ------------------------------------------------------
# Length of period: 38
# Number of all Buy/Sell Pairs (periods): 213
# Sum of all Buy/Sell Pairs (periods): 2032.7644805908203
# Number of investments: 213
# Sum of investments: 42712.76696777344
#
# Number of Pairs (periods) with positive result (win): 152
# Sum of Pairs (periods) with positive result (win): 2721.378616333008
#
# Number of Pairs (periods) with negative result (lost): 61
# Sum of Pairs (periods) with negative result (lost): -688.6141357421875
#
# ------------------------------------------------------
# Length of period: 39
# Number of all Buy/Sell Pairs (periods): 212
# Sum of all Buy/Sell Pairs (periods): 2072.5152282714844
# Number of investments: 212
# Sum of investments: 42491.24452209473
#
# Number of Pairs (periods) with positive result (win): 154
# Sum of Pairs (periods) with positive result (win): 2769.5960998535156
#
# Number of Pairs (periods) with negative result (lost): 58
# Sum of Pairs (periods) with negative result (lost): -697.0808715820312
#
# ------------------------------------------------------
# Length of period: 40
# Number of all Buy/Sell Pairs (periods): 211
# Sum of all Buy/Sell Pairs (periods): 2114.3683013916016
# Number of investments: 211
# Sum of investments: 42268.82405090332
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 2825.8636474609375
#
# Number of Pairs (periods) with negative result (lost): 58
# Sum of Pairs (periods) with negative result (lost): -711.4953460693359
#
# ------------------------------------------------------
# Length of period: 41
# Number of all Buy/Sell Pairs (periods): 210
# Sum of all Buy/Sell Pairs (periods): 2159.8816528320312
# Number of investments: 210
# Sum of investments: 42043.41015625
#
# Number of Pairs (periods) with positive result (win): 154
# Sum of Pairs (periods) with positive result (win): 2883.5531158447266
#
# Number of Pairs (periods) with negative result (lost): 56
# Sum of Pairs (periods) with negative result (lost): -723.6714630126953
#
# ------------------------------------------------------
# Length of period: 42
# Number of all Buy/Sell Pairs (periods): 209
# Sum of all Buy/Sell Pairs (periods): 2210.660675048828
# Number of investments: 209
# Sum of investments: 41813.81547546387
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 2937.3544311523438
#
# Number of Pairs (periods) with negative result (lost): 56
# Sum of Pairs (periods) with negative result (lost): -726.6937561035156
#
# ------------------------------------------------------
# Length of period: 43
# Number of all Buy/Sell Pairs (periods): 208
# Sum of all Buy/Sell Pairs (periods): 2269.5404052734375
# Number of investments: 208
# Sum of investments: 41580.658630371094
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 2995.937728881836
#
# Number of Pairs (periods) with negative result (lost): 55
# Sum of Pairs (periods) with negative result (lost): -726.3973236083984
#
# ------------------------------------------------------
# Length of period: 44
# Number of all Buy/Sell Pairs (periods): 207
# Sum of all Buy/Sell Pairs (periods): 2333.1073608398438
# Number of investments: 207
# Sum of investments: 41347.77119445801
#
# Number of Pairs (periods) with positive result (win): 154
# Sum of Pairs (periods) with positive result (win): 3055.3143310546875
#
# Number of Pairs (periods) with negative result (lost): 53
# Sum of Pairs (periods) with negative result (lost): -722.2069702148438
#
# ------------------------------------------------------
# Length of period: 45
# Number of all Buy/Sell Pairs (periods): 206
# Sum of all Buy/Sell Pairs (periods): 2395.6839904785156
# Number of investments: 206
# Sum of investments: 41116.869384765625
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 3102.820343017578
#
# Number of Pairs (periods) with negative result (lost): 53
# Sum of Pairs (periods) with negative result (lost): -707.1363525390625
#
# ------------------------------------------------------
# Length of period: 46
# Number of all Buy/Sell Pairs (periods): 205
# Sum of all Buy/Sell Pairs (periods): 2457.5419158935547
# Number of investments: 205
# Sum of investments: 40886.80570983887
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 3149.220245361328
#
# Number of Pairs (periods) with negative result (lost): 54
# Sum of Pairs (periods) with negative result (lost): -691.6783294677734
#
# ------------------------------------------------------
# Length of period: 47
# Number of all Buy/Sell Pairs (periods): 204
# Sum of all Buy/Sell Pairs (periods): 2517.8675231933594
# Number of investments: 204
# Sum of investments: 40656.552474975586
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 3196.687255859375
#
# Number of Pairs (periods) with negative result (lost): 54
# Sum of Pairs (periods) with negative result (lost): -678.8197326660156
#
# ------------------------------------------------------
# Length of period: 48
# Number of all Buy/Sell Pairs (periods): 203
# Sum of all Buy/Sell Pairs (periods): 2581.2714233398438
# Number of investments: 203
# Sum of investments: 40421.21043395996
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 3245.983901977539
#
# Number of Pairs (periods) with negative result (lost): 53
# Sum of Pairs (periods) with negative result (lost): -664.7124786376953
#
# ------------------------------------------------------
# Length of period: 49
# Number of all Buy/Sell Pairs (periods): 202
# Sum of all Buy/Sell Pairs (periods): 2644.8162384033203
# Number of investments: 202
# Sum of investments: 40185.249755859375
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 3296.266311645508
#
# Number of Pairs (periods) with negative result (lost): 51
# Sum of Pairs (periods) with negative result (lost): -651.4500732421875
#
# ------------------------------------------------------
# Length of period: 50
# Number of all Buy/Sell Pairs (periods): 201
# Sum of all Buy/Sell Pairs (periods): 2708.974380493164
# Number of investments: 201
# Sum of investments: 39950.76583862305
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 3344.6617584228516
#
# Number of Pairs (periods) with negative result (lost): 52
# Sum of Pairs (periods) with negative result (lost): -635.6873779296875
#
# ------------------------------------------------------
# Length of period: 51
# Number of all Buy/Sell Pairs (periods): 200
# Sum of all Buy/Sell Pairs (periods): 2768.4275970458984
# Number of investments: 200
# Sum of investments: 39719.12565612793
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 3390.6537017822266
#
# Number of Pairs (periods) with negative result (lost): 53
# Sum of Pairs (periods) with negative result (lost): -622.2261047363281
#
# ------------------------------------------------------
# Length of period: 52
# Number of all Buy/Sell Pairs (periods): 199
# Sum of all Buy/Sell Pairs (periods): 2827.889862060547
# Number of investments: 199
# Sum of investments: 39487.85466003418
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 3433.4801635742188
#
# Number of Pairs (periods) with negative result (lost): 51
# Sum of Pairs (periods) with negative result (lost): -605.5903015136719
#
# ------------------------------------------------------
# Length of period: 53
# Number of all Buy/Sell Pairs (periods): 198
# Sum of all Buy/Sell Pairs (periods): 2888.322738647461
# Number of investments: 198
# Sum of investments: 39254.51820373535
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 3473.3939819335938
#
# Number of Pairs (periods) with negative result (lost): 53
# Sum of Pairs (periods) with negative result (lost): -585.0712432861328
#
# ------------------------------------------------------
# Length of period: 54
# Number of all Buy/Sell Pairs (periods): 197
# Sum of all Buy/Sell Pairs (periods): 2943.8623046875
# Number of investments: 197
# Sum of investments: 39023.726150512695
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 3519.889129638672
#
# Number of Pairs (periods) with negative result (lost): 50
# Sum of Pairs (periods) with negative result (lost): -576.0268249511719
#
# ------------------------------------------------------
# Length of period: 55
# Number of all Buy/Sell Pairs (periods): 196
# Sum of all Buy/Sell Pairs (periods): 2993.082290649414
# Number of investments: 196
# Sum of investments: 38796.675857543945
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 3569.5626373291016
#
# Number of Pairs (periods) with negative result (lost): 49
# Sum of Pairs (periods) with negative result (lost): -576.4803466796875
#
# ------------------------------------------------------
# Length of period: 56
# Number of all Buy/Sell Pairs (periods): 195
# Sum of all Buy/Sell Pairs (periods): 3051.054702758789
# Number of investments: 195
# Sum of investments: 38568.13883972168
#
# Number of Pairs (periods) with positive result (win): 146
# Sum of Pairs (periods) with positive result (win): 3609.2863159179688
#
# Number of Pairs (periods) with negative result (lost): 49
# Sum of Pairs (periods) with negative result (lost): -558.2316131591797
#
# ------------------------------------------------------
# Length of period: 57
# Number of all Buy/Sell Pairs (periods): 194
# Sum of all Buy/Sell Pairs (periods): 3108.6202697753906
# Number of investments: 194
# Sum of investments: 38339.10292053223
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 3649.652313232422
#
# Number of Pairs (periods) with negative result (lost): 46
# Sum of Pairs (periods) with negative result (lost): -541.0320434570312
#
# ------------------------------------------------------
# Length of period: 58
# Number of all Buy/Sell Pairs (periods): 193
# Sum of all Buy/Sell Pairs (periods): 3163.847396850586
# Number of investments: 193
# Sum of investments: 38113.82872009277
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 3694.7682037353516
#
# Number of Pairs (periods) with negative result (lost): 43
# Sum of Pairs (periods) with negative result (lost): -530.9208068847656
#
# ------------------------------------------------------
# Length of period: 59
# Number of all Buy/Sell Pairs (periods): 192
# Sum of all Buy/Sell Pairs (periods): 3216.1381225585938
# Number of investments: 192
# Sum of investments: 37892.625564575195
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 3731.4842529296875
#
# Number of Pairs (periods) with negative result (lost): 42
# Sum of Pairs (periods) with negative result (lost): -515.3461303710938
#
# ------------------------------------------------------
# Length of period: 60
# Number of all Buy/Sell Pairs (periods): 191
# Sum of all Buy/Sell Pairs (periods): 3269.944564819336
# Number of investments: 191
# Sum of investments: 37666.32362365723
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 3769.438674926758
#
# Number of Pairs (periods) with negative result (lost): 41
# Sum of Pairs (periods) with negative result (lost): -499.4941101074219
#
# ------------------------------------------------------
# Length of period: 61
# Number of all Buy/Sell Pairs (periods): 190
# Sum of all Buy/Sell Pairs (periods): 3324.444869995117
# Number of investments: 190
# Sum of investments: 37441.14921569824
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 3808.931625366211
#
# Number of Pairs (periods) with negative result (lost): 42
# Sum of Pairs (periods) with negative result (lost): -484.48675537109375
#
# ------------------------------------------------------
# Length of period: 62
# Number of all Buy/Sell Pairs (periods): 189
# Sum of all Buy/Sell Pairs (periods): 3381.4959259033203
# Number of investments: 189
# Sum of investments: 37214.86723327637
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 3848.0107421875
#
# Number of Pairs (periods) with negative result (lost): 40
# Sum of Pairs (periods) with negative result (lost): -466.5148162841797
#
# ------------------------------------------------------
# Length of period: 63
# Number of all Buy/Sell Pairs (periods): 188
# Sum of all Buy/Sell Pairs (periods): 3439.1626586914062
# Number of investments: 188
# Sum of investments: 36989.15399169922
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 3883.4444274902344
#
# Number of Pairs (periods) with negative result (lost): 37
# Sum of Pairs (periods) with negative result (lost): -444.2817687988281
#
# ------------------------------------------------------
# Length of period: 64
# Number of all Buy/Sell Pairs (periods): 187
# Sum of all Buy/Sell Pairs (periods): 3502.798294067383
# Number of investments: 187
# Sum of investments: 36756.66566467285
#
# Number of Pairs (periods) with positive result (win): 152
# Sum of Pairs (periods) with positive result (win): 3921.881103515625
#
# Number of Pairs (periods) with negative result (lost): 35
# Sum of Pairs (periods) with negative result (lost): -419.0828094482422
#
# ------------------------------------------------------
# Length of period: 65
# Number of all Buy/Sell Pairs (periods): 186
# Sum of all Buy/Sell Pairs (periods): 3562.0614318847656
# Number of investments: 186
# Sum of investments: 36529.375915527344
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 3956.538314819336
#
# Number of Pairs (periods) with negative result (lost): 33
# Sum of Pairs (periods) with negative result (lost): -394.4768829345703
#
# ------------------------------------------------------
# Length of period: 66
# Number of all Buy/Sell Pairs (periods): 185
# Sum of all Buy/Sell Pairs (periods): 3620.2987518310547
# Number of investments: 185
# Sum of investments: 36302.355560302734
#
# Number of Pairs (periods) with positive result (win): 154
# Sum of Pairs (periods) with positive result (win): 3992.9254608154297
#
# Number of Pairs (periods) with negative result (lost): 31
# Sum of Pairs (periods) with negative result (lost): -372.626708984375
#
# ------------------------------------------------------
# Length of period: 67
# Number of all Buy/Sell Pairs (periods): 184
# Sum of all Buy/Sell Pairs (periods): 3678.5132904052734
# Number of investments: 184
# Sum of investments: 36076.482681274414
#
# Number of Pairs (periods) with positive result (win): 155
# Sum of Pairs (periods) with positive result (win): 4025.654083251953
#
# Number of Pairs (periods) with negative result (lost): 29
# Sum of Pairs (periods) with negative result (lost): -347.1407928466797
#
# ------------------------------------------------------
# Length of period: 68
# Number of all Buy/Sell Pairs (periods): 183
# Sum of all Buy/Sell Pairs (periods): 3736.5113525390625
# Number of investments: 183
# Sum of investments: 35849.61199951172
#
# Number of Pairs (periods) with positive result (win): 157
# Sum of Pairs (periods) with positive result (win): 4060.005874633789
#
# Number of Pairs (periods) with negative result (lost): 26
# Sum of Pairs (periods) with negative result (lost): -323.49452209472656
#
# ------------------------------------------------------
# Length of period: 69
# Number of all Buy/Sell Pairs (periods): 182
# Sum of all Buy/Sell Pairs (periods): 3795.4925231933594
# Number of investments: 182
# Sum of investments: 35623.63934326172
#
# Number of Pairs (periods) with positive result (win): 160
# Sum of Pairs (periods) with positive result (win): 4100.29084777832
#
# Number of Pairs (periods) with negative result (lost): 22
# Sum of Pairs (periods) with negative result (lost): -304.79832458496094
#
# ------------------------------------------------------
# Length of period: 70
# Number of all Buy/Sell Pairs (periods): 181
# Sum of all Buy/Sell Pairs (periods): 3848.9740142822266
# Number of investments: 181
# Sum of investments: 35395.940490722656
#
# Number of Pairs (periods) with positive result (win): 157
# Sum of Pairs (periods) with positive result (win): 4145.341567993164
#
# Number of Pairs (periods) with negative result (lost): 24
# Sum of Pairs (periods) with negative result (lost): -296.3675537109375
#
# ------------------------------------------------------
# Length of period: 71
# Number of all Buy/Sell Pairs (periods): 180
# Sum of all Buy/Sell Pairs (periods): 3901.621124267578
# Number of investments: 180
# Sum of investments: 35167.5731048584
#
# Number of Pairs (periods) with positive result (win): 157
# Sum of Pairs (periods) with positive result (win): 4193.328872680664
#
# Number of Pairs (periods) with negative result (lost): 23
# Sum of Pairs (periods) with negative result (lost): -291.70774841308594
#
# ------------------------------------------------------
# Length of period: 72
# Number of all Buy/Sell Pairs (periods): 179
# Sum of all Buy/Sell Pairs (periods): 3949.9480590820312
# Number of investments: 179
# Sum of investments: 34947.367752075195
#
# Number of Pairs (periods) with positive result (win): 155
# Sum of Pairs (periods) with positive result (win): 4230.757461547852
#
# Number of Pairs (periods) with negative result (lost): 24
# Sum of Pairs (periods) with negative result (lost): -280.8094024658203
#
# ------------------------------------------------------
# Length of period: 73
# Number of all Buy/Sell Pairs (periods): 178
# Sum of all Buy/Sell Pairs (periods): 3997.677963256836
# Number of investments: 178
# Sum of investments: 34731.0538482666
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 4258.366455078125
#
# Number of Pairs (periods) with negative result (lost): 25
# Sum of Pairs (periods) with negative result (lost): -260.68849182128906
#
# ------------------------------------------------------
# Length of period: 74
# Number of all Buy/Sell Pairs (periods): 177
# Sum of all Buy/Sell Pairs (periods): 4046.312454223633
# Number of investments: 177
# Sum of investments: 34515.208892822266
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 4288.667785644531
#
# Number of Pairs (periods) with negative result (lost): 26
# Sum of Pairs (periods) with negative result (lost): -242.35533142089844
#
# ------------------------------------------------------
# Length of period: 75
# Number of all Buy/Sell Pairs (periods): 176
# Sum of all Buy/Sell Pairs (periods): 4102.068878173828
# Number of investments: 176
# Sum of investments: 34293.197509765625
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 4329.793655395508
#
# Number of Pairs (periods) with negative result (lost): 27
# Sum of Pairs (periods) with negative result (lost): -227.7247772216797
#
# ------------------------------------------------------
# Length of period: 76
# Number of all Buy/Sell Pairs (periods): 175
# Sum of all Buy/Sell Pairs (periods): 4160.125106811523
# Number of investments: 175
# Sum of investments: 34070.916732788086
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4368.393966674805
#
# Number of Pairs (periods) with negative result (lost): 27
# Sum of Pairs (periods) with negative result (lost): -208.26885986328125
#
# ------------------------------------------------------
# Length of period: 77
# Number of all Buy/Sell Pairs (periods): 174
# Sum of all Buy/Sell Pairs (periods): 4217.235504150391
# Number of investments: 174
# Sum of investments: 33848.74571228027
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 4406.285263061523
#
# Number of Pairs (periods) with negative result (lost): 25
# Sum of Pairs (periods) with negative result (lost): -189.0497589111328
#
# ------------------------------------------------------
# Length of period: 78
# Number of all Buy/Sell Pairs (periods): 173
# Sum of all Buy/Sell Pairs (periods): 4270.746505737305
# Number of investments: 173
# Sum of investments: 33629.119079589844
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 4442.111862182617
#
# Number of Pairs (periods) with negative result (lost): 24
# Sum of Pairs (periods) with negative result (lost): -171.3653564453125
#
# ------------------------------------------------------
# Length of period: 79
# Number of all Buy/Sell Pairs (periods): 172
# Sum of all Buy/Sell Pairs (periods): 4322.945693969727
# Number of investments: 172
# Sum of investments: 33408.69421386719
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4479.7559814453125
#
# Number of Pairs (periods) with negative result (lost): 24
# Sum of Pairs (periods) with negative result (lost): -156.81028747558594
#
# ------------------------------------------------------
# Length of period: 80
# Number of all Buy/Sell Pairs (periods): 171
# Sum of all Buy/Sell Pairs (periods): 4374.189193725586
# Number of investments: 171
# Sum of investments: 33188.359130859375
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4512.052841186523
#
# Number of Pairs (periods) with negative result (lost): 23
# Sum of Pairs (periods) with negative result (lost): -137.8636474609375
#
# ------------------------------------------------------
# Length of period: 81
# Number of all Buy/Sell Pairs (periods): 170
# Sum of all Buy/Sell Pairs (periods): 4427.576477050781
# Number of investments: 170
# Sum of investments: 32966.4674987793
#
# Number of Pairs (periods) with positive result (win): 145
# Sum of Pairs (periods) with positive result (win): 4549.846527099609
#
# Number of Pairs (periods) with negative result (lost): 25
# Sum of Pairs (periods) with negative result (lost): -122.27005004882812
#
# ------------------------------------------------------
# Length of period: 82
# Number of all Buy/Sell Pairs (periods): 169
# Sum of all Buy/Sell Pairs (periods): 4475.256866455078
# Number of investments: 169
# Sum of investments: 32746.102493286133
#
# Number of Pairs (periods) with positive result (win): 146
# Sum of Pairs (periods) with positive result (win): 4592.208892822266
#
# Number of Pairs (periods) with negative result (lost): 23
# Sum of Pairs (periods) with negative result (lost): -116.9520263671875
#
# ------------------------------------------------------
# Length of period: 83
# Number of all Buy/Sell Pairs (periods): 168
# Sum of all Buy/Sell Pairs (periods): 4528.00813293457
# Number of investments: 168
# Sum of investments: 32523.821716308594
#
# Number of Pairs (periods) with positive result (win): 146
# Sum of Pairs (periods) with positive result (win): 4631.159561157227
#
# Number of Pairs (periods) with negative result (lost): 22
# Sum of Pairs (periods) with negative result (lost): -103.15142822265625
#
# ------------------------------------------------------
# Length of period: 84
# Number of all Buy/Sell Pairs (periods): 167
# Sum of all Buy/Sell Pairs (periods): 4588.000885009766
# Number of investments: 167
# Sum of investments: 32295.324615478516
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 4674.494140625
#
# Number of Pairs (periods) with negative result (lost): 20
# Sum of Pairs (periods) with negative result (lost): -86.49325561523438
#
# ------------------------------------------------------
# Length of period: 85
# Number of all Buy/Sell Pairs (periods): 166
# Sum of all Buy/Sell Pairs (periods): 4645.069442749023
# Number of investments: 166
# Sum of investments: 32066.03924560547
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4715.107513427734
#
# Number of Pairs (periods) with negative result (lost): 18
# Sum of Pairs (periods) with negative result (lost): -70.03807067871094
#
# ------------------------------------------------------
# Length of period: 86
# Number of all Buy/Sell Pairs (periods): 165
# Sum of all Buy/Sell Pairs (periods): 4688.543884277344
# Number of investments: 165
# Sum of investments: 31840.046630859375
#
# Number of Pairs (periods) with positive result (win): 147
# Sum of Pairs (periods) with positive result (win): 4755.761962890625
#
# Number of Pairs (periods) with negative result (lost): 18
# Sum of Pairs (periods) with negative result (lost): -67.21807861328125
#
# ------------------------------------------------------
# Length of period: 87
# Number of all Buy/Sell Pairs (periods): 164
# Sum of all Buy/Sell Pairs (periods): 4735.217071533203
# Number of investments: 164
# Sum of investments: 31612.51741027832
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4793.57292175293
#
# Number of Pairs (periods) with negative result (lost): 16
# Sum of Pairs (periods) with negative result (lost): -58.35585021972656
#
# ------------------------------------------------------
# Length of period: 88
# Number of all Buy/Sell Pairs (periods): 163
# Sum of all Buy/Sell Pairs (periods): 4780.355377197266
# Number of investments: 163
# Sum of investments: 31385.836318969727
#
# Number of Pairs (periods) with positive result (win): 148
# Sum of Pairs (periods) with positive result (win): 4828.602066040039
#
# Number of Pairs (periods) with negative result (lost): 15
# Sum of Pairs (periods) with negative result (lost): -48.24668884277344
#
# ------------------------------------------------------
# Length of period: 89
# Number of all Buy/Sell Pairs (periods): 162
# Sum of all Buy/Sell Pairs (periods): 4824.8160400390625
# Number of investments: 162
# Sum of investments: 31159.49447631836
#
# Number of Pairs (periods) with positive result (win): 150
# Sum of Pairs (periods) with positive result (win): 4866.796112060547
#
# Number of Pairs (periods) with negative result (lost): 12
# Sum of Pairs (periods) with negative result (lost): -41.980072021484375
#
# ------------------------------------------------------
# Length of period: 90
# Number of all Buy/Sell Pairs (periods): 161
# Sum of all Buy/Sell Pairs (periods): 4865.150360107422
# Number of investments: 161
# Sum of investments: 30935.457550048828
#
# Number of Pairs (periods) with positive result (win): 149
# Sum of Pairs (periods) with positive result (win): 4899.368743896484
#
# Number of Pairs (periods) with negative result (lost): 12
# Sum of Pairs (periods) with negative result (lost): -34.2183837890625
#
# ------------------------------------------------------
# Length of period: 91
# Number of all Buy/Sell Pairs (periods): 160
# Sum of all Buy/Sell Pairs (periods): 4908.616317749023
# Number of investments: 160
# Sum of investments: 30709.554748535156
#
# Number of Pairs (periods) with positive result (win): 152
# Sum of Pairs (periods) with positive result (win): 4933.976379394531
#
# Number of Pairs (periods) with negative result (lost): 8
# Sum of Pairs (periods) with negative result (lost): -25.360061645507812
#
# ------------------------------------------------------
# Length of period: 92
# Number of all Buy/Sell Pairs (periods): 159
# Sum of all Buy/Sell Pairs (periods): 4948.972869873047
# Number of investments: 159
# Sum of investments: 30483.54217529297
#
# Number of Pairs (periods) with positive result (win): 152
# Sum of Pairs (periods) with positive result (win): 4968.370178222656
#
# Number of Pairs (periods) with negative result (lost): 7
# Sum of Pairs (periods) with negative result (lost): -19.397308349609375
#
# ------------------------------------------------------
# Length of period: 93
# Number of all Buy/Sell Pairs (periods): 158
# Sum of all Buy/Sell Pairs (periods): 4987.564636230469
# Number of investments: 158
# Sum of investments: 30258.148239135742
#
# Number of Pairs (periods) with positive result (win): 152
# Sum of Pairs (periods) with positive result (win): 5001.098571777344
#
# Number of Pairs (periods) with negative result (lost): 6
# Sum of Pairs (periods) with negative result (lost): -13.533935546875
#
# ------------------------------------------------------
# Length of period: 94
# Number of all Buy/Sell Pairs (periods): 157
# Sum of all Buy/Sell Pairs (periods): 5024.033706665039
# Number of investments: 157
# Sum of investments: 30032.594650268555
#
# Number of Pairs (periods) with positive result (win): 151
# Sum of Pairs (periods) with positive result (win): 5030.189239501953
#
# Number of Pairs (periods) with negative result (lost): 6
# Sum of Pairs (periods) with negative result (lost): -6.1555328369140625
#
# ------------------------------------------------------
# Length of period: 95
# Number of all Buy/Sell Pairs (periods): 156
# Sum of all Buy/Sell Pairs (periods): 5059.056106567383
# Number of investments: 156
# Sum of investments: 29808.36814880371
#
# Number of Pairs (periods) with positive result (win): 154
# Sum of Pairs (periods) with positive result (win): 5063.852752685547
#
# Number of Pairs (periods) with negative result (lost): 2
# Sum of Pairs (periods) with negative result (lost): -4.7966461181640625
#
# ------------------------------------------------------
# Length of period: 96
# Number of all Buy/Sell Pairs (periods): 155
# Sum of all Buy/Sell Pairs (periods): 5091.055206298828
# Number of investments: 155
# Sum of investments: 29587.135055541992
#
# Number of Pairs (periods) with positive result (win): 153
# Sum of Pairs (periods) with positive result (win): 5095.179290771484
#
# Number of Pairs (periods) with negative result (lost): 2
# Sum of Pairs (periods) with negative result (lost): -4.12408447265625
#
# ...
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 218
# Number of all Buy/Sell Pairs (periods): 33
# Sum of all Buy/Sell Pairs (periods): 1817.5436401367188
# Number of investments: 33
# Sum of investments: 6145.5111083984375
#
# Number of Pairs (periods) with positive result (win): 33
# Sum of Pairs (periods) with positive result (win): 1817.5436401367188
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 219
# Number of all Buy/Sell Pairs (periods): 32
# Sum of all Buy/Sell Pairs (periods): 1775.0130920410156
# Number of investments: 32
# Sum of investments: 5964.057922363281
#
# Number of Pairs (periods) with positive result (win): 32
# Sum of Pairs (periods) with positive result (win): 1775.0130920410156
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 220
# Number of all Buy/Sell Pairs (periods): 31
# Sum of all Buy/Sell Pairs (periods): 1733.1362609863281
# Number of investments: 31
# Sum of investments: 5781.061996459961
#
# Number of Pairs (periods) with positive result (win): 31
# Sum of Pairs (periods) with positive result (win): 1733.1362609863281
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 221
# Number of all Buy/Sell Pairs (periods): 30
# Sum of all Buy/Sell Pairs (periods): 1688.4514617919922
# Number of investments: 30
# Sum of investments: 5597.777435302734
#
# Number of Pairs (periods) with positive result (win): 30
# Sum of Pairs (periods) with positive result (win): 1688.4514617919922
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 222
# Number of all Buy/Sell Pairs (periods): 29
# Sum of all Buy/Sell Pairs (periods): 1647.8689422607422
# Number of investments: 29
# Sum of investments: 5413.607070922852
#
# Number of Pairs (periods) with positive result (win): 29
# Sum of Pairs (periods) with positive result (win): 1647.8689422607422
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 223
# Number of all Buy/Sell Pairs (periods): 28
# Sum of all Buy/Sell Pairs (periods): 1606.3698272705078
# Number of investments: 28
# Sum of investments: 5227.336608886719
#
# Number of Pairs (periods) with positive result (win): 28
# Sum of Pairs (periods) with positive result (win): 1606.3698272705078
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 224
# Number of all Buy/Sell Pairs (periods): 27
# Sum of all Buy/Sell Pairs (periods): 1566.3030242919922
# Number of investments: 27
# Sum of investments: 5039.374130249023
#
# Number of Pairs (periods) with positive result (win): 27
# Sum of Pairs (periods) with positive result (win): 1566.3030242919922
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 225
# Number of all Buy/Sell Pairs (periods): 26
# Sum of all Buy/Sell Pairs (periods): 1524.7506561279297
# Number of investments: 26
# Sum of investments: 4852.178009033203
#
# Number of Pairs (periods) with positive result (win): 26
# Sum of Pairs (periods) with positive result (win): 1524.7506561279297
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 226
# Number of all Buy/Sell Pairs (periods): 25
# Sum of all Buy/Sell Pairs (periods): 1484.76123046875
# Number of investments: 25
# Sum of investments: 4663.898406982422
#
# Number of Pairs (periods) with positive result (win): 25
# Sum of Pairs (periods) with positive result (win): 1484.76123046875
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 227
# Number of all Buy/Sell Pairs (periods): 24
# Sum of all Buy/Sell Pairs (periods): 1443.313949584961
# Number of investments: 24
# Sum of investments: 4475.7281494140625
#
# Number of Pairs (periods) with positive result (win): 24
# Sum of Pairs (periods) with positive result (win): 1443.313949584961
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 228
# Number of all Buy/Sell Pairs (periods): 23
# Sum of all Buy/Sell Pairs (periods): 1397.2596130371094
# Number of investments: 23
# Sum of investments: 4289.168243408203
#
# Number of Pairs (periods) with positive result (win): 23
# Sum of Pairs (periods) with positive result (win): 1397.2596130371094
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 229
# Number of all Buy/Sell Pairs (periods): 22
# Sum of all Buy/Sell Pairs (periods): 1347.1986083984375
# Number of investments: 22
# Sum of investments: 4104.42741394043
#
# Number of Pairs (periods) with positive result (win): 22
# Sum of Pairs (periods) with positive result (win): 1347.1986083984375
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 230
# Number of all Buy/Sell Pairs (periods): 21
# Sum of all Buy/Sell Pairs (periods): 1298.2714538574219
# Number of investments: 21
# Sum of investments: 3918.682586669922
#
# Number of Pairs (periods) with positive result (win): 21
# Sum of Pairs (periods) with positive result (win): 1298.2714538574219
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 231
# Number of all Buy/Sell Pairs (periods): 20
# Sum of all Buy/Sell Pairs (periods): 1244.5015869140625
# Number of investments: 20
# Sum of investments: 3735.383102416992
#
# Number of Pairs (periods) with positive result (win): 20
# Sum of Pairs (periods) with positive result (win): 1244.5015869140625
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 232
# Number of all Buy/Sell Pairs (periods): 19
# Sum of all Buy/Sell Pairs (periods): 1192.0924835205078
# Number of investments: 19
# Sum of investments: 3548.465347290039
#
# Number of Pairs (periods) with positive result (win): 19
# Sum of Pairs (periods) with positive result (win): 1192.0924835205078
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 233
# Number of all Buy/Sell Pairs (periods): 18
# Sum of all Buy/Sell Pairs (periods): 1140.2947235107422
# Number of investments: 18
# Sum of investments: 3357.879608154297
#
# Number of Pairs (periods) with positive result (win): 18
# Sum of Pairs (periods) with positive result (win): 1140.2947235107422
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 234
# Number of all Buy/Sell Pairs (periods): 17
# Sum of all Buy/Sell Pairs (periods): 1088.8232421875
# Number of investments: 17
# Sum of investments: 3166.6079864501953
#
# Number of Pairs (periods) with positive result (win): 17
# Sum of Pairs (periods) with positive result (win): 1088.8232421875
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 235
# Number of all Buy/Sell Pairs (periods): 16
# Sum of all Buy/Sell Pairs (periods): 1039.0613555908203
# Number of investments: 16
# Sum of investments: 2973.5968017578125
#
# Number of Pairs (periods) with positive result (win): 16
# Sum of Pairs (periods) with positive result (win): 1039.0613555908203
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 236
# Number of all Buy/Sell Pairs (periods): 15
# Sum of all Buy/Sell Pairs (periods): 989.8272705078125
# Number of investments: 15
# Sum of investments: 2780.257598876953
#
# Number of Pairs (periods) with positive result (win): 15
# Sum of Pairs (periods) with positive result (win): 989.8272705078125
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 237
# Number of all Buy/Sell Pairs (periods): 14
# Sum of all Buy/Sell Pairs (periods): 937.3634185791016
# Number of investments: 14
# Sum of investments: 2586.242446899414
#
# Number of Pairs (periods) with positive result (win): 14
# Sum of Pairs (periods) with positive result (win): 937.3634185791016
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 238
# Number of all Buy/Sell Pairs (periods): 13
# Sum of all Buy/Sell Pairs (periods): 882.5983734130859
# Number of investments: 13
# Sum of investments: 2393.5096130371094
#
# Number of Pairs (periods) with positive result (win): 13
# Sum of Pairs (periods) with positive result (win): 882.5983734130859
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 239
# Number of all Buy/Sell Pairs (periods): 12
# Sum of all Buy/Sell Pairs (periods): 826.7958679199219
# Number of investments: 12
# Sum of investments: 2203.0928344726562
#
# Number of Pairs (periods) with positive result (win): 12
# Sum of Pairs (periods) with positive result (win): 826.7958679199219
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 240
# Number of all Buy/Sell Pairs (periods): 11
# Sum of all Buy/Sell Pairs (periods): 766.6124267578125
# Number of investments: 11
# Sum of investments: 2015.5885925292969
#
# Number of Pairs (periods) with positive result (win): 11
# Sum of Pairs (periods) with positive result (win): 766.6124267578125
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 241
# Number of all Buy/Sell Pairs (periods): 10
# Sum of all Buy/Sell Pairs (periods): 700.3446807861328
# Number of investments: 10
# Sum of investments: 1833.9988555908203
#
# Number of Pairs (periods) with positive result (win): 10
# Sum of Pairs (periods) with positive result (win): 700.3446807861328
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 242
# Number of all Buy/Sell Pairs (periods): 9
# Sum of all Buy/Sell Pairs (periods): 632.1144714355469
# Number of investments: 9
# Sum of investments: 1651.4647827148438
#
# Number of Pairs (periods) with positive result (win): 9
# Sum of Pairs (periods) with positive result (win): 632.1144714355469
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 243
# Number of all Buy/Sell Pairs (periods): 8
# Sum of all Buy/Sell Pairs (periods): 563.7232818603516
# Number of investments: 8
# Sum of investments: 1466.6543731689453
#
# Number of Pairs (periods) with positive result (win): 8
# Sum of Pairs (periods) with positive result (win): 563.7232818603516
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 244
# Number of all Buy/Sell Pairs (periods): 7
# Sum of all Buy/Sell Pairs (periods): 500.4281005859375
# Number of investments: 7
# Sum of investments: 1282.1719818115234
#
# Number of Pairs (periods) with positive result (win): 7
# Sum of Pairs (periods) with positive result (win): 500.4281005859375
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 245
# Number of all Buy/Sell Pairs (periods): 6
# Sum of all Buy/Sell Pairs (periods): 435.9912567138672
# Number of investments: 6
# Sum of investments: 1097.0931701660156
#
# Number of Pairs (periods) with positive result (win): 6
# Sum of Pairs (periods) with positive result (win): 435.9912567138672
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 246
# Number of all Buy/Sell Pairs (periods): 5
# Sum of all Buy/Sell Pairs (periods): 365.8158264160156
# Number of investments: 5
# Sum of investments: 913.0580902099609
#
# Number of Pairs (periods) with positive result (win): 5
# Sum of Pairs (periods) with positive result (win): 365.8158264160156
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 247
# Number of all Buy/Sell Pairs (periods): 4
# Sum of all Buy/Sell Pairs (periods): 295.2787322998047
# Number of investments: 4
# Sum of investments: 728.6055297851562
#
# Number of Pairs (periods) with positive result (win): 4
# Sum of Pairs (periods) with positive result (win): 295.2787322998047
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 248
# Number of all Buy/Sell Pairs (periods): 3
# Sum of all Buy/Sell Pairs (periods): 217.46099853515625
# Number of investments: 3
# Sum of investments: 548.5068206787109
#
# Number of Pairs (periods) with positive result (win): 3
# Sum of Pairs (periods) with positive result (win): 217.46099853515625
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 249
# Number of all Buy/Sell Pairs (periods): 2
# Sum of all Buy/Sell Pairs (periods): 139.54983520507812
# Number of investments: 2
# Sum of investments: 367.68247985839844
#
# Number of Pairs (periods) with positive result (win): 2
# Sum of Pairs (periods) with positive result (win): 139.54983520507812
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------
# Length of period: 250
# Number of all Buy/Sell Pairs (periods): 1
# Sum of all Buy/Sell Pairs (periods): 67.39093017578125
# Number of investments: 1
# Sum of investments: 184.53208923339844
#
# Number of Pairs (periods) with positive result (win): 1
# Sum of Pairs (periods) with positive result (win): 67.39093017578125
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0
#
# ------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# Creating the plot
plt.plot(period_lengths, corresponding_results)

# Adding title and labels
plt.title("Result vs. period length")
plt.xlabel("Length of Stay in Market")
plt.ylabel("Result")

# Enabling grid
plt.grid(True)

# Finding the maximum y value and its corresponding x
max_y = max(corresponding_results)
max_x = period_lengths[corresponding_results.index(max_y)]

# Plotting the maximum y value
plt.plot(max_x, max_y, 'ro')  # 'ro' stands for red circle marker

# Annotating the maximum y value and corresponding x value
plt.annotate(f'Max y = {max_y} at x = {max_x}', 
             (max_x, max_y), 
             textcoords="offset points", 
             xytext=(0, 10), 
             ha='center')

# Display the plot
plt.show()

# %%
result_list, investments = evaluate_trade_period(stock_close_prices, period_length=max_x)

print(f"Period length (stay in market): {max_x}")
print(f"Max Result: {max_y}")
print()

print(f"Number of all Buy/Sell Pairs (periods): {len(result_list)}")
print(f"Sum of all Buy/Sell Pairs (periods): {sum(result_list)}")
print(f"Number of investments: {len(investments)}")
print(f"Sum of investments: {sum(investments)}")
print()

positive_results = result_list[result_list > 0]
print(f"Number of Pairs (periods) with positive result (win): {len(positive_results)}")
print(f"Sum of Pairs (periods) with positive result (win): {sum(positive_results)}")
print()

negative_results = result_list[result_list < 0]
print(f"Number of Pairs (periods) with negative result (lost): {len(negative_results)}")
print(f"Sum of Pairs (periods) with negative result (lost): {sum(negative_results)}")
print()
# Out:
# Period length (stay in market): 125
# Max Result: 5675.917465209961
#
# Number of all Buy/Sell Pairs (periods): 126
# Sum of all Buy/Sell Pairs (periods): 5675.917465209961
# Number of investments: 126
# Sum of investments: 23171.150756835938
#
# Number of Pairs (periods) with positive result (win): 126
# Sum of Pairs (periods) with positive result (win): 5675.917465209961
#
# Number of Pairs (periods) with negative result (lost): 0
# Sum of Pairs (periods) with negative result (lost): 0

# %%
total_investement = sum(investments)

share_return = round((max_y/total_investement) * 100, 2) 

print("Invested: ", total_investement)
print("Lost/Win: ", max_y)
print(f"Share Return: {share_return} %")
# Out:
# Invested:  23171.150756835938
# Lost/Win:  5675.917465209961
# Share Return: 24.5 %

# %%
buy_price_at_start = stock_close_prices.values[0][0]
bought_shares = total_investement/buy_price_at_start
sell_price_at_end = stock_close_prices.values[len(stock_close_prices)-1][0]
profit = (bought_shares*sell_price_at_end) - (bought_shares*buy_price_at_start)

print("One-time Investment: ", total_investement)
print("One-time Investment - Lost/Win: ", profit)
print(f"One-time Investment Share Return: {(profit/total_investement) * 100} %")
# Out:
# One-time Investment:  23171.150756835938
# One-time Investment - Lost/Win:  8462.080547797817
# One-time Investment Share Return: 36.519897680529915 %
