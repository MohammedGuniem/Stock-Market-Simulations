# %% [markdown]
# <h1>yfinance</h1>

# %%
import yfinance as yf
from IPython.display import JSON, display
import matplotlib.pyplot as plt

# %% [markdown]
# <h4>The Ticker module allows us to access company data based on their market ticker symbol:</h4>

# %%
data = yf.Ticker("TSLA")

# %% [markdown]
# <h4>Now, we can access the company information under the corresponding fields:</h4>

# %%
JSON(data.info)

# %% [markdown]
# <h4>Let's output the profit margins and RoE:</h4>

# %%
print("profitMargins = ", data.info['profitMargins'])
print("returnOnEquity = ", data.info['returnOnEquity'])
# Out:
# profitMargins =  0.14368
# returnOnEquity =  0.23736

# %% [markdown]
# <h4>In addition to the info fields, the data object provides the following fields:</h4>

# %% [markdown]
# <h5>dividends</h5>

# %%
display(data.dividends)
# Out:
# Series([], Name: Dividends, dtype: float64)

# %% [markdown]
# <h4>splits</h4>

# %%
display(data.splits)
# Out:
# Date
# 2020-08-31 00:00:00-04:00    5.0
# 2022-08-25 00:00:00-04:00    3.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# <h4>balance_sheet</h4>

# %%
display(data.balance_sheet)
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                                      0.0
# Ordinary Shares Number                             3185000000.0
# Share Issued                                       3185000000.0
# Net Debt                                                    NaN
# Total Debt                                         9573000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  29094000000.0
# Other Short Term Investments                      12696000000.0
# Cash And Cash Equivalents                         16398000000.0
# Cash Equivalents                                    495000000.0
# Cash Financial                                    15903000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             3164000000.0
# ...

# %% [markdown]
# <h4>cashflow</h4>

# %%
display(data.cashflow)
# Out:
#                                                    2023-12-31     2022-12-31  \
# Free Cash Flow                                   4357000000.0   7552000000.0
# Repayment Of Debt                               -1815000000.0  -3866000000.0
# Issuance Of Debt                                 3931000000.0            0.0
# Issuance Of Capital Stock                                 NaN            0.0
# Capital Expenditure                             -8899000000.0  -7172000000.0
# Interest Paid Supplemental Data                   126000000.0    152000000.0
# Income Tax Paid Supplemental Data                1119000000.0   1203000000.0
# End Cash Position                               17189000000.0  16924000000.0
# Beginning Cash Position                         16924000000.0  18144000000.0
# Effect Of Exchange Rate Changes                     4000000.0   -444000000.0
# Changes In Cash                                   261000000.0   -776000000.0
# ...

# %% [markdown]
# <h4>earnings_dates</h4>

# %%
display(data.earnings_dates)
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-06-13 16:00:00-04:00           NaN           NaN          NaN
# 2025-04-21 16:00:00-04:00           NaN           NaN          NaN
# 2025-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-10-16 06:00:00-04:00           NaN           NaN          NaN
# 2024-07-17 06:00:00-04:00          0.59           NaN          NaN
# 2024-06-13 16:00:00-04:00           NaN           NaN          NaN
# 2024-04-23 16:00:00-04:00          0.51          0.45      -0.1204
# 2024-01-24 16:00:00-05:00          0.74          0.71      -0.0439
# 2023-10-18 16:00:00-04:00          0.72          0.66      -0.0825
# 2023-07-19 16:00:00-04:00          0.82          0.91       0.1063
# 2023-04-19 16:00:00-04:00          0.85          0.85      -0.0004
# 2023-01-25 16:00:00-05:00          1.13          1.19       0.0555

# %% [markdown]
# <h4>plot the cash flow table as bar charts</h4>

# %%
x = data.earnings_dates
x.plot(kind="bar")
plt.show()
